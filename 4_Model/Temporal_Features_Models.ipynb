# %% [markdown]
# # Models on Temporal Features
# ## Data Preparation

# %%
from Classifier import get_KNN_Model, get_accuracy_matric, get_lin_SVM_Model, get_NaiveBayes_Model
from Hawkes_Process import get_topic_vector
from Topic_Modelling import LDA_main_driver
from filters import train_test_splitter
import numpy as np
import warnings

warnings.simplefilter(action='ignore')

# %%
df, dict_genuine, dict_fake, lda_genuine, lda_fake = LDA_main_driver()
num_topics = 10
# Out:
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-* LDA Training Started -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
#
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-* LDA Training Ended -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*

# %%
user_topic_vectors, labels = get_topic_vector(df, dict_genuine, dict_fake, lda_genuine, lda_fake, 1)
# Out:
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-* Hawkes Process Started -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
#
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-* Hawkes Process Ended -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*

# %%
total_len = len(user_topic_vectors)
X = np.array(user_topic_vectors)
Y = np.array(labels)

# %%
hawkes_ops = X[:,[20,21]]

# %%
hawkes_ops.shape, Y.shape
# Out:
# ((1527, 2), (1527,))

# %%
x_train, x_test, y_train, y_test = train_test_splitter(hawkes_ops, Y)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((1221, 2), (1221,), (306, 2), (306,))

# %%
def confusionMatrixPrint(P,Y,dataType):
    TF = 0
    TT = 0
    FF = 0
    FT = 0
    for p,y in zip(P,Y):
        if (p,y) == (0,0):
            FF += 1
        elif (p,y) == (1,1):
            TT += 1
        elif (p,y) == (0,1):
            TF += 1
        else:
            FT += 1

    print('------------------------------------------------------------------------------------\n')
    if dataType == 0:
        print("  Confusion Matrix for Train Data : ")
    else:
        print("  Confusion Matrix for Validation Data \n")
    print("         True Positive = ",TT,"           True Negetive = ",TF)
    print("        False Positive = ",FT,"          False Negetive = ",FF)
    print('\n------------------------------------------------------------------------------------\n')
    total = TT+FF+TF+FT
    print(f"  Total Cases : {total}\n")
    print("Accuracy  : ",(TT+FF)/total)
    try:
        prec = (TT)/(TT+FT)
        recall = (TT)/(TT+TF)
        f = (2*recall*prec)/(recall+prec)
        print("Precision : ",prec)
        print("Recall    : ",recall)
        print("F1 Score  : ",f)
    except:
        pass
    
    
    print('\n------------------------------------------------------------------------------------')

# %% [markdown]
# # 1. KNN Classifier on Intensity Function Value And Adj_matrix Value

# %%
knn = get_KNN_Model(x_train, y_train)

# %%
pred = knn.predict(x_train)
confusionMatrixPrint(pred,y_train,0)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Train Data :
#          True Positive =  12            True Negetive =  149
#         False Positive =  14           False Negetive =  1046
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 1221
#
# Accuracy  :  0.8665028665028665
# Precision :  0.46153846153846156
# Recall    :  0.07453416149068323
# F1 Score  :  0.1283422459893048
#
# ------------------------------------------------------------------------------------

# %%
pred = knn.predict(x_test)
confusionMatrixPrint(pred,y_test,1)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Validation Data
#
#          True Positive =  3            True Negetive =  30
#         False Positive =  5           False Negetive =  268
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 306
#
# Accuracy  :  0.8856209150326797
# Precision :  0.375
# Recall    :  0.09090909090909091
# F1 Score  :  0.14634146341463414
#
# ------------------------------------------------------------------------------------

# %% [markdown]
# # 2. SVM Classifier on Intensity Function Value And Adj_matrix Value

# %%
svm = get_lin_SVM_Model(x_train, y_train)

# %%
pred = svm.predict(x_train)
confusionMatrixPrint(pred,y_train,0)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Train Data :
#          True Positive =  0            True Negetive =  161
#         False Positive =  0           False Negetive =  1060
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 1221
#
# Accuracy  :  0.8681408681408681
#
# ------------------------------------------------------------------------------------

# %%
pred = svm.predict(x_test)
confusionMatrixPrint(pred,y_test,1)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Validation Data
#
#          True Positive =  0            True Negetive =  33
#         False Positive =  0           False Negetive =  273
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 306
#
# Accuracy  :  0.8921568627450981
#
# ------------------------------------------------------------------------------------

# %% [markdown]
# # 3. Naive Bayes Classifier on Intensity Function Value And Adj_matrix Value

# %%
nb = get_NaiveBayes_Model(x_train, y_train)

# %%
pred = nb.predict(x_train)
confusionMatrixPrint(pred,y_train,0)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Train Data :
#          True Positive =  0            True Negetive =  161
#         False Positive =  0           False Negetive =  1060
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 1221
#
# Accuracy  :  0.8681408681408681
#
# ------------------------------------------------------------------------------------

# %%
pred = nb.predict(x_test)
confusionMatrixPrint(pred,y_test,1)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Validation Data
#
#          True Positive =  0            True Negetive =  33
#         False Positive =  0           False Negetive =  273
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 306
#
# Accuracy  :  0.8921568627450981
#
# ------------------------------------------------------------------------------------

# %% [markdown]
# # 4. Nueral Network Based Classifier on Hawkes Process Output
#
# ## Fully Connected Network of :
#      - Input Layer : 2, 64
#      - Hidden Layer 1 : 64 , 128
#      - Hidden Layer 2 : 128 , 256
#      - Hidden Layer 3 : 256 , 512
#      - Hidden Layer 4 : 512 , 256
#      - Hidden Layer 5 : 256 , 128
#      - Hidden Layer 6 : 128 , 64
#      - Hidden Layer 7 : 64 , 32
#      - Hidden Layer 8 : 32 , 16
#      - Output Layer : 16 , 2

# %%
import torch.nn as nn
import warnings
import torch

# %%
def get_Device():
    return torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device = get_Device()
print(device)
# Out:
# cuda

# %%
x_train = torch.Tensor(x_train).to(device)
y_train = torch.Tensor(y_train).to(device)
x_test = torch.Tensor(x_test).to(device)
y_test = torch.Tensor(y_test).to(device)

# %%
y_train = y_train.to(torch.long)

# %%
class TemporalClassifierModel(nn.Module):
    def __init__(self, input_size, output_size):
        super(TemporalClassifierModel, self).__init__()
        self.layer1 = nn.Linear(input_size, 64)
        self.layer2 = nn.Linear(64, 128)
        self.layer3 = nn.Linear(128, 256)
        self.layer4 = nn.Linear(256, 512)
        self.layer5 = nn.Linear(512, 256)
        
        self.layer6 = nn.Linear(256, 128)
        self.layer7 = nn.Linear(128, 64)
        self.layer8 = nn.Linear(64, 32)
        self.layer9 = nn.Linear(32, 16)
        self.layer10 = nn.Linear(16, output_size)
        self.relu = nn.ReLU()
        

    def forward(self, inputs):
        out = self.layer1(inputs)
        out = self.relu(out)
        
        out = self.layer2(out)
        out = self.relu(out)
        
        out = self.layer3(out)
        out = self.relu(out)
        
        out = self.layer4(out)
        out = self.relu(out)
        
        out = self.layer5(out)
        out = self.relu(out)
        
        out = self.layer6(out)
        out = self.relu(out)
        
        out = self.layer7(out)
        out = self.relu(out)
        
        out = self.layer8(out)
        out = self.relu(out)
        
        out = self.layer9(out)
        out = self.relu(out)
        
        out = self.layer10(out)
        
        return out

# %%
input_size = 2
output_size = 2
hidden_size = 80
learning_rate = 0.0001
n_epochs = 5000

# %%
model = TemporalClassifierModel(input_size=input_size,
                                     output_size=output_size)
model.to(device)
# Out:
# TemporalClassifierModel(
#   (layer1): Linear(in_features=2, out_features=64, bias=True)
#   (layer2): Linear(in_features=64, out_features=128, bias=True)
#   (layer3): Linear(in_features=128, out_features=256, bias=True)
#   (layer4): Linear(in_features=256, out_features=512, bias=True)
#   (layer5): Linear(in_features=512, out_features=256, bias=True)
#   (layer6): Linear(in_features=256, out_features=128, bias=True)
#   (layer7): Linear(in_features=128, out_features=64, bias=True)
#   (layer8): Linear(in_features=64, out_features=32, bias=True)
#   (layer9): Linear(in_features=32, out_features=16, bias=True)
#   (layer10): Linear(in_features=16, out_features=2, bias=True)
#   (relu): ReLU()
# )

# %%
lossfn = torch.nn.CrossEntropyLoss()
lossfn.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def Validator(x_test, y_test):
    predicted = model(x_test).to(device)
    pred = torch.max(predicted.data,1)[1]
    total_test = len(y_test)
    correct_pred = 0

    for i in range(total_test):
        if y_test[i] == pred[i]:
            correct_pred += 1

    return correct_pred/total_test

# %%
val_acc_list = []
training_acc_list = []
model_list = []

for epoch in range(n_epochs):

    predicted = model(x_train).to(device)    

    loss = lossfn(predicted,y_train)
        
    optimizer.zero_grad()
    loss.backward()
    
    optimizer.step()
    
    val_acc = Validator(x_test, y_test.to(torch.int))
    
    print(f'Epoch [ {epoch+1} / {n_epochs} ] Training-Loss = {loss.item():.4f} Training-Accuracy = {1- loss.item()} Validation-Accuracy = {val_acc}')
    
    training_acc_list.append(1-loss.item())
    val_acc_list.append(val_acc)
    model_list.append(model)
# Out:
# Epoch [ 1 / 5000 ] Training-Loss = 0.6431 Training-Accuracy = 0.3568531274795532 Validation-Accuracy = 0.8921568627450981
# Epoch [ 2 / 5000 ] Training-Loss = 0.6423 Training-Accuracy = 0.3577149510383606 Validation-Accuracy = 0.8921568627450981
# Epoch [ 3 / 5000 ] Training-Loss = 0.6417 Training-Accuracy = 0.3583173155784607 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4 / 5000 ] Training-Loss = 0.6411 Training-Accuracy = 0.3588683605194092 Validation-Accuracy = 0.8921568627450981
# Epoch [ 5 / 5000 ] Training-Loss = 0.6406 Training-Accuracy = 0.3594295382499695 Validation-Accuracy = 0.8921568627450981
# Epoch [ 6 / 5000 ] Training-Loss = 0.6400 Training-Accuracy = 0.35995054244995117 Validation-Accuracy = 0.8921568627450981
# Epoch [ 7 / 5000 ] Training-Loss = 0.6396 Training-Accuracy = 0.36042749881744385 Validation-Accuracy = 0.8921568627450981
# Epoch [ 8 / 5000 ] Training-Loss = 0.6391 Training-Accuracy = 0.3608996868133545 Validation-Accuracy = 0.8921568627450981
# Epoch [ 9 / 5000 ] Training-Loss = 0.6386 Training-Accuracy = 0.3613675832748413 Validation-Accuracy = 0.8921568627450981
# Epoch [ 10 / 5000 ] Training-Loss = 0.6382 Training-Accuracy = 0.36183977127075195 Validation-Accuracy = 0.8921568627450981
# Epoch [ 11 / 5000 ] Training-Loss = 0.6377 Training-Accuracy = 0.3623098134994507 Validation-Accuracy = 0.8921568627450981
# Epoch [ 12 / 5000 ] Training-Loss = 0.6372 Training-Accuracy = 0.3627890944480896 Validation-Accuracy = 0.8921568627450981
# Epoch [ 13 / 5000 ] Training-Loss = 0.6367 Training-Accuracy = 0.3632829189300537 Validation-Accuracy = 0.8921568627450981
# Epoch [ 14 / 5000 ] Training-Loss = 0.6362 Training-Accuracy = 0.36377543210983276 Validation-Accuracy = 0.8921568627450981
# Epoch [ 15 / 5000 ] Training-Loss = 0.6357 Training-Accuracy = 0.36428624391555786 Validation-Accuracy = 0.8921568627450981
# Epoch [ 16 / 5000 ] Training-Loss = 0.6352 Training-Accuracy = 0.3648190498352051 Validation-Accuracy = 0.8921568627450981
# Epoch [ 17 / 5000 ] Training-Loss = 0.6346 Training-Accuracy = 0.3653736114501953 Validation-Accuracy = 0.8921568627450981
# Epoch [ 18 / 5000 ] Training-Loss = 0.6341 Training-Accuracy = 0.36594200134277344 Validation-Accuracy = 0.8921568627450981
# Epoch [ 19 / 5000 ] Training-Loss = 0.6335 Training-Accuracy = 0.3665276765823364 Validation-Accuracy = 0.8921568627450981
# Epoch [ 20 / 5000 ] Training-Loss = 0.6329 Training-Accuracy = 0.36713922023773193 Validation-Accuracy = 0.8921568627450981
# Epoch [ 21 / 5000 ] Training-Loss = 0.6322 Training-Accuracy = 0.3677706718444824 Validation-Accuracy = 0.8921568627450981
# Epoch [ 22 / 5000 ] Training-Loss = 0.6316 Training-Accuracy = 0.3684263229370117 Validation-Accuracy = 0.8921568627450981
# Epoch [ 23 / 5000 ] Training-Loss = 0.6309 Training-Accuracy = 0.36911213397979736 Validation-Accuracy = 0.8921568627450981
# Epoch [ 24 / 5000 ] Training-Loss = 0.6302 Training-Accuracy = 0.36983007192611694 Validation-Accuracy = 0.8921568627450981
# Epoch [ 25 / 5000 ] Training-Loss = 0.6294 Training-Accuracy = 0.37059223651885986 Validation-Accuracy = 0.8921568627450981
# Epoch [ 26 / 5000 ] Training-Loss = 0.6286 Training-Accuracy = 0.3714108467102051 Validation-Accuracy = 0.8921568627450981
# Epoch [ 27 / 5000 ] Training-Loss = 0.6277 Training-Accuracy = 0.3723044991493225 Validation-Accuracy = 0.8921568627450981
# Epoch [ 28 / 5000 ] Training-Loss = 0.6267 Training-Accuracy = 0.373291015625 Validation-Accuracy = 0.8921568627450981
# Epoch [ 29 / 5000 ] Training-Loss = 0.6256 Training-Accuracy = 0.37436002492904663 Validation-Accuracy = 0.8921568627450981
# Epoch [ 30 / 5000 ] Training-Loss = 0.6245 Training-Accuracy = 0.3755069971084595 Validation-Accuracy = 0.8921568627450981
# Epoch [ 31 / 5000 ] Training-Loss = 0.6233 Training-Accuracy = 0.3767325282096863 Validation-Accuracy = 0.8921568627450981
# Epoch [ 32 / 5000 ] Training-Loss = 0.6220 Training-Accuracy = 0.37804239988327026 Validation-Accuracy = 0.8921568627450981
# Epoch [ 33 / 5000 ] Training-Loss = 0.6205 Training-Accuracy = 0.3794543147087097 Validation-Accuracy = 0.8921568627450981
# Epoch [ 34 / 5000 ] Training-Loss = 0.6190 Training-Accuracy = 0.3809904456138611 Validation-Accuracy = 0.8921568627450981
# Epoch [ 35 / 5000 ] Training-Loss = 0.6173 Training-Accuracy = 0.382667601108551 Validation-Accuracy = 0.8921568627450981
# Epoch [ 36 / 5000 ] Training-Loss = 0.6155 Training-Accuracy = 0.38451099395751953 Validation-Accuracy = 0.8921568627450981
# Epoch [ 37 / 5000 ] Training-Loss = 0.6134 Training-Accuracy = 0.3865787386894226 Validation-Accuracy = 0.8921568627450981
# Epoch [ 38 / 5000 ] Training-Loss = 0.6110 Training-Accuracy = 0.388996422290802 Validation-Accuracy = 0.8921568627450981
# Epoch [ 39 / 5000 ] Training-Loss = 0.6080 Training-Accuracy = 0.39199531078338623 Validation-Accuracy = 0.8921568627450981
# Epoch [ 40 / 5000 ] Training-Loss = 0.6041 Training-Accuracy = 0.39589983224868774 Validation-Accuracy = 0.8921568627450981
# Epoch [ 41 / 5000 ] Training-Loss = 0.5992 Training-Accuracy = 0.4008335471153259 Validation-Accuracy = 0.8921568627450981
# Epoch [ 42 / 5000 ] Training-Loss = 0.5933 Training-Accuracy = 0.4066644310951233 Validation-Accuracy = 0.8921568627450981
# Epoch [ 43 / 5000 ] Training-Loss = 0.5869 Training-Accuracy = 0.4131011366844177 Validation-Accuracy = 0.8921568627450981
# Epoch [ 44 / 5000 ] Training-Loss = 0.5799 Training-Accuracy = 0.42012518644332886 Validation-Accuracy = 0.8921568627450981
# Epoch [ 45 / 5000 ] Training-Loss = 0.5723 Training-Accuracy = 0.42771559953689575 Validation-Accuracy = 0.8921568627450981
# Epoch [ 46 / 5000 ] Training-Loss = 0.5640 Training-Accuracy = 0.4359899163246155 Validation-Accuracy = 0.8921568627450981
# Epoch [ 47 / 5000 ] Training-Loss = 0.5549 Training-Accuracy = 0.4451327919960022 Validation-Accuracy = 0.8921568627450981
# Epoch [ 48 / 5000 ] Training-Loss = 0.5448 Training-Accuracy = 0.4552167057991028 Validation-Accuracy = 0.8921568627450981
# Epoch [ 49 / 5000 ] Training-Loss = 0.5337 Training-Accuracy = 0.466333270072937 Validation-Accuracy = 0.8921568627450981
# Epoch [ 50 / 5000 ] Training-Loss = 0.5217 Training-Accuracy = 0.47828757762908936 Validation-Accuracy = 0.8921568627450981
# Epoch [ 51 / 5000 ] Training-Loss = 0.5090 Training-Accuracy = 0.49096208810806274 Validation-Accuracy = 0.8921568627450981
# Epoch [ 52 / 5000 ] Training-Loss = 0.4958 Training-Accuracy = 0.5042384266853333 Validation-Accuracy = 0.8921568627450981
# Epoch [ 53 / 5000 ] Training-Loss = 0.4820 Training-Accuracy = 0.5179774165153503 Validation-Accuracy = 0.8921568627450981
# Epoch [ 54 / 5000 ] Training-Loss = 0.4681 Training-Accuracy = 0.5319168269634247 Validation-Accuracy = 0.8921568627450981
# Epoch [ 55 / 5000 ] Training-Loss = 0.4542 Training-Accuracy = 0.5457874536514282 Validation-Accuracy = 0.8921568627450981
# Epoch [ 56 / 5000 ] Training-Loss = 0.4407 Training-Accuracy = 0.5592582523822784 Validation-Accuracy = 0.8921568627450981
# Epoch [ 57 / 5000 ] Training-Loss = 0.4281 Training-Accuracy = 0.5719462931156158 Validation-Accuracy = 0.8921568627450981
# Epoch [ 58 / 5000 ] Training-Loss = 0.4165 Training-Accuracy = 0.5834957361221313 Validation-Accuracy = 0.8921568627450981
# Epoch [ 59 / 5000 ] Training-Loss = 0.4064 Training-Accuracy = 0.5935702621936798 Validation-Accuracy = 0.8921568627450981
# Epoch [ 60 / 5000 ] Training-Loss = 0.3981 Training-Accuracy = 0.6018597483634949 Validation-Accuracy = 0.8921568627450981
# Epoch [ 61 / 5000 ] Training-Loss = 0.3920 Training-Accuracy = 0.6080295145511627 Validation-Accuracy = 0.8921568627450981
# Epoch [ 62 / 5000 ] Training-Loss = 0.3882 Training-Accuracy = 0.6118422448635101 Validation-Accuracy = 0.8921568627450981
# Epoch [ 63 / 5000 ] Training-Loss = 0.3867 Training-Accuracy = 0.6132608354091644 Validation-Accuracy = 0.8921568627450981
# Epoch [ 64 / 5000 ] Training-Loss = 0.3875 Training-Accuracy = 0.6125145852565765 Validation-Accuracy = 0.8921568627450981
# Epoch [ 65 / 5000 ] Training-Loss = 0.3899 Training-Accuracy = 0.610137015581131 Validation-Accuracy = 0.8921568627450981
# Epoch [ 66 / 5000 ] Training-Loss = 0.3931 Training-Accuracy = 0.6069031953811646 Validation-Accuracy = 0.8921568627450981
# Epoch [ 67 / 5000 ] Training-Loss = 0.3964 Training-Accuracy = 0.6036241948604584 Validation-Accuracy = 0.8921568627450981
# Epoch [ 68 / 5000 ] Training-Loss = 0.3990 Training-Accuracy = 0.6009927988052368 Validation-Accuracy = 0.8921568627450981
# Epoch [ 69 / 5000 ] Training-Loss = 0.4006 Training-Accuracy = 0.5994223058223724 Validation-Accuracy = 0.8921568627450981
# Epoch [ 70 / 5000 ] Training-Loss = 0.4009 Training-Accuracy = 0.5990519225597382 Validation-Accuracy = 0.8921568627450981
# Epoch [ 71 / 5000 ] Training-Loss = 0.4002 Training-Accuracy = 0.5997738242149353 Validation-Accuracy = 0.8921568627450981
# Epoch [ 72 / 5000 ] Training-Loss = 0.3987 Training-Accuracy = 0.6013233065605164 Validation-Accuracy = 0.8921568627450981
# Epoch [ 73 / 5000 ] Training-Loss = 0.3966 Training-Accuracy = 0.6034156978130341 Validation-Accuracy = 0.8921568627450981
# Epoch [ 74 / 5000 ] Training-Loss = 0.3943 Training-Accuracy = 0.6057318449020386 Validation-Accuracy = 0.8921568627450981
# Epoch [ 75 / 5000 ] Training-Loss = 0.3920 Training-Accuracy = 0.6079913675785065 Validation-Accuracy = 0.8921568627450981
# Epoch [ 76 / 5000 ] Training-Loss = 0.3900 Training-Accuracy = 0.6099750697612762 Validation-Accuracy = 0.8921568627450981
# Epoch [ 77 / 5000 ] Training-Loss = 0.3884 Training-Accuracy = 0.6115652620792389 Validation-Accuracy = 0.8921568627450981
# Epoch [ 78 / 5000 ] Training-Loss = 0.3873 Training-Accuracy = 0.6127029657363892 Validation-Accuracy = 0.8921568627450981
# Epoch [ 79 / 5000 ] Training-Loss = 0.3866 Training-Accuracy = 0.6133899986743927 Validation-Accuracy = 0.8921568627450981
# Epoch [ 80 / 5000 ] Training-Loss = 0.3863 Training-Accuracy = 0.6136772632598877 Validation-Accuracy = 0.8921568627450981
# Epoch [ 81 / 5000 ] Training-Loss = 0.3863 Training-Accuracy = 0.6136551201343536 Validation-Accuracy = 0.8921568627450981
# Epoch [ 82 / 5000 ] Training-Loss = 0.3866 Training-Accuracy = 0.6134192943572998 Validation-Accuracy = 0.8921568627450981
# Epoch [ 83 / 5000 ] Training-Loss = 0.3869 Training-Accuracy = 0.613067626953125 Validation-Accuracy = 0.8921568627450981
# Epoch [ 84 / 5000 ] Training-Loss = 0.3873 Training-Accuracy = 0.6126892864704132 Validation-Accuracy = 0.8921568627450981
# Epoch [ 85 / 5000 ] Training-Loss = 0.3876 Training-Accuracy = 0.6123561561107635 Validation-Accuracy = 0.8921568627450981
# Epoch [ 86 / 5000 ] Training-Loss = 0.3879 Training-Accuracy = 0.6121157705783844 Validation-Accuracy = 0.8921568627450981
# Epoch [ 87 / 5000 ] Training-Loss = 0.3880 Training-Accuracy = 0.6119958460330963 Validation-Accuracy = 0.8921568627450981
# Epoch [ 88 / 5000 ] Training-Loss = 0.3880 Training-Accuracy = 0.6120036840438843 Validation-Accuracy = 0.8921568627450981
# Epoch [ 89 / 5000 ] Training-Loss = 0.3879 Training-Accuracy = 0.6121306419372559 Validation-Accuracy = 0.8921568627450981
# Epoch [ 90 / 5000 ] Training-Loss = 0.3876 Training-Accuracy = 0.6123562455177307 Validation-Accuracy = 0.8921568627450981
# Epoch [ 91 / 5000 ] Training-Loss = 0.3873 Training-Accuracy = 0.6126509606838226 Validation-Accuracy = 0.8921568627450981
# Epoch [ 92 / 5000 ] Training-Loss = 0.3870 Training-Accuracy = 0.6129838824272156 Validation-Accuracy = 0.8921568627450981
# Epoch [ 93 / 5000 ] Training-Loss = 0.3867 Training-Accuracy = 0.6133244931697845 Validation-Accuracy = 0.8921568627450981
# Epoch [ 94 / 5000 ] Training-Loss = 0.3864 Training-Accuracy = 0.6136394739151001 Validation-Accuracy = 0.8921568627450981
# Epoch [ 95 / 5000 ] Training-Loss = 0.3861 Training-Accuracy = 0.6139047741889954 Validation-Accuracy = 0.8921568627450981
# Epoch [ 96 / 5000 ] Training-Loss = 0.3859 Training-Accuracy = 0.6141046583652496 Validation-Accuracy = 0.8921568627450981
# Epoch [ 97 / 5000 ] Training-Loss = 0.3858 Training-Accuracy = 0.6142347157001495 Validation-Accuracy = 0.8921568627450981
# Epoch [ 98 / 5000 ] Training-Loss = 0.3857 Training-Accuracy = 0.6142936646938324 Validation-Accuracy = 0.8921568627450981
# Epoch [ 99 / 5000 ] Training-Loss = 0.3857 Training-Accuracy = 0.6142930388450623 Validation-Accuracy = 0.8921568627450981
# Epoch [ 100 / 5000 ] Training-Loss = 0.3857 Training-Accuracy = 0.6142524778842926 Validation-Accuracy = 0.8921568627450981
# Epoch [ 101 / 5000 ] Training-Loss = 0.3858 Training-Accuracy = 0.6141960322856903 Validation-Accuracy = 0.8921568627450981
# Epoch [ 102 / 5000 ] Training-Loss = 0.3859 Training-Accuracy = 0.6141456961631775 Validation-Accuracy = 0.8921568627450981
# Epoch [ 103 / 5000 ] Training-Loss = 0.3859 Training-Accuracy = 0.6141176223754883 Validation-Accuracy = 0.8921568627450981
# Epoch [ 104 / 5000 ] Training-Loss = 0.3859 Training-Accuracy = 0.6141210794448853 Validation-Accuracy = 0.8921568627450981
# Epoch [ 105 / 5000 ] Training-Loss = 0.3858 Training-Accuracy = 0.6141589879989624 Validation-Accuracy = 0.8921568627450981
# Epoch [ 106 / 5000 ] Training-Loss = 0.3858 Training-Accuracy = 0.6142266392707825 Validation-Accuracy = 0.8921568627450981
# Epoch [ 107 / 5000 ] Training-Loss = 0.3857 Training-Accuracy = 0.6143157184123993 Validation-Accuracy = 0.8921568627450981
# Epoch [ 108 / 5000 ] Training-Loss = 0.3856 Training-Accuracy = 0.6144145429134369 Validation-Accuracy = 0.8921568627450981
# Epoch [ 109 / 5000 ] Training-Loss = 0.3855 Training-Accuracy = 0.6145147383213043 Validation-Accuracy = 0.8921568627450981
# Epoch [ 110 / 5000 ] Training-Loss = 0.3854 Training-Accuracy = 0.6146073639392853 Validation-Accuracy = 0.8921568627450981
# Epoch [ 111 / 5000 ] Training-Loss = 0.3853 Training-Accuracy = 0.6146872937679291 Validation-Accuracy = 0.8921568627450981
# Epoch [ 112 / 5000 ] Training-Loss = 0.3852 Training-Accuracy = 0.6147505044937134 Validation-Accuracy = 0.8921568627450981
# Epoch [ 113 / 5000 ] Training-Loss = 0.3852 Training-Accuracy = 0.614798903465271 Validation-Accuracy = 0.8921568627450981
# Epoch [ 114 / 5000 ] Training-Loss = 0.3852 Training-Accuracy = 0.6148349344730377 Validation-Accuracy = 0.8921568627450981
# Epoch [ 115 / 5000 ] Training-Loss = 0.3851 Training-Accuracy = 0.6148632764816284 Validation-Accuracy = 0.8921568627450981
# Epoch [ 116 / 5000 ] Training-Loss = 0.3851 Training-Accuracy = 0.6148881018161774 Validation-Accuracy = 0.8921568627450981
# Epoch [ 117 / 5000 ] Training-Loss = 0.3851 Training-Accuracy = 0.614914208650589 Validation-Accuracy = 0.8921568627450981
# Epoch [ 118 / 5000 ] Training-Loss = 0.3851 Training-Accuracy = 0.6149449646472931 Validation-Accuracy = 0.8921568627450981
# Epoch [ 119 / 5000 ] Training-Loss = 0.3850 Training-Accuracy = 0.6149831712245941 Validation-Accuracy = 0.8921568627450981
# Epoch [ 120 / 5000 ] Training-Loss = 0.3850 Training-Accuracy = 0.6150285303592682 Validation-Accuracy = 0.8921568627450981
# Epoch [ 121 / 5000 ] Training-Loss = 0.3849 Training-Accuracy = 0.6150802373886108 Validation-Accuracy = 0.8921568627450981
# Epoch [ 122 / 5000 ] Training-Loss = 0.3849 Training-Accuracy = 0.615135669708252 Validation-Accuracy = 0.8921568627450981
# Epoch [ 123 / 5000 ] Training-Loss = 0.3848 Training-Accuracy = 0.6151906549930573 Validation-Accuracy = 0.8921568627450981
# Epoch [ 124 / 5000 ] Training-Loss = 0.3848 Training-Accuracy = 0.6152440309524536 Validation-Accuracy = 0.8921568627450981
# Epoch [ 125 / 5000 ] Training-Loss = 0.3847 Training-Accuracy = 0.6152941882610321 Validation-Accuracy = 0.8921568627450981
# Epoch [ 126 / 5000 ] Training-Loss = 0.3847 Training-Accuracy = 0.615337610244751 Validation-Accuracy = 0.8921568627450981
# Epoch [ 127 / 5000 ] Training-Loss = 0.3846 Training-Accuracy = 0.6153770983219147 Validation-Accuracy = 0.8921568627450981
# Epoch [ 128 / 5000 ] Training-Loss = 0.3846 Training-Accuracy = 0.6154127717018127 Validation-Accuracy = 0.8921568627450981
# Epoch [ 129 / 5000 ] Training-Loss = 0.3846 Training-Accuracy = 0.6154472231864929 Validation-Accuracy = 0.8921568627450981
# Epoch [ 130 / 5000 ] Training-Loss = 0.3845 Training-Accuracy = 0.6154830753803253 Validation-Accuracy = 0.8921568627450981
# Epoch [ 131 / 5000 ] Training-Loss = 0.3845 Training-Accuracy = 0.6155208051204681 Validation-Accuracy = 0.8921568627450981
# Epoch [ 132 / 5000 ] Training-Loss = 0.3844 Training-Accuracy = 0.615559458732605 Validation-Accuracy = 0.8921568627450981
# Epoch [ 133 / 5000 ] Training-Loss = 0.3844 Training-Accuracy = 0.6156013011932373 Validation-Accuracy = 0.8921568627450981
# Epoch [ 134 / 5000 ] Training-Loss = 0.3844 Training-Accuracy = 0.6156458258628845 Validation-Accuracy = 0.8921568627450981
# Epoch [ 135 / 5000 ] Training-Loss = 0.3843 Training-Accuracy = 0.6156903505325317 Validation-Accuracy = 0.8921568627450981
# Epoch [ 136 / 5000 ] Training-Loss = 0.3843 Training-Accuracy = 0.615734726190567 Validation-Accuracy = 0.8921568627450981
# Epoch [ 137 / 5000 ] Training-Loss = 0.3842 Training-Accuracy = 0.6157777905464172 Validation-Accuracy = 0.8921568627450981
# Epoch [ 138 / 5000 ] Training-Loss = 0.3842 Training-Accuracy = 0.61581951379776 Validation-Accuracy = 0.8921568627450981
# Epoch [ 139 / 5000 ] Training-Loss = 0.3841 Training-Accuracy = 0.6158594787120819 Validation-Accuracy = 0.8921568627450981
# Epoch [ 140 / 5000 ] Training-Loss = 0.3841 Training-Accuracy = 0.6158983409404755 Validation-Accuracy = 0.8921568627450981
# Epoch [ 141 / 5000 ] Training-Loss = 0.3841 Training-Accuracy = 0.6159359812736511 Validation-Accuracy = 0.8921568627450981
# Epoch [ 142 / 5000 ] Training-Loss = 0.3840 Training-Accuracy = 0.6159743666648865 Validation-Accuracy = 0.8921568627450981
# Epoch [ 143 / 5000 ] Training-Loss = 0.3840 Training-Accuracy = 0.6160145401954651 Validation-Accuracy = 0.8921568627450981
# Epoch [ 144 / 5000 ] Training-Loss = 0.3839 Training-Accuracy = 0.6160561144351959 Validation-Accuracy = 0.8921568627450981
# Epoch [ 145 / 5000 ] Training-Loss = 0.3839 Training-Accuracy = 0.6160998642444611 Validation-Accuracy = 0.8921568627450981
# Epoch [ 146 / 5000 ] Training-Loss = 0.3839 Training-Accuracy = 0.6161442995071411 Validation-Accuracy = 0.8921568627450981
# Epoch [ 147 / 5000 ] Training-Loss = 0.3838 Training-Accuracy = 0.6161888837814331 Validation-Accuracy = 0.8921568627450981
# Epoch [ 148 / 5000 ] Training-Loss = 0.3838 Training-Accuracy = 0.6162325441837311 Validation-Accuracy = 0.8921568627450981
# Epoch [ 149 / 5000 ] Training-Loss = 0.3837 Training-Accuracy = 0.6162751317024231 Validation-Accuracy = 0.8921568627450981
# Epoch [ 150 / 5000 ] Training-Loss = 0.3837 Training-Accuracy = 0.6163162589073181 Validation-Accuracy = 0.8921568627450981
# Epoch [ 151 / 5000 ] Training-Loss = 0.3836 Training-Accuracy = 0.6163569092750549 Validation-Accuracy = 0.8921568627450981
# Epoch [ 152 / 5000 ] Training-Loss = 0.3836 Training-Accuracy = 0.6163986027240753 Validation-Accuracy = 0.8921568627450981
# Epoch [ 153 / 5000 ] Training-Loss = 0.3836 Training-Accuracy = 0.6164423525333405 Validation-Accuracy = 0.8921568627450981
# Epoch [ 154 / 5000 ] Training-Loss = 0.3835 Training-Accuracy = 0.6164872050285339 Validation-Accuracy = 0.8921568627450981
# Epoch [ 155 / 5000 ] Training-Loss = 0.3835 Training-Accuracy = 0.6165316998958588 Validation-Accuracy = 0.8921568627450981
# Epoch [ 156 / 5000 ] Training-Loss = 0.3834 Training-Accuracy = 0.6165750622749329 Validation-Accuracy = 0.8921568627450981
# Epoch [ 157 / 5000 ] Training-Loss = 0.3834 Training-Accuracy = 0.6166180074214935 Validation-Accuracy = 0.8921568627450981
# Epoch [ 158 / 5000 ] Training-Loss = 0.3833 Training-Accuracy = 0.6166604459285736 Validation-Accuracy = 0.8921568627450981
# Epoch [ 159 / 5000 ] Training-Loss = 0.3833 Training-Accuracy = 0.6167020797729492 Validation-Accuracy = 0.8921568627450981
# Epoch [ 160 / 5000 ] Training-Loss = 0.3833 Training-Accuracy = 0.6167445182800293 Validation-Accuracy = 0.8921568627450981
# Epoch [ 161 / 5000 ] Training-Loss = 0.3832 Training-Accuracy = 0.6167864203453064 Validation-Accuracy = 0.8921568627450981
# Epoch [ 162 / 5000 ] Training-Loss = 0.3832 Training-Accuracy = 0.616828978061676 Validation-Accuracy = 0.8921568627450981
# Epoch [ 163 / 5000 ] Training-Loss = 0.3831 Training-Accuracy = 0.6168721318244934 Validation-Accuracy = 0.8921568627450981
# Epoch [ 164 / 5000 ] Training-Loss = 0.3831 Training-Accuracy = 0.6169168055057526 Validation-Accuracy = 0.8921568627450981
# Epoch [ 165 / 5000 ] Training-Loss = 0.3830 Training-Accuracy = 0.6169608533382416 Validation-Accuracy = 0.8921568627450981
# Epoch [ 166 / 5000 ] Training-Loss = 0.3830 Training-Accuracy = 0.6170036494731903 Validation-Accuracy = 0.8921568627450981
# Epoch [ 167 / 5000 ] Training-Loss = 0.3830 Training-Accuracy = 0.6170467734336853 Validation-Accuracy = 0.8921568627450981
# Epoch [ 168 / 5000 ] Training-Loss = 0.3829 Training-Accuracy = 0.6170893013477325 Validation-Accuracy = 0.8921568627450981
# Epoch [ 169 / 5000 ] Training-Loss = 0.3829 Training-Accuracy = 0.6171316504478455 Validation-Accuracy = 0.8921568627450981
# Epoch [ 170 / 5000 ] Training-Loss = 0.3828 Training-Accuracy = 0.6171735227108002 Validation-Accuracy = 0.8921568627450981
# Epoch [ 171 / 5000 ] Training-Loss = 0.3828 Training-Accuracy = 0.6172139644622803 Validation-Accuracy = 0.8921568627450981
# Epoch [ 172 / 5000 ] Training-Loss = 0.3827 Training-Accuracy = 0.6172545254230499 Validation-Accuracy = 0.8921568627450981
# Epoch [ 173 / 5000 ] Training-Loss = 0.3827 Training-Accuracy = 0.6172945201396942 Validation-Accuracy = 0.8921568627450981
# Epoch [ 174 / 5000 ] Training-Loss = 0.3827 Training-Accuracy = 0.6173353791236877 Validation-Accuracy = 0.8921568627450981
# Epoch [ 175 / 5000 ] Training-Loss = 0.3826 Training-Accuracy = 0.6173754930496216 Validation-Accuracy = 0.8921568627450981
# Epoch [ 176 / 5000 ] Training-Loss = 0.3826 Training-Accuracy = 0.6174148619174957 Validation-Accuracy = 0.8921568627450981
# Epoch [ 177 / 5000 ] Training-Loss = 0.3825 Training-Accuracy = 0.6174541711807251 Validation-Accuracy = 0.8921568627450981
# Epoch [ 178 / 5000 ] Training-Loss = 0.3825 Training-Accuracy = 0.6174940168857574 Validation-Accuracy = 0.8921568627450981
# Epoch [ 179 / 5000 ] Training-Loss = 0.3825 Training-Accuracy = 0.6175337433815002 Validation-Accuracy = 0.8921568627450981
# Epoch [ 180 / 5000 ] Training-Loss = 0.3824 Training-Accuracy = 0.6175733208656311 Validation-Accuracy = 0.8921568627450981
# Epoch [ 181 / 5000 ] Training-Loss = 0.3824 Training-Accuracy = 0.6176132559776306 Validation-Accuracy = 0.8921568627450981
# Epoch [ 182 / 5000 ] Training-Loss = 0.3823 Training-Accuracy = 0.617652028799057 Validation-Accuracy = 0.8921568627450981
# Epoch [ 183 / 5000 ] Training-Loss = 0.3823 Training-Accuracy = 0.6176896393299103 Validation-Accuracy = 0.8921568627450981
# Epoch [ 184 / 5000 ] Training-Loss = 0.3823 Training-Accuracy = 0.6177283227443695 Validation-Accuracy = 0.8921568627450981
# Epoch [ 185 / 5000 ] Training-Loss = 0.3822 Training-Accuracy = 0.6177673935890198 Validation-Accuracy = 0.8921568627450981
# Epoch [ 186 / 5000 ] Training-Loss = 0.3822 Training-Accuracy = 0.6178054511547089 Validation-Accuracy = 0.8921568627450981
# Epoch [ 187 / 5000 ] Training-Loss = 0.3822 Training-Accuracy = 0.6178434491157532 Validation-Accuracy = 0.8921568627450981
# Epoch [ 188 / 5000 ] Training-Loss = 0.3821 Training-Accuracy = 0.6178808212280273 Validation-Accuracy = 0.8921568627450981
# Epoch [ 189 / 5000 ] Training-Loss = 0.3821 Training-Accuracy = 0.6179184317588806 Validation-Accuracy = 0.8921568627450981
# Epoch [ 190 / 5000 ] Training-Loss = 0.3820 Training-Accuracy = 0.6179557740688324 Validation-Accuracy = 0.8921568627450981
# Epoch [ 191 / 5000 ] Training-Loss = 0.3820 Training-Accuracy = 0.6179929375648499 Validation-Accuracy = 0.8921568627450981
# Epoch [ 192 / 5000 ] Training-Loss = 0.3820 Training-Accuracy = 0.6180287301540375 Validation-Accuracy = 0.8921568627450981
# Epoch [ 193 / 5000 ] Training-Loss = 0.3819 Training-Accuracy = 0.6180640161037445 Validation-Accuracy = 0.8921568627450981
# Epoch [ 194 / 5000 ] Training-Loss = 0.3819 Training-Accuracy = 0.6180996894836426 Validation-Accuracy = 0.8921568627450981
# Epoch [ 195 / 5000 ] Training-Loss = 0.3819 Training-Accuracy = 0.6181355714797974 Validation-Accuracy = 0.8921568627450981
# Epoch [ 196 / 5000 ] Training-Loss = 0.3818 Training-Accuracy = 0.6181714534759521 Validation-Accuracy = 0.8921568627450981
# Epoch [ 197 / 5000 ] Training-Loss = 0.3818 Training-Accuracy = 0.618206799030304 Validation-Accuracy = 0.8921568627450981
# Epoch [ 198 / 5000 ] Training-Loss = 0.3818 Training-Accuracy = 0.6182417571544647 Validation-Accuracy = 0.8921568627450981
# Epoch [ 199 / 5000 ] Training-Loss = 0.3817 Training-Accuracy = 0.6182762384414673 Validation-Accuracy = 0.8921568627450981
# Epoch [ 200 / 5000 ] Training-Loss = 0.3817 Training-Accuracy = 0.6183101832866669 Validation-Accuracy = 0.8921568627450981
# Epoch [ 201 / 5000 ] Training-Loss = 0.3817 Training-Accuracy = 0.6183443665504456 Validation-Accuracy = 0.8921568627450981
# Epoch [ 202 / 5000 ] Training-Loss = 0.3816 Training-Accuracy = 0.6183780133724213 Validation-Accuracy = 0.8921568627450981
# Epoch [ 203 / 5000 ] Training-Loss = 0.3816 Training-Accuracy = 0.6184113919734955 Validation-Accuracy = 0.8921568627450981
# Epoch [ 204 / 5000 ] Training-Loss = 0.3816 Training-Accuracy = 0.6184446215629578 Validation-Accuracy = 0.8921568627450981
# Epoch [ 205 / 5000 ] Training-Loss = 0.3815 Training-Accuracy = 0.6184771955013275 Validation-Accuracy = 0.8921568627450981
# Epoch [ 206 / 5000 ] Training-Loss = 0.3815 Training-Accuracy = 0.6185097098350525 Validation-Accuracy = 0.8921568627450981
# Epoch [ 207 / 5000 ] Training-Loss = 0.3815 Training-Accuracy = 0.6185413599014282 Validation-Accuracy = 0.8921568627450981
# Epoch [ 208 / 5000 ] Training-Loss = 0.3814 Training-Accuracy = 0.6185726821422577 Validation-Accuracy = 0.8921568627450981
# Epoch [ 209 / 5000 ] Training-Loss = 0.3814 Training-Accuracy = 0.6186042428016663 Validation-Accuracy = 0.8921568627450981
# Epoch [ 210 / 5000 ] Training-Loss = 0.3814 Training-Accuracy = 0.6186355352401733 Validation-Accuracy = 0.8921568627450981
# Epoch [ 211 / 5000 ] Training-Loss = 0.3813 Training-Accuracy = 0.6186657547950745 Validation-Accuracy = 0.8921568627450981
# Epoch [ 212 / 5000 ] Training-Loss = 0.3813 Training-Accuracy = 0.6186957657337189 Validation-Accuracy = 0.8921568627450981
# Epoch [ 213 / 5000 ] Training-Loss = 0.3813 Training-Accuracy = 0.618725597858429 Validation-Accuracy = 0.8921568627450981
# Epoch [ 214 / 5000 ] Training-Loss = 0.3812 Training-Accuracy = 0.6187548935413361 Validation-Accuracy = 0.8921568627450981
# Epoch [ 215 / 5000 ] Training-Loss = 0.3812 Training-Accuracy = 0.6187841296195984 Validation-Accuracy = 0.8921568627450981
# Epoch [ 216 / 5000 ] Training-Loss = 0.3812 Training-Accuracy = 0.6188131868839264 Validation-Accuracy = 0.8921568627450981
# Epoch [ 217 / 5000 ] Training-Loss = 0.3812 Training-Accuracy = 0.6188419461250305 Validation-Accuracy = 0.8921568627450981
# Epoch [ 218 / 5000 ] Training-Loss = 0.3811 Training-Accuracy = 0.6188704669475555 Validation-Accuracy = 0.8921568627450981
# Epoch [ 219 / 5000 ] Training-Loss = 0.3811 Training-Accuracy = 0.6188985705375671 Validation-Accuracy = 0.8921568627450981
# Epoch [ 220 / 5000 ] Training-Loss = 0.3811 Training-Accuracy = 0.6189264059066772 Validation-Accuracy = 0.8921568627450981
# Epoch [ 221 / 5000 ] Training-Loss = 0.3810 Training-Accuracy = 0.6189538836479187 Validation-Accuracy = 0.8921568627450981
# Epoch [ 222 / 5000 ] Training-Loss = 0.3810 Training-Accuracy = 0.6189813017845154 Validation-Accuracy = 0.8921568627450981
# Epoch [ 223 / 5000 ] Training-Loss = 0.3810 Training-Accuracy = 0.6190082132816315 Validation-Accuracy = 0.8921568627450981
# Epoch [ 224 / 5000 ] Training-Loss = 0.3810 Training-Accuracy = 0.6190349459648132 Validation-Accuracy = 0.8921568627450981
# Epoch [ 225 / 5000 ] Training-Loss = 0.3809 Training-Accuracy = 0.6190614402294159 Validation-Accuracy = 0.8921568627450981
# Epoch [ 226 / 5000 ] Training-Loss = 0.3809 Training-Accuracy = 0.6190874874591827 Validation-Accuracy = 0.8921568627450981
# Epoch [ 227 / 5000 ] Training-Loss = 0.3809 Training-Accuracy = 0.6191126704216003 Validation-Accuracy = 0.8921568627450981
# Epoch [ 228 / 5000 ] Training-Loss = 0.3809 Training-Accuracy = 0.6191379129886627 Validation-Accuracy = 0.8921568627450981
# Epoch [ 229 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6191628575325012 Validation-Accuracy = 0.8921568627450981
# Epoch [ 230 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6191874444484711 Validation-Accuracy = 0.8921568627450981
# Epoch [ 231 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192114949226379 Validation-Accuracy = 0.8921568627450981
# Epoch [ 232 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192349493503571 Validation-Accuracy = 0.8921568627450981
# Epoch [ 233 / 5000 ] Training-Loss = 0.3807 Training-Accuracy = 0.6192583441734314 Validation-Accuracy = 0.8921568627450981
# Epoch [ 234 / 5000 ] Training-Loss = 0.3807 Training-Accuracy = 0.6192820370197296 Validation-Accuracy = 0.8921568627450981
# Epoch [ 235 / 5000 ] Training-Loss = 0.3807 Training-Accuracy = 0.6193052232265472 Validation-Accuracy = 0.8921568627450981
# Epoch [ 236 / 5000 ] Training-Loss = 0.3807 Training-Accuracy = 0.6193278133869171 Validation-Accuracy = 0.8921568627450981
# Epoch [ 237 / 5000 ] Training-Loss = 0.3807 Training-Accuracy = 0.6193499863147736 Validation-Accuracy = 0.8921568627450981
# Epoch [ 238 / 5000 ] Training-Loss = 0.3806 Training-Accuracy = 0.6193724274635315 Validation-Accuracy = 0.8921568627450981
# Epoch [ 239 / 5000 ] Training-Loss = 0.3806 Training-Accuracy = 0.6193943917751312 Validation-Accuracy = 0.8921568627450981
# Epoch [ 240 / 5000 ] Training-Loss = 0.3806 Training-Accuracy = 0.6194161474704742 Validation-Accuracy = 0.8921568627450981
# Epoch [ 241 / 5000 ] Training-Loss = 0.3806 Training-Accuracy = 0.6194378435611725 Validation-Accuracy = 0.8921568627450981
# Epoch [ 242 / 5000 ] Training-Loss = 0.3805 Training-Accuracy = 0.6194590926170349 Validation-Accuracy = 0.8921568627450981
# Epoch [ 243 / 5000 ] Training-Loss = 0.3805 Training-Accuracy = 0.6194802522659302 Validation-Accuracy = 0.8921568627450981
# Epoch [ 244 / 5000 ] Training-Loss = 0.3805 Training-Accuracy = 0.619500994682312 Validation-Accuracy = 0.8921568627450981
# Epoch [ 245 / 5000 ] Training-Loss = 0.3805 Training-Accuracy = 0.6195213198661804 Validation-Accuracy = 0.8921568627450981
# Epoch [ 246 / 5000 ] Training-Loss = 0.3805 Training-Accuracy = 0.6195414364337921 Validation-Accuracy = 0.8921568627450981
# Epoch [ 247 / 5000 ] Training-Loss = 0.3804 Training-Accuracy = 0.6195612847805023 Validation-Accuracy = 0.8921568627450981
# Epoch [ 248 / 5000 ] Training-Loss = 0.3804 Training-Accuracy = 0.61958047747612 Validation-Accuracy = 0.8921568627450981
# Epoch [ 249 / 5000 ] Training-Loss = 0.3804 Training-Accuracy = 0.6195995211601257 Validation-Accuracy = 0.8921568627450981
# Epoch [ 250 / 5000 ] Training-Loss = 0.3804 Training-Accuracy = 0.61961829662323 Validation-Accuracy = 0.8921568627450981
# Epoch [ 251 / 5000 ] Training-Loss = 0.3804 Training-Accuracy = 0.619636595249176 Validation-Accuracy = 0.8921568627450981
# Epoch [ 252 / 5000 ] Training-Loss = 0.3803 Training-Accuracy = 0.6196546256542206 Validation-Accuracy = 0.8921568627450981
# Epoch [ 253 / 5000 ] Training-Loss = 0.3803 Training-Accuracy = 0.6196726560592651 Validation-Accuracy = 0.8921568627450981
# Epoch [ 254 / 5000 ] Training-Loss = 0.3803 Training-Accuracy = 0.6196902394294739 Validation-Accuracy = 0.8921568627450981
# Epoch [ 255 / 5000 ] Training-Loss = 0.3803 Training-Accuracy = 0.6197076439857483 Validation-Accuracy = 0.8921568627450981
# Epoch [ 256 / 5000 ] Training-Loss = 0.3803 Training-Accuracy = 0.6197247803211212 Validation-Accuracy = 0.8921568627450981
# Epoch [ 257 / 5000 ] Training-Loss = 0.3803 Training-Accuracy = 0.6197419464588165 Validation-Accuracy = 0.8921568627450981
# Epoch [ 258 / 5000 ] Training-Loss = 0.3802 Training-Accuracy = 0.6197586059570312 Validation-Accuracy = 0.8921568627450981
# Epoch [ 259 / 5000 ] Training-Loss = 0.3802 Training-Accuracy = 0.6197749674320221 Validation-Accuracy = 0.8921568627450981
# Epoch [ 260 / 5000 ] Training-Loss = 0.3802 Training-Accuracy = 0.6197911202907562 Validation-Accuracy = 0.8921568627450981
# Epoch [ 261 / 5000 ] Training-Loss = 0.3802 Training-Accuracy = 0.6198070347309113 Validation-Accuracy = 0.8921568627450981
# Epoch [ 262 / 5000 ] Training-Loss = 0.3802 Training-Accuracy = 0.6198231279850006 Validation-Accuracy = 0.8921568627450981
# Epoch [ 263 / 5000 ] Training-Loss = 0.3802 Training-Accuracy = 0.6198384165763855 Validation-Accuracy = 0.8921568627450981
# Epoch [ 264 / 5000 ] Training-Loss = 0.3801 Training-Accuracy = 0.6198538541793823 Validation-Accuracy = 0.8921568627450981
# Epoch [ 265 / 5000 ] Training-Loss = 0.3801 Training-Accuracy = 0.6198692619800568 Validation-Accuracy = 0.8921568627450981
# Epoch [ 266 / 5000 ] Training-Loss = 0.3801 Training-Accuracy = 0.6198841333389282 Validation-Accuracy = 0.8921568627450981
# Epoch [ 267 / 5000 ] Training-Loss = 0.3801 Training-Accuracy = 0.6198988258838654 Validation-Accuracy = 0.8921568627450981
# Epoch [ 268 / 5000 ] Training-Loss = 0.3801 Training-Accuracy = 0.6199131011962891 Validation-Accuracy = 0.8921568627450981
# Epoch [ 269 / 5000 ] Training-Loss = 0.3801 Training-Accuracy = 0.6199273467063904 Validation-Accuracy = 0.8921568627450981
# Epoch [ 270 / 5000 ] Training-Loss = 0.3801 Training-Accuracy = 0.6199413239955902 Validation-Accuracy = 0.8921568627450981
# Epoch [ 271 / 5000 ] Training-Loss = 0.3800 Training-Accuracy = 0.6199550032615662 Validation-Accuracy = 0.8921568627450981
# Epoch [ 272 / 5000 ] Training-Loss = 0.3800 Training-Accuracy = 0.6199683547019958 Validation-Accuracy = 0.8921568627450981
# Epoch [ 273 / 5000 ] Training-Loss = 0.3800 Training-Accuracy = 0.6199818849563599 Validation-Accuracy = 0.8921568627450981
# Epoch [ 274 / 5000 ] Training-Loss = 0.3800 Training-Accuracy = 0.6199950277805328 Validation-Accuracy = 0.8921568627450981
# Epoch [ 275 / 5000 ] Training-Loss = 0.3800 Training-Accuracy = 0.6200080215930939 Validation-Accuracy = 0.8921568627450981
# Epoch [ 276 / 5000 ] Training-Loss = 0.3800 Training-Accuracy = 0.620020717382431 Validation-Accuracy = 0.8921568627450981
# Epoch [ 277 / 5000 ] Training-Loss = 0.3800 Training-Accuracy = 0.6200335621833801 Validation-Accuracy = 0.8921568627450981
# Epoch [ 278 / 5000 ] Training-Loss = 0.3800 Training-Accuracy = 0.6200463175773621 Validation-Accuracy = 0.8921568627450981
# Epoch [ 279 / 5000 ] Training-Loss = 0.3799 Training-Accuracy = 0.6200588047504425 Validation-Accuracy = 0.8921568627450981
# Epoch [ 280 / 5000 ] Training-Loss = 0.3799 Training-Accuracy = 0.6200712025165558 Validation-Accuracy = 0.8921568627450981
# Epoch [ 281 / 5000 ] Training-Loss = 0.3799 Training-Accuracy = 0.6200833022594452 Validation-Accuracy = 0.8921568627450981
# Epoch [ 282 / 5000 ] Training-Loss = 0.3799 Training-Accuracy = 0.6200952529907227 Validation-Accuracy = 0.8921568627450981
# Epoch [ 283 / 5000 ] Training-Loss = 0.3799 Training-Accuracy = 0.6201070845127106 Validation-Accuracy = 0.8921568627450981
# Epoch [ 284 / 5000 ] Training-Loss = 0.3799 Training-Accuracy = 0.6201186776161194 Validation-Accuracy = 0.8921568627450981
# Epoch [ 285 / 5000 ] Training-Loss = 0.3799 Training-Accuracy = 0.6201298832893372 Validation-Accuracy = 0.8921568627450981
# Epoch [ 286 / 5000 ] Training-Loss = 0.3799 Training-Accuracy = 0.6201407611370087 Validation-Accuracy = 0.8921568627450981
# Epoch [ 287 / 5000 ] Training-Loss = 0.3798 Training-Accuracy = 0.6201516687870026 Validation-Accuracy = 0.8921568627450981
# Epoch [ 288 / 5000 ] Training-Loss = 0.3798 Training-Accuracy = 0.6201624274253845 Validation-Accuracy = 0.8921568627450981
# Epoch [ 289 / 5000 ] Training-Loss = 0.3798 Training-Accuracy = 0.6201730370521545 Validation-Accuracy = 0.8921568627450981
# Epoch [ 290 / 5000 ] Training-Loss = 0.3798 Training-Accuracy = 0.6201837360858917 Validation-Accuracy = 0.8921568627450981
# Epoch [ 291 / 5000 ] Training-Loss = 0.3798 Training-Accuracy = 0.6201939880847931 Validation-Accuracy = 0.8921568627450981
# Epoch [ 292 / 5000 ] Training-Loss = 0.3798 Training-Accuracy = 0.6202040612697601 Validation-Accuracy = 0.8921568627450981
# Epoch [ 293 / 5000 ] Training-Loss = 0.3798 Training-Accuracy = 0.6202140152454376 Validation-Accuracy = 0.8921568627450981
# Epoch [ 294 / 5000 ] Training-Loss = 0.3798 Training-Accuracy = 0.6202237606048584 Validation-Accuracy = 0.8921568627450981
# Epoch [ 295 / 5000 ] Training-Loss = 0.3798 Training-Accuracy = 0.6202336549758911 Validation-Accuracy = 0.8921568627450981
# Epoch [ 296 / 5000 ] Training-Loss = 0.3798 Training-Accuracy = 0.6202432811260223 Validation-Accuracy = 0.8921568627450981
# Epoch [ 297 / 5000 ] Training-Loss = 0.3797 Training-Accuracy = 0.6202528178691864 Validation-Accuracy = 0.8921568627450981
# Epoch [ 298 / 5000 ] Training-Loss = 0.3797 Training-Accuracy = 0.6202622950077057 Validation-Accuracy = 0.8921568627450981
# Epoch [ 299 / 5000 ] Training-Loss = 0.3797 Training-Accuracy = 0.6202720105648041 Validation-Accuracy = 0.8921568627450981
# Epoch [ 300 / 5000 ] Training-Loss = 0.3797 Training-Accuracy = 0.6202808320522308 Validation-Accuracy = 0.8921568627450981
# Epoch [ 301 / 5000 ] Training-Loss = 0.3797 Training-Accuracy = 0.6202899515628815 Validation-Accuracy = 0.8921568627450981
# Epoch [ 302 / 5000 ] Training-Loss = 0.3797 Training-Accuracy = 0.620298832654953 Validation-Accuracy = 0.8921568627450981
# Epoch [ 303 / 5000 ] Training-Loss = 0.3797 Training-Accuracy = 0.6203079521656036 Validation-Accuracy = 0.8921568627450981
# Epoch [ 304 / 5000 ] Training-Loss = 0.3797 Training-Accuracy = 0.6203167140483856 Validation-Accuracy = 0.8921568627450981
# Epoch [ 305 / 5000 ] Training-Loss = 0.3797 Training-Accuracy = 0.6203254461288452 Validation-Accuracy = 0.8921568627450981
# Epoch [ 306 / 5000 ] Training-Loss = 0.3797 Training-Accuracy = 0.6203341484069824 Validation-Accuracy = 0.8921568627450981
# Epoch [ 307 / 5000 ] Training-Loss = 0.3797 Training-Accuracy = 0.6203423738479614 Validation-Accuracy = 0.8921568627450981
# Epoch [ 308 / 5000 ] Training-Loss = 0.3796 Training-Accuracy = 0.6203508973121643 Validation-Accuracy = 0.8921568627450981
# Epoch [ 309 / 5000 ] Training-Loss = 0.3796 Training-Accuracy = 0.6203594505786896 Validation-Accuracy = 0.8921568627450981
# Epoch [ 310 / 5000 ] Training-Loss = 0.3796 Training-Accuracy = 0.6203676760196686 Validation-Accuracy = 0.8921568627450981
# Epoch [ 311 / 5000 ] Training-Loss = 0.3796 Training-Accuracy = 0.6203759610652924 Validation-Accuracy = 0.8921568627450981
# Epoch [ 312 / 5000 ] Training-Loss = 0.3796 Training-Accuracy = 0.6203844547271729 Validation-Accuracy = 0.8921568627450981
# Epoch [ 313 / 5000 ] Training-Loss = 0.3796 Training-Accuracy = 0.6203927099704742 Validation-Accuracy = 0.8921568627450981
# Epoch [ 314 / 5000 ] Training-Loss = 0.3796 Training-Accuracy = 0.6204007267951965 Validation-Accuracy = 0.8921568627450981
# Epoch [ 315 / 5000 ] Training-Loss = 0.3796 Training-Accuracy = 0.620409220457077 Validation-Accuracy = 0.8921568627450981
# Epoch [ 316 / 5000 ] Training-Loss = 0.3796 Training-Accuracy = 0.6204172670841217 Validation-Accuracy = 0.8921568627450981
# Epoch [ 317 / 5000 ] Training-Loss = 0.3796 Training-Accuracy = 0.6204250752925873 Validation-Accuracy = 0.8921568627450981
# Epoch [ 318 / 5000 ] Training-Loss = 0.3796 Training-Accuracy = 0.620433121919632 Validation-Accuracy = 0.8921568627450981
# Epoch [ 319 / 5000 ] Training-Loss = 0.3796 Training-Accuracy = 0.6204403340816498 Validation-Accuracy = 0.8921568627450981
# Epoch [ 320 / 5000 ] Training-Loss = 0.3796 Training-Accuracy = 0.6204476356506348 Validation-Accuracy = 0.8921568627450981
# Epoch [ 321 / 5000 ] Training-Loss = 0.3795 Training-Accuracy = 0.6204547882080078 Validation-Accuracy = 0.8921568627450981
# Epoch [ 322 / 5000 ] Training-Loss = 0.3795 Training-Accuracy = 0.6204618513584137 Validation-Accuracy = 0.8921568627450981
# Epoch [ 323 / 5000 ] Training-Loss = 0.3795 Training-Accuracy = 0.6204686164855957 Validation-Accuracy = 0.8921568627450981
# Epoch [ 324 / 5000 ] Training-Loss = 0.3795 Training-Accuracy = 0.6204758286476135 Validation-Accuracy = 0.8921568627450981
# Epoch [ 325 / 5000 ] Training-Loss = 0.3795 Training-Accuracy = 0.6204828321933746 Validation-Accuracy = 0.8921568627450981
# Epoch [ 326 / 5000 ] Training-Loss = 0.3795 Training-Accuracy = 0.6204896569252014 Validation-Accuracy = 0.8921568627450981
# Epoch [ 327 / 5000 ] Training-Loss = 0.3795 Training-Accuracy = 0.6204961836338043 Validation-Accuracy = 0.8921568627450981
# Epoch [ 328 / 5000 ] Training-Loss = 0.3795 Training-Accuracy = 0.6205030083656311 Validation-Accuracy = 0.8921568627450981
# Epoch [ 329 / 5000 ] Training-Loss = 0.3795 Training-Accuracy = 0.6205097138881683 Validation-Accuracy = 0.8921568627450981
# Epoch [ 330 / 5000 ] Training-Loss = 0.3795 Training-Accuracy = 0.6205163300037384 Validation-Accuracy = 0.8921568627450981
# Epoch [ 331 / 5000 ] Training-Loss = 0.3795 Training-Accuracy = 0.6205230355262756 Validation-Accuracy = 0.8921568627450981
# Epoch [ 332 / 5000 ] Training-Loss = 0.3795 Training-Accuracy = 0.6205297112464905 Validation-Accuracy = 0.8921568627450981
# Epoch [ 333 / 5000 ] Training-Loss = 0.3795 Training-Accuracy = 0.6205361485481262 Validation-Accuracy = 0.8921568627450981
# Epoch [ 334 / 5000 ] Training-Loss = 0.3795 Training-Accuracy = 0.62054243683815 Validation-Accuracy = 0.8921568627450981
# Epoch [ 335 / 5000 ] Training-Loss = 0.3795 Training-Accuracy = 0.6205484569072723 Validation-Accuracy = 0.8921568627450981
# Epoch [ 336 / 5000 ] Training-Loss = 0.3794 Training-Accuracy = 0.6205551028251648 Validation-Accuracy = 0.8921568627450981
# Epoch [ 337 / 5000 ] Training-Loss = 0.3794 Training-Accuracy = 0.6205615401268005 Validation-Accuracy = 0.8921568627450981
# Epoch [ 338 / 5000 ] Training-Loss = 0.3794 Training-Accuracy = 0.6205678880214691 Validation-Accuracy = 0.8921568627450981
# Epoch [ 339 / 5000 ] Training-Loss = 0.3794 Training-Accuracy = 0.6205739378929138 Validation-Accuracy = 0.8921568627450981
# Epoch [ 340 / 5000 ] Training-Loss = 0.3794 Training-Accuracy = 0.6205804944038391 Validation-Accuracy = 0.8921568627450981
# Epoch [ 341 / 5000 ] Training-Loss = 0.3794 Training-Accuracy = 0.6205867230892181 Validation-Accuracy = 0.8921568627450981
# Epoch [ 342 / 5000 ] Training-Loss = 0.3794 Training-Accuracy = 0.6205929219722748 Validation-Accuracy = 0.8921568627450981
# Epoch [ 343 / 5000 ] Training-Loss = 0.3794 Training-Accuracy = 0.6205987334251404 Validation-Accuracy = 0.8921568627450981
# Epoch [ 344 / 5000 ] Training-Loss = 0.3794 Training-Accuracy = 0.6206051111221313 Validation-Accuracy = 0.8921568627450981
# Epoch [ 345 / 5000 ] Training-Loss = 0.3794 Training-Accuracy = 0.6206111013889313 Validation-Accuracy = 0.8921568627450981
# Epoch [ 346 / 5000 ] Training-Loss = 0.3794 Training-Accuracy = 0.6206172704696655 Validation-Accuracy = 0.8921568627450981
# Epoch [ 347 / 5000 ] Training-Loss = 0.3794 Training-Accuracy = 0.6206232011318207 Validation-Accuracy = 0.8921568627450981
# Epoch [ 348 / 5000 ] Training-Loss = 0.3794 Training-Accuracy = 0.6206294596195221 Validation-Accuracy = 0.8921568627450981
# Epoch [ 349 / 5000 ] Training-Loss = 0.3794 Training-Accuracy = 0.6206350922584534 Validation-Accuracy = 0.8921568627450981
# Epoch [ 350 / 5000 ] Training-Loss = 0.3794 Training-Accuracy = 0.6206412613391876 Validation-Accuracy = 0.8921568627450981
# Epoch [ 351 / 5000 ] Training-Loss = 0.3794 Training-Accuracy = 0.6206476390361786 Validation-Accuracy = 0.8921568627450981
# Epoch [ 352 / 5000 ] Training-Loss = 0.3793 Training-Accuracy = 0.620653361082077 Validation-Accuracy = 0.8921568627450981
# Epoch [ 353 / 5000 ] Training-Loss = 0.3793 Training-Accuracy = 0.6206592917442322 Validation-Accuracy = 0.8921568627450981
# Epoch [ 354 / 5000 ] Training-Loss = 0.3793 Training-Accuracy = 0.620665431022644 Validation-Accuracy = 0.8921568627450981
# Epoch [ 355 / 5000 ] Training-Loss = 0.3793 Training-Accuracy = 0.6206711828708649 Validation-Accuracy = 0.8921568627450981
# Epoch [ 356 / 5000 ] Training-Loss = 0.3793 Training-Accuracy = 0.6206771731376648 Validation-Accuracy = 0.8921568627450981
# Epoch [ 357 / 5000 ] Training-Loss = 0.3793 Training-Accuracy = 0.6206834018230438 Validation-Accuracy = 0.8921568627450981
# Epoch [ 358 / 5000 ] Training-Loss = 0.3793 Training-Accuracy = 0.6206890046596527 Validation-Accuracy = 0.8921568627450981
# Epoch [ 359 / 5000 ] Training-Loss = 0.3793 Training-Accuracy = 0.6206940114498138 Validation-Accuracy = 0.8921568627450981
# Epoch [ 360 / 5000 ] Training-Loss = 0.3793 Training-Accuracy = 0.6206982135772705 Validation-Accuracy = 0.8921568627450981
# Epoch [ 361 / 5000 ] Training-Loss = 0.3793 Training-Accuracy = 0.6207043826580048 Validation-Accuracy = 0.8921568627450981
# Epoch [ 362 / 5000 ] Training-Loss = 0.3793 Training-Accuracy = 0.6207093298435211 Validation-Accuracy = 0.8921568627450981
# Epoch [ 363 / 5000 ] Training-Loss = 0.3793 Training-Accuracy = 0.620714545249939 Validation-Accuracy = 0.8921568627450981
# Epoch [ 364 / 5000 ] Training-Loss = 0.3793 Training-Accuracy = 0.6207194328308105 Validation-Accuracy = 0.8921568627450981
# Epoch [ 365 / 5000 ] Training-Loss = 0.3793 Training-Accuracy = 0.6207244098186493 Validation-Accuracy = 0.8921568627450981
# Epoch [ 366 / 5000 ] Training-Loss = 0.3793 Training-Accuracy = 0.6207297742366791 Validation-Accuracy = 0.8921568627450981
# Epoch [ 367 / 5000 ] Training-Loss = 0.3793 Training-Accuracy = 0.6207349300384521 Validation-Accuracy = 0.8921568627450981
# Epoch [ 368 / 5000 ] Training-Loss = 0.3793 Training-Accuracy = 0.6207394003868103 Validation-Accuracy = 0.8921568627450981
# Epoch [ 369 / 5000 ] Training-Loss = 0.3793 Training-Accuracy = 0.6207446455955505 Validation-Accuracy = 0.8921568627450981
# Epoch [ 370 / 5000 ] Training-Loss = 0.3793 Training-Accuracy = 0.6207497417926788 Validation-Accuracy = 0.8921568627450981
# Epoch [ 371 / 5000 ] Training-Loss = 0.3792 Training-Accuracy = 0.6207549571990967 Validation-Accuracy = 0.8921568627450981
# Epoch [ 372 / 5000 ] Training-Loss = 0.3792 Training-Accuracy = 0.620759904384613 Validation-Accuracy = 0.8921568627450981
# Epoch [ 373 / 5000 ] Training-Loss = 0.3792 Training-Accuracy = 0.6207647919654846 Validation-Accuracy = 0.8921568627450981
# Epoch [ 374 / 5000 ] Training-Loss = 0.3792 Training-Accuracy = 0.6207694411277771 Validation-Accuracy = 0.8921568627450981
# Epoch [ 375 / 5000 ] Training-Loss = 0.3792 Training-Accuracy = 0.6207746267318726 Validation-Accuracy = 0.8921568627450981
# Epoch [ 376 / 5000 ] Training-Loss = 0.3792 Training-Accuracy = 0.6207794547080994 Validation-Accuracy = 0.8921568627450981
# Epoch [ 377 / 5000 ] Training-Loss = 0.3792 Training-Accuracy = 0.6207842826843262 Validation-Accuracy = 0.8921568627450981
# Epoch [ 378 / 5000 ] Training-Loss = 0.3792 Training-Accuracy = 0.6207893490791321 Validation-Accuracy = 0.8921568627450981
# Epoch [ 379 / 5000 ] Training-Loss = 0.3792 Training-Accuracy = 0.6207939684391022 Validation-Accuracy = 0.8921568627450981
# Epoch [ 380 / 5000 ] Training-Loss = 0.3792 Training-Accuracy = 0.6207988560199738 Validation-Accuracy = 0.8921568627450981
# Epoch [ 381 / 5000 ] Training-Loss = 0.3792 Training-Accuracy = 0.6208038032054901 Validation-Accuracy = 0.8921568627450981
# Epoch [ 382 / 5000 ] Training-Loss = 0.3792 Training-Accuracy = 0.6208086311817169 Validation-Accuracy = 0.8921568627450981
# Epoch [ 383 / 5000 ] Training-Loss = 0.3792 Training-Accuracy = 0.6208131909370422 Validation-Accuracy = 0.8921568627450981
# Epoch [ 384 / 5000 ] Training-Loss = 0.3792 Training-Accuracy = 0.6208181083202362 Validation-Accuracy = 0.8921568627450981
# Epoch [ 385 / 5000 ] Training-Loss = 0.3792 Training-Accuracy = 0.6208231151103973 Validation-Accuracy = 0.8921568627450981
# Epoch [ 386 / 5000 ] Training-Loss = 0.3792 Training-Accuracy = 0.6208276152610779 Validation-Accuracy = 0.8921568627450981
# Epoch [ 387 / 5000 ] Training-Loss = 0.3792 Training-Accuracy = 0.6208326816558838 Validation-Accuracy = 0.8921568627450981
# Epoch [ 388 / 5000 ] Training-Loss = 0.3792 Training-Accuracy = 0.6208371520042419 Validation-Accuracy = 0.8921568627450981
# ...
# Epoch [ 4873 / 5000 ] Training-Loss = 0.3603 Training-Accuracy = 0.6397010982036591 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4874 / 5000 ] Training-Loss = 0.3597 Training-Accuracy = 0.6403270363807678 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4875 / 5000 ] Training-Loss = 0.3592 Training-Accuracy = 0.64080411195755 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4876 / 5000 ] Training-Loss = 0.3593 Training-Accuracy = 0.6406782865524292 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4877 / 5000 ] Training-Loss = 0.3593 Training-Accuracy = 0.6406539082527161 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4878 / 5000 ] Training-Loss = 0.3591 Training-Accuracy = 0.6409331858158112 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4879 / 5000 ] Training-Loss = 0.3590 Training-Accuracy = 0.6410422623157501 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4880 / 5000 ] Training-Loss = 0.3591 Training-Accuracy = 0.6409080922603607 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4881 / 5000 ] Training-Loss = 0.3591 Training-Accuracy = 0.6409107744693756 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4882 / 5000 ] Training-Loss = 0.3587 Training-Accuracy = 0.6413297653198242 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4883 / 5000 ] Training-Loss = 0.3587 Training-Accuracy = 0.6413022577762604 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4884 / 5000 ] Training-Loss = 0.3584 Training-Accuracy = 0.641550749540329 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4885 / 5000 ] Training-Loss = 0.3583 Training-Accuracy = 0.6417120695114136 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4886 / 5000 ] Training-Loss = 0.3579 Training-Accuracy = 0.6421083807945251 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4887 / 5000 ] Training-Loss = 0.3577 Training-Accuracy = 0.6422888338565826 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4888 / 5000 ] Training-Loss = 0.3575 Training-Accuracy = 0.6424938440322876 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4889 / 5000 ] Training-Loss = 0.3571 Training-Accuracy = 0.6428510546684265 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4890 / 5000 ] Training-Loss = 0.3570 Training-Accuracy = 0.6429610252380371 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4891 / 5000 ] Training-Loss = 0.3569 Training-Accuracy = 0.6430561542510986 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4892 / 5000 ] Training-Loss = 0.3569 Training-Accuracy = 0.6431487500667572 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4893 / 5000 ] Training-Loss = 0.3567 Training-Accuracy = 0.6433381140232086 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4894 / 5000 ] Training-Loss = 0.3565 Training-Accuracy = 0.6434700787067413 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4895 / 5000 ] Training-Loss = 0.3566 Training-Accuracy = 0.6433624029159546 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4896 / 5000 ] Training-Loss = 0.3565 Training-Accuracy = 0.6435478031635284 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4897 / 5000 ] Training-Loss = 0.3562 Training-Accuracy = 0.6437524557113647 Validation-Accuracy = 0.8986928104575164
# Epoch [ 4898 / 5000 ] Training-Loss = 0.3564 Training-Accuracy = 0.6435563862323761 Validation-Accuracy = 0.8986928104575164
# Epoch [ 4899 / 5000 ] Training-Loss = 0.3567 Training-Accuracy = 0.6432836651802063 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4900 / 5000 ] Training-Loss = 0.3565 Training-Accuracy = 0.643510639667511 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4901 / 5000 ] Training-Loss = 0.3562 Training-Accuracy = 0.6438055634498596 Validation-Accuracy = 0.8986928104575164
# Epoch [ 4902 / 5000 ] Training-Loss = 0.3565 Training-Accuracy = 0.6435092091560364 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4903 / 5000 ] Training-Loss = 0.3564 Training-Accuracy = 0.6436492502689362 Validation-Accuracy = 0.8986928104575164
# Epoch [ 4904 / 5000 ] Training-Loss = 0.3561 Training-Accuracy = 0.6439007818698883 Validation-Accuracy = 0.8986928104575164
# Epoch [ 4905 / 5000 ] Training-Loss = 0.3563 Training-Accuracy = 0.6436503529548645 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4906 / 5000 ] Training-Loss = 0.3565 Training-Accuracy = 0.6434831619262695 Validation-Accuracy = 0.8986928104575164
# Epoch [ 4907 / 5000 ] Training-Loss = 0.3560 Training-Accuracy = 0.6439656615257263 Validation-Accuracy = 0.8986928104575164
# Epoch [ 4908 / 5000 ] Training-Loss = 0.3560 Training-Accuracy = 0.6440154910087585 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4909 / 5000 ] Training-Loss = 0.3563 Training-Accuracy = 0.6437073647975922 Validation-Accuracy = 0.8986928104575164
# Epoch [ 4910 / 5000 ] Training-Loss = 0.3561 Training-Accuracy = 0.643878698348999 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4911 / 5000 ] Training-Loss = 0.3561 Training-Accuracy = 0.6439425051212311 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4912 / 5000 ] Training-Loss = 0.3558 Training-Accuracy = 0.6441705226898193 Validation-Accuracy = 0.8986928104575164
# Epoch [ 4913 / 5000 ] Training-Loss = 0.3563 Training-Accuracy = 0.6436809003353119 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4914 / 5000 ] Training-Loss = 0.3573 Training-Accuracy = 0.6427316069602966 Validation-Accuracy = 0.8986928104575164
# Epoch [ 4915 / 5000 ] Training-Loss = 0.3558 Training-Accuracy = 0.6441973447799683 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4916 / 5000 ] Training-Loss = 0.3596 Training-Accuracy = 0.6404153406620026 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4917 / 5000 ] Training-Loss = 0.3630 Training-Accuracy = 0.6369856894016266 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4918 / 5000 ] Training-Loss = 0.3647 Training-Accuracy = 0.6353414058685303 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4919 / 5000 ] Training-Loss = 0.3561 Training-Accuracy = 0.6439125537872314 Validation-Accuracy = 0.8986928104575164
# Epoch [ 4920 / 5000 ] Training-Loss = 0.3755 Training-Accuracy = 0.6245034635066986 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4921 / 5000 ] Training-Loss = 0.3670 Training-Accuracy = 0.633040577173233 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4922 / 5000 ] Training-Loss = 0.3811 Training-Accuracy = 0.6188876628875732 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4923 / 5000 ] Training-Loss = 0.3689 Training-Accuracy = 0.6310510635375977 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4924 / 5000 ] Training-Loss = 0.3591 Training-Accuracy = 0.6409189999103546 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4925 / 5000 ] Training-Loss = 0.3768 Training-Accuracy = 0.6232387721538544 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4926 / 5000 ] Training-Loss = 0.3598 Training-Accuracy = 0.6401731669902802 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4927 / 5000 ] Training-Loss = 0.3699 Training-Accuracy = 0.6301379799842834 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4928 / 5000 ] Training-Loss = 0.3713 Training-Accuracy = 0.6287165880203247 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4929 / 5000 ] Training-Loss = 0.3620 Training-Accuracy = 0.6380111277103424 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4930 / 5000 ] Training-Loss = 0.3618 Training-Accuracy = 0.6382497251033783 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4931 / 5000 ] Training-Loss = 0.3684 Training-Accuracy = 0.6316308379173279 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4932 / 5000 ] Training-Loss = 0.3633 Training-Accuracy = 0.6366690993309021 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4933 / 5000 ] Training-Loss = 0.3604 Training-Accuracy = 0.6395664215087891 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4934 / 5000 ] Training-Loss = 0.3649 Training-Accuracy = 0.6351455748081207 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4935 / 5000 ] Training-Loss = 0.3655 Training-Accuracy = 0.6345178484916687 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4936 / 5000 ] Training-Loss = 0.3610 Training-Accuracy = 0.6390455663204193 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4937 / 5000 ] Training-Loss = 0.3613 Training-Accuracy = 0.6387152075767517 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4938 / 5000 ] Training-Loss = 0.3640 Training-Accuracy = 0.6359723210334778 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4939 / 5000 ] Training-Loss = 0.3618 Training-Accuracy = 0.6381599009037018 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4940 / 5000 ] Training-Loss = 0.3604 Training-Accuracy = 0.6396430432796478 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4941 / 5000 ] Training-Loss = 0.3626 Training-Accuracy = 0.6373599171638489 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4942 / 5000 ] Training-Loss = 0.3630 Training-Accuracy = 0.6370404064655304 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4943 / 5000 ] Training-Loss = 0.3606 Training-Accuracy = 0.6394310295581818 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4944 / 5000 ] Training-Loss = 0.3605 Training-Accuracy = 0.6395059823989868 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4945 / 5000 ] Training-Loss = 0.3620 Training-Accuracy = 0.6380167007446289 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4946 / 5000 ] Training-Loss = 0.3606 Training-Accuracy = 0.6393710970878601 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4947 / 5000 ] Training-Loss = 0.3597 Training-Accuracy = 0.6403124332427979 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4948 / 5000 ] Training-Loss = 0.3597 Training-Accuracy = 0.6402685344219208 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4949 / 5000 ] Training-Loss = 0.3605 Training-Accuracy = 0.6394906938076019 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4950 / 5000 ] Training-Loss = 0.3604 Training-Accuracy = 0.6396111249923706 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4951 / 5000 ] Training-Loss = 0.3593 Training-Accuracy = 0.6406919062137604 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4952 / 5000 ] Training-Loss = 0.3592 Training-Accuracy = 0.640849232673645 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4953 / 5000 ] Training-Loss = 0.3596 Training-Accuracy = 0.6403948664665222 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4954 / 5000 ] Training-Loss = 0.3596 Training-Accuracy = 0.640431135892868 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4955 / 5000 ] Training-Loss = 0.3590 Training-Accuracy = 0.6410475969314575 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4956 / 5000 ] Training-Loss = 0.3588 Training-Accuracy = 0.6412318646907806 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4957 / 5000 ] Training-Loss = 0.3589 Training-Accuracy = 0.641143411397934 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4958 / 5000 ] Training-Loss = 0.3587 Training-Accuracy = 0.6412702798843384 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4959 / 5000 ] Training-Loss = 0.3585 Training-Accuracy = 0.6414547860622406 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4960 / 5000 ] Training-Loss = 0.3583 Training-Accuracy = 0.6417052447795868 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4961 / 5000 ] Training-Loss = 0.3582 Training-Accuracy = 0.641811728477478 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4962 / 5000 ] Training-Loss = 0.3581 Training-Accuracy = 0.6419329643249512 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4963 / 5000 ] Training-Loss = 0.3579 Training-Accuracy = 0.6420983970165253 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4964 / 5000 ] Training-Loss = 0.3576 Training-Accuracy = 0.6424174010753632 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4965 / 5000 ] Training-Loss = 0.3573 Training-Accuracy = 0.6427356600761414 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4966 / 5000 ] Training-Loss = 0.3571 Training-Accuracy = 0.6428884565830231 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4967 / 5000 ] Training-Loss = 0.3570 Training-Accuracy = 0.6430339813232422 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4968 / 5000 ] Training-Loss = 0.3567 Training-Accuracy = 0.6432870924472809 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4969 / 5000 ] Training-Loss = 0.3566 Training-Accuracy = 0.6433687210083008 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4970 / 5000 ] Training-Loss = 0.3566 Training-Accuracy = 0.6433683931827545 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4971 / 5000 ] Training-Loss = 0.3565 Training-Accuracy = 0.6435408294200897 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4972 / 5000 ] Training-Loss = 0.3564 Training-Accuracy = 0.6435572504997253 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4973 / 5000 ] Training-Loss = 0.3562 Training-Accuracy = 0.6438179910182953 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4974 / 5000 ] Training-Loss = 0.3561 Training-Accuracy = 0.6438623070716858 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4975 / 5000 ] Training-Loss = 0.3563 Training-Accuracy = 0.6436643004417419 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4976 / 5000 ] Training-Loss = 0.3567 Training-Accuracy = 0.6433115005493164 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4977 / 5000 ] Training-Loss = 0.3563 Training-Accuracy = 0.6436515748500824 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4978 / 5000 ] Training-Loss = 0.3561 Training-Accuracy = 0.643930047750473 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4979 / 5000 ] Training-Loss = 0.3566 Training-Accuracy = 0.6434021890163422 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4980 / 5000 ] Training-Loss = 0.3560 Training-Accuracy = 0.6440109312534332 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4981 / 5000 ] Training-Loss = 0.3561 Training-Accuracy = 0.6439324021339417 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4982 / 5000 ] Training-Loss = 0.3562 Training-Accuracy = 0.6438279747962952 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4983 / 5000 ] Training-Loss = 0.3560 Training-Accuracy = 0.644047737121582 Validation-Accuracy = 0.8986928104575164
# Epoch [ 4984 / 5000 ] Training-Loss = 0.3558 Training-Accuracy = 0.644184023141861 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4985 / 5000 ] Training-Loss = 0.3557 Training-Accuracy = 0.6442677676677704 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4986 / 5000 ] Training-Loss = 0.3557 Training-Accuracy = 0.6443234384059906 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4987 / 5000 ] Training-Loss = 0.3556 Training-Accuracy = 0.6443893611431122 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4988 / 5000 ] Training-Loss = 0.3557 Training-Accuracy = 0.6442521512508392 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4989 / 5000 ] Training-Loss = 0.3568 Training-Accuracy = 0.6431731581687927 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4990 / 5000 ] Training-Loss = 0.3566 Training-Accuracy = 0.6433579325675964 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4991 / 5000 ] Training-Loss = 0.3570 Training-Accuracy = 0.6429873704910278 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4992 / 5000 ] Training-Loss = 0.3558 Training-Accuracy = 0.6442158818244934 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4993 / 5000 ] Training-Loss = 0.3576 Training-Accuracy = 0.6423617601394653 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4994 / 5000 ] Training-Loss = 0.3598 Training-Accuracy = 0.6401565372943878 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4995 / 5000 ] Training-Loss = 0.3587 Training-Accuracy = 0.6412897408008575 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4996 / 5000 ] Training-Loss = 0.3608 Training-Accuracy = 0.6392470300197601 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4997 / 5000 ] Training-Loss = 0.3592 Training-Accuracy = 0.6408279240131378 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4998 / 5000 ] Training-Loss = 0.3606 Training-Accuracy = 0.6393716335296631 Validation-Accuracy = 0.8954248366013072
# Epoch [ 4999 / 5000 ] Training-Loss = 0.3560 Training-Accuracy = 0.6439967155456543 Validation-Accuracy = 0.8954248366013072
# Epoch [ 5000 / 5000 ] Training-Loss = 0.3632 Training-Accuracy = 0.636797308921814 Validation-Accuracy = 0.8954248366013072

# %%
print("Maximum Training Accuracy = ", max(training_acc_list))
print("Maximum Validation Accuracy = ",max(val_acc_list) )
model = model_list[training_acc_list.index(max(training_acc_list))]
# Out:
# Maximum Training Accuracy =  0.6443893611431122
# Maximum Validation Accuracy =  0.8986928104575164

# %%
predicted = model(x_train).to(device)
predicted = torch.max(predicted.data,1)[1]
confusionMatrixPrint(predicted.to('cpu').numpy(),y_train.to('cpu').numpy(),0)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Train Data :
#          True Positive =  4            True Negetive =  157
#         False Positive =  3           False Negetive =  1057
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 1221
#
# Accuracy  :  0.868959868959869
# Precision :  0.5714285714285714
# Recall    :  0.024844720496894408
# F1 Score  :  0.047619047619047616
#
# ------------------------------------------------------------------------------------

# %%
predicted = model(x_test).to(device)
predicted = torch.max(predicted.data,1)[1]
confusionMatrixPrint(predicted.to('cpu').numpy(),y_test.to('cpu').numpy(),1)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Validation Data
#
#          True Positive =  2            True Negetive =  31
#         False Positive =  1           False Negetive =  272
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 306
#
# Accuracy  :  0.8954248366013072
# Precision :  0.6666666666666666
# Recall    :  0.06060606060606061
# F1 Score  :  0.1111111111111111
#
# ------------------------------------------------------------------------------------

# %%
torch.save(model,"saved_model/temporal_nn.pt")
