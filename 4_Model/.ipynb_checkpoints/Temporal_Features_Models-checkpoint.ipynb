# %% [markdown]
# # Models on Temporal Features
# ## Data Preparation

# %%
from Classifier import get_KNN_Model, get_accuracy_matric, get_lin_SVM_Model, get_NaiveBayes_Model
from Hawkes_Process import get_topic_vector
from Topic_Modelling import LDA_main_driver
from filters import train_test_splitter
import numpy as np
import warnings

warnings.simplefilter(action='ignore')

# %%
df, dict_genuine, dict_fake, lda_genuine, lda_fake = LDA_main_driver()
num_topics = 10
# Out:
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-* LDA Training Started -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
#
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-* LDA Training Ended -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*

# %%
user_topic_vectors, labels = get_topic_vector(df, dict_genuine, dict_fake, lda_genuine, lda_fake, 1)
# Out:
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-* Hawkes Process Started -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
#
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-* Hawkes Process Ended -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*

# %%
total_len = len(user_topic_vectors)
X = np.array(user_topic_vectors)
Y = np.array(labels)

# %%
hawkes_ops = X[:,[20,21]]

# %%
hawkes_ops.shape, Y.shape
# Out:
# ((1527, 2), (1527,))

# %%
x_train, x_test, y_train, y_test = train_test_splitter(hawkes_ops, Y)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((1221, 2), (1221,), (306, 2), (306,))

# %%
def confusionMatrixPrint(P,Y,dataType):
    TF = 0
    TT = 0
    FF = 0
    FT = 0
    for p,y in zip(P,Y):
        if (p,y) == (0,0):
            FF += 1
        elif (p,y) == (1,1):
            TT += 1
        elif (p,y) == (0,1):
            TF += 1
        else:
            FT += 1

    print('------------------------------------------------------------------------------------\n')
    if dataType == 0:
        print("  Confusion Matrix for Train Data : ")
    else:
        print("  Confusion Matrix for Validation Data \n")
    print("         True Positive = ",TT,"           True Negetive = ",TF)
    print("        False Positive = ",FT,"          False Negetive = ",FF)
    print('\n------------------------------------------------------------------------------------\n')
    total = TT+FF+TF+FT
    print(f"  Total Cases : {total}\n")
    print("Accuracy  : ",(TT+FF)/total)
    try:
        prec = (TT)/(TT+FT)
        recall = (TT)/(TT+TF)
        f = (2*recall*prec)/(recall+prec)
        print("Precision : ",prec)
        print("Recall    : ",recall)
        print("F1 Score  : ",f)
    except:
        pass
    
    
    print('\n------------------------------------------------------------------------------------')

# %% [markdown]
# # 1. KNN Classifier on Intensity Function Value And Adj_matrix Value

# %%
knn = get_KNN_Model(x_train, y_train)

# %%
pred = knn.predict(x_train)
confusionMatrixPrint(pred,y_train,0)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Train Data :
#          True Positive =  12            True Negetive =  149
#         False Positive =  14           False Negetive =  1046
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 1221
#
# Accuracy  :  0.8665028665028665
# Precision :  0.46153846153846156
# Recall    :  0.07453416149068323
# F1 Score  :  0.1283422459893048
#
# ------------------------------------------------------------------------------------

# %%
pred = knn.predict(x_test)
confusionMatrixPrint(pred,y_test,1)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Validation Data
#
#          True Positive =  3            True Negetive =  30
#         False Positive =  5           False Negetive =  268
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 306
#
# Accuracy  :  0.8856209150326797
# Precision :  0.375
# Recall    :  0.09090909090909091
# F1 Score  :  0.14634146341463414
#
# ------------------------------------------------------------------------------------

# %% [markdown]
# # 2. SVM Classifier on Intensity Function Value And Adj_matrix Value

# %%
svm = get_lin_SVM_Model(x_train, y_train)

# %%
pred = svm.predict(x_train)
confusionMatrixPrint(pred,y_train,0)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Train Data :
#          True Positive =  0            True Negetive =  161
#         False Positive =  0           False Negetive =  1060
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 1221
#
# Accuracy  :  0.8681408681408681
#
# ------------------------------------------------------------------------------------

# %%
pred = svm.predict(x_test)
confusionMatrixPrint(pred,y_test,1)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Validation Data
#
#          True Positive =  0            True Negetive =  33
#         False Positive =  0           False Negetive =  273
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 306
#
# Accuracy  :  0.8921568627450981
#
# ------------------------------------------------------------------------------------

# %% [markdown]
# # 3. Naive Bayes Classifier on Intensity Function Value And Adj_matrix Value

# %%
nb = get_NaiveBayes_Model(x_train, y_train)

# %%
pred = nb.predict(x_train)
confusionMatrixPrint(pred,y_train,0)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Train Data :
#          True Positive =  0            True Negetive =  161
#         False Positive =  0           False Negetive =  1060
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 1221
#
# Accuracy  :  0.8681408681408681
#
# ------------------------------------------------------------------------------------

# %%
pred = nb.predict(x_test)
confusionMatrixPrint(pred,y_test,1)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Validation Data
#
#          True Positive =  0            True Negetive =  33
#         False Positive =  0           False Negetive =  273
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 306
#
# Accuracy  :  0.8921568627450981
#
# ------------------------------------------------------------------------------------

# %% [markdown]
# # 4. Nueral Network Based Classifier on Hawkes Process Output
#
# ## Fully Connected Network of :
#      - Input Layer : 2, 64
#      - Hidden Layer 1 : 64 , 128
#      - Hidden Layer 2 : 128 , 256
#      - Hidden Layer 3 : 256 , 512
#      - Hidden Layer 4 : 512 , 256
#      - Hidden Layer 5 : 256 , 128
#      - Hidden Layer 6 : 128 , 64
#      - Hidden Layer 7 : 64 , 32
#      - Hidden Layer 8 : 32 , 16
#      - Output Layer : 16 , 2

# %%
import torch.nn as nn
import warnings
import torch

# %%
def get_Device():
    return torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device = get_Device()
print(device)
# Out:
# cuda

# %%
x_train = torch.Tensor(x_train).to(device)
y_train = torch.Tensor(y_train).to(device)
x_test = torch.Tensor(x_test).to(device)
y_test = torch.Tensor(y_test).to(device)

# %%
y_train = y_train.to(torch.long)

# %%
class TemporalClassifierModel(nn.Module):
    def __init__(self, input_size, output_size):
        super(TemporalClassifierModel, self).__init__()
        self.layer1 = nn.Linear(input_size, 64)
        self.layer2 = nn.Linear(64, 128)
        self.layer3 = nn.Linear(128, 256)
        self.layer4 = nn.Linear(256, 512)
        self.layer5 = nn.Linear(512, 256)
        
        self.layer6 = nn.Linear(256, 128)
        self.layer7 = nn.Linear(128, 64)
        self.layer8 = nn.Linear(64, 32)
        self.layer9 = nn.Linear(32, 16)
        self.layer10 = nn.Linear(16, output_size)
        self.relu = nn.ReLU()
        

    def forward(self, inputs):
        out = self.layer1(inputs)
        out = self.relu(out)
        
#         out = self.layer2(out)
#         out = self.relu(out)
        
#         out = self.layer3(out)
#         out = self.relu(out)
        
#         out = self.layer4(out)
#         out = self.relu(out)
        
#         out = self.layer5(out)
#         out = self.relu(out)
        
#         out = self.layer6(out)
#         out = self.relu(out)
        
#         out = self.layer7(out)
#         out = self.relu(out)
        
#         out = self.layer8(out)
#         out = self.relu(out)
        
#         out = self.layer9(out)
#         out = self.relu(out)
        
        out = self.layer10(out)
        
        return out

# %%
input_size = 2
output_size = 2
hidden_size = 80
learning_rate = 0.0001
n_epochs = 5000

# %%
model = TemporalClassifierModel(input_size=input_size,
                                     output_size=output_size)
model.to(device)
# Out:
# TemporalClassifierModel(
#   (layer1): Linear(in_features=2, out_features=16, bias=True)
#   (layer10): Linear(in_features=16, out_features=2, bias=True)
#   (relu): ReLU()
# )

# %%
lossfn = torch.nn.CrossEntropyLoss()
lossfn.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def Validator(x_test, y_test):
    predicted = model(x_test).to(device)
    pred = torch.max(predicted.data,1)[1]
    total_test = len(y_test)
    correct_pred = 0

    for i in range(total_test):
        if y_test[i] == pred[i]:
            correct_pred += 1

    return correct_pred/total_test

# %%
val_acc_list = []
training_acc_list = []
model_list = []

for epoch in range(n_epochs):

    predicted = model(x_train).to(device)    

    loss = lossfn(predicted,y_train)
        
    optimizer.zero_grad()
    loss.backward()
    
    optimizer.step()
    
    val_acc = Validator(x_test, y_test.to(torch.int))
    
    print(f'Epoch [ {epoch+1} / {n_epochs} ] Training-Loss = {loss.item():.4f} Training-Accuracy = {1- loss.item()} Validation-Accuracy = {val_acc}')
    
    training_acc_list.append(1-loss.item())
    val_acc_list.append(val_acc)
    model_list.append(model)
# Out:
# Epoch [ 1 / 5000 ] Training-Loss = 1.2153 Training-Accuracy = -0.21526730060577393 Validation-Accuracy = 0.12091503267973856
# Epoch [ 2 / 5000 ] Training-Loss = 1.2104 Training-Accuracy = -0.2103559970855713 Validation-Accuracy = 0.12418300653594772
# Epoch [ 3 / 5000 ] Training-Loss = 1.2055 Training-Accuracy = -0.2054579257965088 Validation-Accuracy = 0.12418300653594772
# Epoch [ 4 / 5000 ] Training-Loss = 1.2006 Training-Accuracy = -0.20057296752929688 Validation-Accuracy = 0.12418300653594772
# Epoch [ 5 / 5000 ] Training-Loss = 1.1957 Training-Accuracy = -0.1957019567489624 Validation-Accuracy = 0.12418300653594772
# Epoch [ 6 / 5000 ] Training-Loss = 1.1908 Training-Accuracy = -0.19084489345550537 Validation-Accuracy = 0.12418300653594772
# Epoch [ 7 / 5000 ] Training-Loss = 1.1860 Training-Accuracy = -0.18600201606750488 Validation-Accuracy = 0.12418300653594772
# Epoch [ 8 / 5000 ] Training-Loss = 1.1812 Training-Accuracy = -0.1811736822128296 Validation-Accuracy = 0.12418300653594772
# Epoch [ 9 / 5000 ] Training-Loss = 1.1764 Training-Accuracy = -0.1763596534729004 Validation-Accuracy = 0.12418300653594772
# Epoch [ 10 / 5000 ] Training-Loss = 1.1716 Training-Accuracy = -0.17156100273132324 Validation-Accuracy = 0.12418300653594772
# Epoch [ 11 / 5000 ] Training-Loss = 1.1668 Training-Accuracy = -0.16677701473236084 Validation-Accuracy = 0.12418300653594772
# Epoch [ 12 / 5000 ] Training-Loss = 1.1620 Training-Accuracy = -0.1620088815689087 Validation-Accuracy = 0.12418300653594772
# Epoch [ 13 / 5000 ] Training-Loss = 1.1573 Training-Accuracy = -0.1572563648223877 Validation-Accuracy = 0.12418300653594772
# Epoch [ 14 / 5000 ] Training-Loss = 1.1525 Training-Accuracy = -0.1525193452835083 Validation-Accuracy = 0.12745098039215685
# Epoch [ 15 / 5000 ] Training-Loss = 1.1478 Training-Accuracy = -0.14779901504516602 Validation-Accuracy = 0.12745098039215685
# Epoch [ 16 / 5000 ] Training-Loss = 1.1431 Training-Accuracy = -0.14309453964233398 Validation-Accuracy = 0.12745098039215685
# Epoch [ 17 / 5000 ] Training-Loss = 1.1384 Training-Accuracy = -0.1384068727493286 Validation-Accuracy = 0.12745098039215685
# Epoch [ 18 / 5000 ] Training-Loss = 1.1337 Training-Accuracy = -0.1337357759475708 Validation-Accuracy = 0.12745098039215685
# Epoch [ 19 / 5000 ] Training-Loss = 1.1291 Training-Accuracy = -0.12908196449279785 Validation-Accuracy = 0.12745098039215685
# Epoch [ 20 / 5000 ] Training-Loss = 1.1244 Training-Accuracy = -0.12444508075714111 Validation-Accuracy = 0.12745098039215685
# Epoch [ 21 / 5000 ] Training-Loss = 1.1198 Training-Accuracy = -0.11982560157775879 Validation-Accuracy = 0.12745098039215685
# Epoch [ 22 / 5000 ] Training-Loss = 1.1152 Training-Accuracy = -0.11522316932678223 Validation-Accuracy = 0.13071895424836602
# Epoch [ 23 / 5000 ] Training-Loss = 1.1106 Training-Accuracy = -0.11063897609710693 Validation-Accuracy = 0.13071895424836602
# Epoch [ 24 / 5000 ] Training-Loss = 1.1061 Training-Accuracy = -0.1060720682144165 Validation-Accuracy = 0.13071895424836602
# Epoch [ 25 / 5000 ] Training-Loss = 1.1015 Training-Accuracy = -0.10152328014373779 Validation-Accuracy = 0.13071895424836602
# Epoch [ 26 / 5000 ] Training-Loss = 1.0970 Training-Accuracy = -0.09699296951293945 Validation-Accuracy = 0.13071895424836602
# Epoch [ 27 / 5000 ] Training-Loss = 1.0925 Training-Accuracy = -0.09248065948486328 Validation-Accuracy = 0.13071895424836602
# Epoch [ 28 / 5000 ] Training-Loss = 1.0880 Training-Accuracy = -0.08798694610595703 Validation-Accuracy = 0.13071895424836602
# Epoch [ 29 / 5000 ] Training-Loss = 1.0835 Training-Accuracy = -0.08351123332977295 Validation-Accuracy = 0.13071895424836602
# Epoch [ 30 / 5000 ] Training-Loss = 1.0791 Training-Accuracy = -0.0790548324584961 Validation-Accuracy = 0.13071895424836602
# Epoch [ 31 / 5000 ] Training-Loss = 1.0746 Training-Accuracy = -0.07461690902709961 Validation-Accuracy = 0.13071895424836602
# Epoch [ 32 / 5000 ] Training-Loss = 1.0702 Training-Accuracy = -0.0701979398727417 Validation-Accuracy = 0.13071895424836602
# Epoch [ 33 / 5000 ] Training-Loss = 1.0658 Training-Accuracy = -0.06579804420471191 Validation-Accuracy = 0.13071895424836602
# Epoch [ 34 / 5000 ] Training-Loss = 1.0614 Training-Accuracy = -0.0614171028137207 Validation-Accuracy = 0.13071895424836602
# Epoch [ 35 / 5000 ] Training-Loss = 1.0571 Training-Accuracy = -0.057055115699768066 Validation-Accuracy = 0.13071895424836602
# Epoch [ 36 / 5000 ] Training-Loss = 1.0527 Training-Accuracy = -0.052712321281433105 Validation-Accuracy = 0.13071895424836602
# Epoch [ 37 / 5000 ] Training-Loss = 1.0484 Training-Accuracy = -0.04838895797729492 Validation-Accuracy = 0.13071895424836602
# Epoch [ 38 / 5000 ] Training-Loss = 1.0441 Training-Accuracy = -0.04408538341522217 Validation-Accuracy = 0.13071895424836602
# Epoch [ 39 / 5000 ] Training-Loss = 1.0398 Training-Accuracy = -0.03980076313018799 Validation-Accuracy = 0.13071895424836602
# Epoch [ 40 / 5000 ] Training-Loss = 1.0355 Training-Accuracy = -0.03553581237792969 Validation-Accuracy = 0.13071895424836602
# Epoch [ 41 / 5000 ] Training-Loss = 1.0313 Training-Accuracy = -0.031290531158447266 Validation-Accuracy = 0.13071895424836602
# Epoch [ 42 / 5000 ] Training-Loss = 1.0271 Training-Accuracy = -0.02706468105316162 Validation-Accuracy = 0.13071895424836602
# Epoch [ 43 / 5000 ] Training-Loss = 1.0229 Training-Accuracy = -0.022858381271362305 Validation-Accuracy = 0.13071895424836602
# Epoch [ 44 / 5000 ] Training-Loss = 1.0187 Training-Accuracy = -0.01867210865020752 Validation-Accuracy = 0.13071895424836602
# Epoch [ 45 / 5000 ] Training-Loss = 1.0145 Training-Accuracy = -0.014505505561828613 Validation-Accuracy = 0.13071895424836602
# Epoch [ 46 / 5000 ] Training-Loss = 1.0104 Training-Accuracy = -0.010358572006225586 Validation-Accuracy = 0.13071895424836602
# Epoch [ 47 / 5000 ] Training-Loss = 1.0062 Training-Accuracy = -0.006231546401977539 Validation-Accuracy = 0.13071895424836602
# Epoch [ 48 / 5000 ] Training-Loss = 1.0021 Training-Accuracy = -0.0021244287490844727 Validation-Accuracy = 0.13071895424836602
# Epoch [ 49 / 5000 ] Training-Loss = 0.9980 Training-Accuracy = 0.001962900161743164 Validation-Accuracy = 0.13071895424836602
# Epoch [ 50 / 5000 ] Training-Loss = 0.9940 Training-Accuracy = 0.006030261516571045 Validation-Accuracy = 0.13071895424836602
# Epoch [ 51 / 5000 ] Training-Loss = 0.9899 Training-Accuracy = 0.010077834129333496 Validation-Accuracy = 0.13071895424836602
# Epoch [ 52 / 5000 ] Training-Loss = 0.9859 Training-Accuracy = 0.014105141162872314 Validation-Accuracy = 0.13071895424836602
# Epoch [ 53 / 5000 ] Training-Loss = 0.9819 Training-Accuracy = 0.018112897872924805 Validation-Accuracy = 0.13071895424836602
# Epoch [ 54 / 5000 ] Training-Loss = 0.9779 Training-Accuracy = 0.022100508213043213 Validation-Accuracy = 0.13071895424836602
# Epoch [ 55 / 5000 ] Training-Loss = 0.9739 Training-Accuracy = 0.026068389415740967 Validation-Accuracy = 0.13071895424836602
# Epoch [ 56 / 5000 ] Training-Loss = 0.9700 Training-Accuracy = 0.030016005039215088 Validation-Accuracy = 0.13071895424836602
# Epoch [ 57 / 5000 ] Training-Loss = 0.9661 Training-Accuracy = 0.03394407033920288 Validation-Accuracy = 0.13398692810457516
# Epoch [ 58 / 5000 ] Training-Loss = 0.9621 Training-Accuracy = 0.03785187005996704 Validation-Accuracy = 0.14052287581699346
# Epoch [ 59 / 5000 ] Training-Loss = 0.9583 Training-Accuracy = 0.041739821434020996 Validation-Accuracy = 0.14052287581699346
# Epoch [ 60 / 5000 ] Training-Loss = 0.9544 Training-Accuracy = 0.045607805252075195 Validation-Accuracy = 0.14052287581699346
# Epoch [ 61 / 5000 ] Training-Loss = 0.9505 Training-Accuracy = 0.04945576190948486 Validation-Accuracy = 0.14052287581699346
# Epoch [ 62 / 5000 ] Training-Loss = 0.9467 Training-Accuracy = 0.053283751010894775 Validation-Accuracy = 0.14705882352941177
# Epoch [ 63 / 5000 ] Training-Loss = 0.9429 Training-Accuracy = 0.05709201097488403 Validation-Accuracy = 0.15359477124183007
# Epoch [ 64 / 5000 ] Training-Loss = 0.9391 Training-Accuracy = 0.06087988615036011 Validation-Accuracy = 0.15359477124183007
# Epoch [ 65 / 5000 ] Training-Loss = 0.9354 Training-Accuracy = 0.06464844942092896 Validation-Accuracy = 0.15359477124183007
# Epoch [ 66 / 5000 ] Training-Loss = 0.9316 Training-Accuracy = 0.0683966875076294 Validation-Accuracy = 0.1568627450980392
# Epoch [ 67 / 5000 ] Training-Loss = 0.9279 Training-Accuracy = 0.0721253752708435 Validation-Accuracy = 0.1568627450980392
# Epoch [ 68 / 5000 ] Training-Loss = 0.9242 Training-Accuracy = 0.07583385705947876 Validation-Accuracy = 0.1568627450980392
# Epoch [ 69 / 5000 ] Training-Loss = 0.9205 Training-Accuracy = 0.07952278852462769 Validation-Accuracy = 0.1568627450980392
# Epoch [ 70 / 5000 ] Training-Loss = 0.9168 Training-Accuracy = 0.08319199085235596 Validation-Accuracy = 0.1568627450980392
# Epoch [ 71 / 5000 ] Training-Loss = 0.9132 Training-Accuracy = 0.08684098720550537 Validation-Accuracy = 0.1568627450980392
# Epoch [ 72 / 5000 ] Training-Loss = 0.9095 Training-Accuracy = 0.09047061204910278 Validation-Accuracy = 0.1568627450980392
# Epoch [ 73 / 5000 ] Training-Loss = 0.9059 Training-Accuracy = 0.09408009052276611 Validation-Accuracy = 0.1568627450980392
# Epoch [ 74 / 5000 ] Training-Loss = 0.9023 Training-Accuracy = 0.09767013788223267 Validation-Accuracy = 0.1568627450980392
# Epoch [ 75 / 5000 ] Training-Loss = 0.8988 Training-Accuracy = 0.10124039649963379 Validation-Accuracy = 0.1568627450980392
# Epoch [ 76 / 5000 ] Training-Loss = 0.8952 Training-Accuracy = 0.10479110479354858 Validation-Accuracy = 0.1568627450980392
# Epoch [ 77 / 5000 ] Training-Loss = 0.8917 Training-Accuracy = 0.10832208395004272 Validation-Accuracy = 0.1568627450980392
# Epoch [ 78 / 5000 ] Training-Loss = 0.8882 Training-Accuracy = 0.11183339357376099 Validation-Accuracy = 0.1568627450980392
# Epoch [ 79 / 5000 ] Training-Loss = 0.8847 Training-Accuracy = 0.11532533168792725 Validation-Accuracy = 0.1568627450980392
# Epoch [ 80 / 5000 ] Training-Loss = 0.8812 Training-Accuracy = 0.11879771947860718 Validation-Accuracy = 0.1568627450980392
# Epoch [ 81 / 5000 ] Training-Loss = 0.8777 Training-Accuracy = 0.122250497341156 Validation-Accuracy = 0.1568627450980392
# Epoch [ 82 / 5000 ] Training-Loss = 0.8743 Training-Accuracy = 0.1256839632987976 Validation-Accuracy = 0.1568627450980392
# Epoch [ 83 / 5000 ] Training-Loss = 0.8709 Training-Accuracy = 0.12909787893295288 Validation-Accuracy = 0.1568627450980392
# Epoch [ 84 / 5000 ] Training-Loss = 0.8675 Training-Accuracy = 0.13249266147613525 Validation-Accuracy = 0.1568627450980392
# Epoch [ 85 / 5000 ] Training-Loss = 0.8641 Training-Accuracy = 0.13586807250976562 Validation-Accuracy = 0.1568627450980392
# Epoch [ 86 / 5000 ] Training-Loss = 0.8608 Training-Accuracy = 0.13922405242919922 Validation-Accuracy = 0.1568627450980392
# Epoch [ 87 / 5000 ] Training-Loss = 0.8574 Training-Accuracy = 0.14256083965301514 Validation-Accuracy = 0.1568627450980392
# Epoch [ 88 / 5000 ] Training-Loss = 0.8541 Training-Accuracy = 0.14587843418121338 Validation-Accuracy = 0.1568627450980392
# Epoch [ 89 / 5000 ] Training-Loss = 0.8508 Training-Accuracy = 0.1491767168045044 Validation-Accuracy = 0.1568627450980392
# Epoch [ 90 / 5000 ] Training-Loss = 0.8475 Training-Accuracy = 0.15245604515075684 Validation-Accuracy = 0.1568627450980392
# Epoch [ 91 / 5000 ] Training-Loss = 0.8443 Training-Accuracy = 0.15571624040603638 Validation-Accuracy = 0.1568627450980392
# Epoch [ 92 / 5000 ] Training-Loss = 0.8410 Training-Accuracy = 0.15895742177963257 Validation-Accuracy = 0.1568627450980392
# Epoch [ 93 / 5000 ] Training-Loss = 0.8378 Training-Accuracy = 0.1621795892715454 Validation-Accuracy = 0.1568627450980392
# Epoch [ 94 / 5000 ] Training-Loss = 0.8346 Training-Accuracy = 0.16538286209106445 Validation-Accuracy = 0.1568627450980392
# Epoch [ 95 / 5000 ] Training-Loss = 0.8314 Training-Accuracy = 0.16856718063354492 Validation-Accuracy = 0.1568627450980392
# Epoch [ 96 / 5000 ] Training-Loss = 0.8283 Training-Accuracy = 0.17173266410827637 Validation-Accuracy = 0.1568627450980392
# Epoch [ 97 / 5000 ] Training-Loss = 0.8251 Training-Accuracy = 0.17487943172454834 Validation-Accuracy = 0.1568627450980392
# Epoch [ 98 / 5000 ] Training-Loss = 0.8220 Training-Accuracy = 0.1780073642730713 Validation-Accuracy = 0.1568627450980392
# Epoch [ 99 / 5000 ] Training-Loss = 0.8189 Training-Accuracy = 0.18111670017242432 Validation-Accuracy = 0.1568627450980392
# Epoch [ 100 / 5000 ] Training-Loss = 0.8158 Training-Accuracy = 0.18420743942260742 Validation-Accuracy = 0.1568627450980392
# Epoch [ 101 / 5000 ] Training-Loss = 0.8127 Training-Accuracy = 0.18727922439575195 Validation-Accuracy = 0.1568627450980392
# Epoch [ 102 / 5000 ] Training-Loss = 0.8097 Training-Accuracy = 0.19033288955688477 Validation-Accuracy = 0.1568627450980392
# Epoch [ 103 / 5000 ] Training-Loss = 0.8066 Training-Accuracy = 0.19336795806884766 Validation-Accuracy = 0.1568627450980392
# Epoch [ 104 / 5000 ] Training-Loss = 0.8036 Training-Accuracy = 0.1963844895362854 Validation-Accuracy = 0.1568627450980392
# Epoch [ 105 / 5000 ] Training-Loss = 0.8006 Training-Accuracy = 0.19938284158706665 Validation-Accuracy = 0.1568627450980392
# Epoch [ 106 / 5000 ] Training-Loss = 0.7976 Training-Accuracy = 0.20236295461654663 Validation-Accuracy = 0.1568627450980392
# Epoch [ 107 / 5000 ] Training-Loss = 0.7947 Training-Accuracy = 0.20532476902008057 Validation-Accuracy = 0.1568627450980392
# Epoch [ 108 / 5000 ] Training-Loss = 0.7917 Training-Accuracy = 0.20826822519302368 Validation-Accuracy = 0.1568627450980392
# Epoch [ 109 / 5000 ] Training-Loss = 0.7888 Training-Accuracy = 0.21119362115859985 Validation-Accuracy = 0.1568627450980392
# Epoch [ 110 / 5000 ] Training-Loss = 0.7859 Training-Accuracy = 0.2141008973121643 Validation-Accuracy = 0.1568627450980392
# Epoch [ 111 / 5000 ] Training-Loss = 0.7830 Training-Accuracy = 0.21699011325836182 Validation-Accuracy = 0.1568627450980392
# Epoch [ 112 / 5000 ] Training-Loss = 0.7801 Training-Accuracy = 0.21986150741577148 Validation-Accuracy = 0.1568627450980392
# Epoch [ 113 / 5000 ] Training-Loss = 0.7773 Training-Accuracy = 0.22271490097045898 Validation-Accuracy = 0.1568627450980392
# Epoch [ 114 / 5000 ] Training-Loss = 0.7744 Training-Accuracy = 0.22555065155029297 Validation-Accuracy = 0.1568627450980392
# Epoch [ 115 / 5000 ] Training-Loss = 0.7716 Training-Accuracy = 0.22836834192276 Validation-Accuracy = 0.1568627450980392
# Epoch [ 116 / 5000 ] Training-Loss = 0.7688 Training-Accuracy = 0.23116838932037354 Validation-Accuracy = 0.1568627450980392
# Epoch [ 117 / 5000 ] Training-Loss = 0.7660 Training-Accuracy = 0.2339509129524231 Validation-Accuracy = 0.16013071895424835
# Epoch [ 118 / 5000 ] Training-Loss = 0.7633 Training-Accuracy = 0.23671573400497437 Validation-Accuracy = 0.16339869281045752
# Epoch [ 119 / 5000 ] Training-Loss = 0.7605 Training-Accuracy = 0.239463210105896 Validation-Accuracy = 0.16339869281045752
# Epoch [ 120 / 5000 ] Training-Loss = 0.7578 Training-Accuracy = 0.2421931028366089 Validation-Accuracy = 0.16339869281045752
# Epoch [ 121 / 5000 ] Training-Loss = 0.7551 Training-Accuracy = 0.24490571022033691 Validation-Accuracy = 0.16339869281045752
# Epoch [ 122 / 5000 ] Training-Loss = 0.7524 Training-Accuracy = 0.24760085344314575 Validation-Accuracy = 0.16339869281045752
# Epoch [ 123 / 5000 ] Training-Loss = 0.7497 Training-Accuracy = 0.2502787709236145 Validation-Accuracy = 0.16339869281045752
# Epoch [ 124 / 5000 ] Training-Loss = 0.7471 Training-Accuracy = 0.2529396414756775 Validation-Accuracy = 0.16339869281045752
# Epoch [ 125 / 5000 ] Training-Loss = 0.7444 Training-Accuracy = 0.2555834650993347 Validation-Accuracy = 0.16339869281045752
# Epoch [ 126 / 5000 ] Training-Loss = 0.7418 Training-Accuracy = 0.25821006298065186 Validation-Accuracy = 0.16666666666666666
# Epoch [ 127 / 5000 ] Training-Loss = 0.7392 Training-Accuracy = 0.26081961393356323 Validation-Accuracy = 0.16666666666666666
# Epoch [ 128 / 5000 ] Training-Loss = 0.7366 Training-Accuracy = 0.2634124159812927 Validation-Accuracy = 0.16666666666666666
# Epoch [ 129 / 5000 ] Training-Loss = 0.7340 Training-Accuracy = 0.265988290309906 Validation-Accuracy = 0.16666666666666666
# Epoch [ 130 / 5000 ] Training-Loss = 0.7315 Training-Accuracy = 0.2685474157333374 Validation-Accuracy = 0.16666666666666666
# Epoch [ 131 / 5000 ] Training-Loss = 0.7289 Training-Accuracy = 0.2710895538330078 Validation-Accuracy = 0.16339869281045752
# Epoch [ 132 / 5000 ] Training-Loss = 0.7264 Training-Accuracy = 0.27361541986465454 Validation-Accuracy = 0.16666666666666666
# Epoch [ 133 / 5000 ] Training-Loss = 0.7239 Training-Accuracy = 0.27612441778182983 Validation-Accuracy = 0.16666666666666666
# Epoch [ 134 / 5000 ] Training-Loss = 0.7214 Training-Accuracy = 0.2786172032356262 Validation-Accuracy = 0.16666666666666666
# Epoch [ 135 / 5000 ] Training-Loss = 0.7189 Training-Accuracy = 0.2810935378074646 Validation-Accuracy = 0.17320261437908496
# Epoch [ 136 / 5000 ] Training-Loss = 0.7164 Training-Accuracy = 0.2835536003112793 Validation-Accuracy = 0.17647058823529413
# Epoch [ 137 / 5000 ] Training-Loss = 0.7140 Training-Accuracy = 0.2859971523284912 Validation-Accuracy = 0.17973856209150327
# Epoch [ 138 / 5000 ] Training-Loss = 0.7116 Training-Accuracy = 0.288424551486969 Validation-Accuracy = 0.17973856209150327
# Epoch [ 139 / 5000 ] Training-Loss = 0.7092 Training-Accuracy = 0.290835976600647 Validation-Accuracy = 0.1830065359477124
# Epoch [ 140 / 5000 ] Training-Loss = 0.7068 Training-Accuracy = 0.2932314872741699 Validation-Accuracy = 0.19607843137254902
# Epoch [ 141 / 5000 ] Training-Loss = 0.7044 Training-Accuracy = 0.2956107258796692 Validation-Accuracy = 0.21241830065359477
# Epoch [ 142 / 5000 ] Training-Loss = 0.7020 Training-Accuracy = 0.2979740500450134 Validation-Accuracy = 0.23529411764705882
# Epoch [ 143 / 5000 ] Training-Loss = 0.6997 Training-Accuracy = 0.30032163858413696 Validation-Accuracy = 0.2679738562091503
# Epoch [ 144 / 5000 ] Training-Loss = 0.6973 Training-Accuracy = 0.3026534914970398 Validation-Accuracy = 0.2908496732026144
# Epoch [ 145 / 5000 ] Training-Loss = 0.6950 Training-Accuracy = 0.3049694895744324 Validation-Accuracy = 0.3202614379084967
# Epoch [ 146 / 5000 ] Training-Loss = 0.6927 Training-Accuracy = 0.3072701096534729 Validation-Accuracy = 0.3660130718954248
# Epoch [ 147 / 5000 ] Training-Loss = 0.6904 Training-Accuracy = 0.3095552325248718 Validation-Accuracy = 0.4019607843137255
# Epoch [ 148 / 5000 ] Training-Loss = 0.6882 Training-Accuracy = 0.3118246793746948 Validation-Accuracy = 0.43790849673202614
# Epoch [ 149 / 5000 ] Training-Loss = 0.6859 Training-Accuracy = 0.314078688621521 Validation-Accuracy = 0.46405228758169936
# Epoch [ 150 / 5000 ] Training-Loss = 0.6837 Training-Accuracy = 0.316317617893219 Validation-Accuracy = 0.5032679738562091
# Epoch [ 151 / 5000 ] Training-Loss = 0.6815 Training-Accuracy = 0.31854116916656494 Validation-Accuracy = 0.5326797385620915
# Epoch [ 152 / 5000 ] Training-Loss = 0.6793 Training-Accuracy = 0.3207494020462036 Validation-Accuracy = 0.5784313725490197
# Epoch [ 153 / 5000 ] Training-Loss = 0.6771 Training-Accuracy = 0.32294267416000366 Validation-Accuracy = 0.5915032679738562
# Epoch [ 154 / 5000 ] Training-Loss = 0.6749 Training-Accuracy = 0.3251211643218994 Validation-Accuracy = 0.6274509803921569
# Epoch [ 155 / 5000 ] Training-Loss = 0.6727 Training-Accuracy = 0.32728439569473267 Validation-Accuracy = 0.7058823529411765
# Epoch [ 156 / 5000 ] Training-Loss = 0.6706 Training-Accuracy = 0.3294329047203064 Validation-Accuracy = 0.7352941176470589
# Epoch [ 157 / 5000 ] Training-Loss = 0.6684 Training-Accuracy = 0.33156657218933105 Validation-Accuracy = 0.7973856209150327
# Epoch [ 158 / 5000 ] Training-Loss = 0.6663 Training-Accuracy = 0.33368557691574097 Validation-Accuracy = 0.8333333333333334
# Epoch [ 159 / 5000 ] Training-Loss = 0.6642 Training-Accuracy = 0.33578991889953613 Validation-Accuracy = 0.8594771241830066
# Epoch [ 160 / 5000 ] Training-Loss = 0.6621 Training-Accuracy = 0.33787989616394043 Validation-Accuracy = 0.8594771241830066
# Epoch [ 161 / 5000 ] Training-Loss = 0.6600 Training-Accuracy = 0.33995503187179565 Validation-Accuracy = 0.8562091503267973
# Epoch [ 162 / 5000 ] Training-Loss = 0.6580 Training-Accuracy = 0.34201598167419434 Validation-Accuracy = 0.8594771241830066
# Epoch [ 163 / 5000 ] Training-Loss = 0.6559 Training-Accuracy = 0.3440624475479126 Validation-Accuracy = 0.869281045751634
# Epoch [ 164 / 5000 ] Training-Loss = 0.6539 Training-Accuracy = 0.34609484672546387 Validation-Accuracy = 0.8790849673202614
# Epoch [ 165 / 5000 ] Training-Loss = 0.6519 Training-Accuracy = 0.3481130599975586 Validation-Accuracy = 0.8856209150326797
# Epoch [ 166 / 5000 ] Training-Loss = 0.6499 Training-Accuracy = 0.350117027759552 Validation-Accuracy = 0.8856209150326797
# Epoch [ 167 / 5000 ] Training-Loss = 0.6479 Training-Accuracy = 0.35210710763931274 Validation-Accuracy = 0.8921568627450981
# Epoch [ 168 / 5000 ] Training-Loss = 0.6459 Training-Accuracy = 0.3540833592414856 Validation-Accuracy = 0.8954248366013072
# Epoch [ 169 / 5000 ] Training-Loss = 0.6440 Training-Accuracy = 0.3560454845428467 Validation-Accuracy = 0.8954248366013072
# Epoch [ 170 / 5000 ] Training-Loss = 0.6420 Training-Accuracy = 0.3579939603805542 Validation-Accuracy = 0.8954248366013072
# Epoch [ 171 / 5000 ] Training-Loss = 0.6401 Training-Accuracy = 0.35992854833602905 Validation-Accuracy = 0.8954248366013072
# Epoch [ 172 / 5000 ] Training-Loss = 0.6382 Training-Accuracy = 0.36184966564178467 Validation-Accuracy = 0.8954248366013072
# Epoch [ 173 / 5000 ] Training-Loss = 0.6362 Training-Accuracy = 0.36375725269317627 Validation-Accuracy = 0.8921568627450981
# Epoch [ 174 / 5000 ] Training-Loss = 0.6343 Training-Accuracy = 0.3656512498855591 Validation-Accuracy = 0.8921568627450981
# Epoch [ 175 / 5000 ] Training-Loss = 0.6325 Training-Accuracy = 0.3675318956375122 Validation-Accuracy = 0.8921568627450981
# Epoch [ 176 / 5000 ] Training-Loss = 0.6306 Training-Accuracy = 0.3693990111351013 Validation-Accuracy = 0.8921568627450981
# Epoch [ 177 / 5000 ] Training-Loss = 0.6287 Training-Accuracy = 0.3712531328201294 Validation-Accuracy = 0.8921568627450981
# Epoch [ 178 / 5000 ] Training-Loss = 0.6269 Training-Accuracy = 0.37309396266937256 Validation-Accuracy = 0.8921568627450981
# Epoch [ 179 / 5000 ] Training-Loss = 0.6251 Training-Accuracy = 0.37492191791534424 Validation-Accuracy = 0.8921568627450981
# Epoch [ 180 / 5000 ] Training-Loss = 0.6233 Training-Accuracy = 0.37673652172088623 Validation-Accuracy = 0.8921568627450981
# Epoch [ 181 / 5000 ] Training-Loss = 0.6215 Training-Accuracy = 0.3785383105278015 Validation-Accuracy = 0.8921568627450981
# Epoch [ 182 / 5000 ] Training-Loss = 0.6197 Training-Accuracy = 0.38032716512680054 Validation-Accuracy = 0.8921568627450981
# Epoch [ 183 / 5000 ] Training-Loss = 0.6179 Training-Accuracy = 0.3821033239364624 Validation-Accuracy = 0.8921568627450981
# Epoch [ 184 / 5000 ] Training-Loss = 0.6161 Training-Accuracy = 0.38386666774749756 Validation-Accuracy = 0.8921568627450981
# Epoch [ 185 / 5000 ] Training-Loss = 0.6144 Training-Accuracy = 0.3856174349784851 Validation-Accuracy = 0.8921568627450981
# Epoch [ 186 / 5000 ] Training-Loss = 0.6126 Training-Accuracy = 0.3873555660247803 Validation-Accuracy = 0.8921568627450981
# Epoch [ 187 / 5000 ] Training-Loss = 0.6109 Training-Accuracy = 0.38908135890960693 Validation-Accuracy = 0.8921568627450981
# Epoch [ 188 / 5000 ] Training-Loss = 0.6092 Training-Accuracy = 0.39079463481903076 Validation-Accuracy = 0.8921568627450981
# Epoch [ 189 / 5000 ] Training-Loss = 0.6075 Training-Accuracy = 0.3924955725669861 Validation-Accuracy = 0.8921568627450981
# Epoch [ 190 / 5000 ] Training-Loss = 0.6058 Training-Accuracy = 0.3941843509674072 Validation-Accuracy = 0.8921568627450981
# Epoch [ 191 / 5000 ] Training-Loss = 0.6041 Training-Accuracy = 0.3958609104156494 Validation-Accuracy = 0.8921568627450981
# Epoch [ 192 / 5000 ] Training-Loss = 0.6025 Training-Accuracy = 0.3975253105163574 Validation-Accuracy = 0.8921568627450981
# Epoch [ 193 / 5000 ] Training-Loss = 0.6008 Training-Accuracy = 0.3991774916648865 Validation-Accuracy = 0.8921568627450981
# Epoch [ 194 / 5000 ] Training-Loss = 0.5992 Training-Accuracy = 0.4008180499076843 Validation-Accuracy = 0.8921568627450981
# Epoch [ 195 / 5000 ] Training-Loss = 0.5976 Training-Accuracy = 0.4024466872215271 Validation-Accuracy = 0.8921568627450981
# Epoch [ 196 / 5000 ] Training-Loss = 0.5959 Training-Accuracy = 0.40406328439712524 Validation-Accuracy = 0.8921568627450981
# Epoch [ 197 / 5000 ] Training-Loss = 0.5943 Training-Accuracy = 0.40566831827163696 Validation-Accuracy = 0.8921568627450981
# Epoch [ 198 / 5000 ] Training-Loss = 0.5927 Training-Accuracy = 0.4072617292404175 Validation-Accuracy = 0.8921568627450981
# Epoch [ 199 / 5000 ] Training-Loss = 0.5912 Training-Accuracy = 0.40884339809417725 Validation-Accuracy = 0.8921568627450981
# Epoch [ 200 / 5000 ] Training-Loss = 0.5896 Training-Accuracy = 0.4104135036468506 Validation-Accuracy = 0.8921568627450981
# Epoch [ 201 / 5000 ] Training-Loss = 0.5880 Training-Accuracy = 0.41197216510772705 Validation-Accuracy = 0.8921568627450981
# Epoch [ 202 / 5000 ] Training-Loss = 0.5865 Training-Accuracy = 0.41351962089538574 Validation-Accuracy = 0.8921568627450981
# Epoch [ 203 / 5000 ] Training-Loss = 0.5849 Training-Accuracy = 0.41505569219589233 Validation-Accuracy = 0.8921568627450981
# Epoch [ 204 / 5000 ] Training-Loss = 0.5834 Training-Accuracy = 0.4165803790092468 Validation-Accuracy = 0.8921568627450981
# Epoch [ 205 / 5000 ] Training-Loss = 0.5819 Training-Accuracy = 0.4180939793586731 Validation-Accuracy = 0.8921568627450981
# Epoch [ 206 / 5000 ] Training-Loss = 0.5804 Training-Accuracy = 0.41959649324417114 Validation-Accuracy = 0.8921568627450981
# Epoch [ 207 / 5000 ] Training-Loss = 0.5789 Training-Accuracy = 0.42108792066574097 Validation-Accuracy = 0.8921568627450981
# Epoch [ 208 / 5000 ] Training-Loss = 0.5774 Training-Accuracy = 0.42256850004196167 Validation-Accuracy = 0.8921568627450981
# Epoch [ 209 / 5000 ] Training-Loss = 0.5760 Training-Accuracy = 0.4240380525588989 Validation-Accuracy = 0.8921568627450981
# Epoch [ 210 / 5000 ] Training-Loss = 0.5745 Training-Accuracy = 0.42549699544906616 Validation-Accuracy = 0.8921568627450981
# Epoch [ 211 / 5000 ] Training-Loss = 0.5731 Training-Accuracy = 0.4269450902938843 Validation-Accuracy = 0.8921568627450981
# Epoch [ 212 / 5000 ] Training-Loss = 0.5716 Training-Accuracy = 0.4283825755119324 Validation-Accuracy = 0.8921568627450981
# Epoch [ 213 / 5000 ] Training-Loss = 0.5702 Training-Accuracy = 0.42980945110321045 Validation-Accuracy = 0.8921568627450981
# Epoch [ 214 / 5000 ] Training-Loss = 0.5688 Training-Accuracy = 0.43122583627700806 Validation-Accuracy = 0.8921568627450981
# Epoch [ 215 / 5000 ] Training-Loss = 0.5674 Training-Accuracy = 0.4326316714286804 Validation-Accuracy = 0.8921568627450981
# Epoch [ 216 / 5000 ] Training-Loss = 0.5660 Training-Accuracy = 0.43402713537216187 Validation-Accuracy = 0.8921568627450981
# Epoch [ 217 / 5000 ] Training-Loss = 0.5646 Training-Accuracy = 0.4354122281074524 Validation-Accuracy = 0.8921568627450981
# Epoch [ 218 / 5000 ] Training-Loss = 0.5632 Training-Accuracy = 0.43678712844848633 Validation-Accuracy = 0.8921568627450981
# Epoch [ 219 / 5000 ] Training-Loss = 0.5618 Training-Accuracy = 0.43815189599990845 Validation-Accuracy = 0.8921568627450981
# Epoch [ 220 / 5000 ] Training-Loss = 0.5605 Training-Accuracy = 0.43950653076171875 Validation-Accuracy = 0.8921568627450981
# Epoch [ 221 / 5000 ] Training-Loss = 0.5591 Training-Accuracy = 0.4408511519432068 Validation-Accuracy = 0.8921568627450981
# Epoch [ 222 / 5000 ] Training-Loss = 0.5578 Training-Accuracy = 0.44218558073043823 Validation-Accuracy = 0.8921568627450981
# Epoch [ 223 / 5000 ] Training-Loss = 0.5565 Training-Accuracy = 0.4435102939605713 Validation-Accuracy = 0.8921568627450981
# Epoch [ 224 / 5000 ] Training-Loss = 0.5552 Training-Accuracy = 0.44482511281967163 Validation-Accuracy = 0.8921568627450981
# Epoch [ 225 / 5000 ] Training-Loss = 0.5539 Training-Accuracy = 0.44613009691238403 Validation-Accuracy = 0.8921568627450981
# Epoch [ 226 / 5000 ] Training-Loss = 0.5526 Training-Accuracy = 0.4474254250526428 Validation-Accuracy = 0.8921568627450981
# Epoch [ 227 / 5000 ] Training-Loss = 0.5513 Training-Accuracy = 0.4487111568450928 Validation-Accuracy = 0.8921568627450981
# Epoch [ 228 / 5000 ] Training-Loss = 0.5500 Training-Accuracy = 0.4499872922897339 Validation-Accuracy = 0.8921568627450981
# Epoch [ 229 / 5000 ] Training-Loss = 0.5487 Training-Accuracy = 0.45125365257263184 Validation-Accuracy = 0.8921568627450981
# Epoch [ 230 / 5000 ] Training-Loss = 0.5475 Training-Accuracy = 0.4525109529495239 Validation-Accuracy = 0.8921568627450981
# Epoch [ 231 / 5000 ] Training-Loss = 0.5462 Training-Accuracy = 0.45375877618789673 Validation-Accuracy = 0.8921568627450981
# Epoch [ 232 / 5000 ] Training-Loss = 0.5450 Training-Accuracy = 0.45499712228775024 Validation-Accuracy = 0.8921568627450981
# Epoch [ 233 / 5000 ] Training-Loss = 0.5438 Training-Accuracy = 0.4562262296676636 Validation-Accuracy = 0.8921568627450981
# Epoch [ 234 / 5000 ] Training-Loss = 0.5426 Training-Accuracy = 0.45744627714157104 Validation-Accuracy = 0.8921568627450981
# Epoch [ 235 / 5000 ] Training-Loss = 0.5413 Training-Accuracy = 0.45865702629089355 Validation-Accuracy = 0.8921568627450981
# Epoch [ 236 / 5000 ] Training-Loss = 0.5401 Training-Accuracy = 0.459858775138855 Validation-Accuracy = 0.8921568627450981
# Epoch [ 237 / 5000 ] Training-Loss = 0.5389 Training-Accuracy = 0.4610516428947449 Validation-Accuracy = 0.8921568627450981
# Epoch [ 238 / 5000 ] Training-Loss = 0.5378 Training-Accuracy = 0.46223533153533936 Validation-Accuracy = 0.8921568627450981
# Epoch [ 239 / 5000 ] Training-Loss = 0.5366 Training-Accuracy = 0.46341025829315186 Validation-Accuracy = 0.8921568627450981
# Epoch [ 240 / 5000 ] Training-Loss = 0.5354 Training-Accuracy = 0.4645764231681824 Validation-Accuracy = 0.8921568627450981
# Epoch [ 241 / 5000 ] Training-Loss = 0.5343 Training-Accuracy = 0.4657338261604309 Validation-Accuracy = 0.8921568627450981
# Epoch [ 242 / 5000 ] Training-Loss = 0.5331 Training-Accuracy = 0.46688246726989746 Validation-Accuracy = 0.8921568627450981
# Epoch [ 243 / 5000 ] Training-Loss = 0.5320 Training-Accuracy = 0.4680224657058716 Validation-Accuracy = 0.8921568627450981
# Epoch [ 244 / 5000 ] Training-Loss = 0.5308 Training-Accuracy = 0.46915388107299805 Validation-Accuracy = 0.8921568627450981
# Epoch [ 245 / 5000 ] Training-Loss = 0.5297 Training-Accuracy = 0.4702768921852112 Validation-Accuracy = 0.8921568627450981
# Epoch [ 246 / 5000 ] Training-Loss = 0.5286 Training-Accuracy = 0.47139132022857666 Validation-Accuracy = 0.8921568627450981
# Epoch [ 247 / 5000 ] Training-Loss = 0.5275 Training-Accuracy = 0.47249728441238403 Validation-Accuracy = 0.8921568627450981
# Epoch [ 248 / 5000 ] Training-Loss = 0.5264 Training-Accuracy = 0.4735953211784363 Validation-Accuracy = 0.8921568627450981
# Epoch [ 249 / 5000 ] Training-Loss = 0.5253 Training-Accuracy = 0.47468483448028564 Validation-Accuracy = 0.8921568627450981
# Epoch [ 250 / 5000 ] Training-Loss = 0.5242 Training-Accuracy = 0.475766122341156 Validation-Accuracy = 0.8921568627450981
# Epoch [ 251 / 5000 ] Training-Loss = 0.5232 Training-Accuracy = 0.4768393039703369 Validation-Accuracy = 0.8921568627450981
# Epoch [ 252 / 5000 ] Training-Loss = 0.5221 Training-Accuracy = 0.4779042601585388 Validation-Accuracy = 0.8921568627450981
# Epoch [ 253 / 5000 ] Training-Loss = 0.5210 Training-Accuracy = 0.4789612889289856 Validation-Accuracy = 0.8921568627450981
# Epoch [ 254 / 5000 ] Training-Loss = 0.5200 Training-Accuracy = 0.480010449886322 Validation-Accuracy = 0.8921568627450981
# Epoch [ 255 / 5000 ] Training-Loss = 0.5189 Training-Accuracy = 0.4810516834259033 Validation-Accuracy = 0.8921568627450981
# Epoch [ 256 / 5000 ] Training-Loss = 0.5179 Training-Accuracy = 0.48208487033843994 Validation-Accuracy = 0.8921568627450981
# Epoch [ 257 / 5000 ] Training-Loss = 0.5169 Training-Accuracy = 0.4831104278564453 Validation-Accuracy = 0.8921568627450981
# Epoch [ 258 / 5000 ] Training-Loss = 0.5159 Training-Accuracy = 0.48412811756134033 Validation-Accuracy = 0.8921568627450981
# Epoch [ 259 / 5000 ] Training-Loss = 0.5149 Training-Accuracy = 0.4851381778717041 Validation-Accuracy = 0.8921568627450981
# Epoch [ 260 / 5000 ] Training-Loss = 0.5139 Training-Accuracy = 0.48614048957824707 Validation-Accuracy = 0.8921568627450981
# Epoch [ 261 / 5000 ] Training-Loss = 0.5129 Training-Accuracy = 0.48713529109954834 Validation-Accuracy = 0.8921568627450981
# Epoch [ 262 / 5000 ] Training-Loss = 0.5119 Training-Accuracy = 0.4881224036216736 Validation-Accuracy = 0.8921568627450981
# Epoch [ 263 / 5000 ] Training-Loss = 0.5109 Training-Accuracy = 0.4891023635864258 Validation-Accuracy = 0.8921568627450981
# Epoch [ 264 / 5000 ] Training-Loss = 0.5099 Training-Accuracy = 0.4900745749473572 Validation-Accuracy = 0.8921568627450981
# Epoch [ 265 / 5000 ] Training-Loss = 0.5090 Training-Accuracy = 0.4910396933555603 Validation-Accuracy = 0.8921568627450981
# Epoch [ 266 / 5000 ] Training-Loss = 0.5080 Training-Accuracy = 0.49199724197387695 Validation-Accuracy = 0.8921568627450981
# Epoch [ 267 / 5000 ] Training-Loss = 0.5071 Training-Accuracy = 0.4929477572441101 Validation-Accuracy = 0.8921568627450981
# Epoch [ 268 / 5000 ] Training-Loss = 0.5061 Training-Accuracy = 0.49389100074768066 Validation-Accuracy = 0.8921568627450981
# Epoch [ 269 / 5000 ] Training-Loss = 0.5052 Training-Accuracy = 0.4948270916938782 Validation-Accuracy = 0.8921568627450981
# Epoch [ 270 / 5000 ] Training-Loss = 0.5042 Training-Accuracy = 0.4957560896873474 Validation-Accuracy = 0.8921568627450981
# Epoch [ 271 / 5000 ] Training-Loss = 0.5033 Training-Accuracy = 0.4966779947280884 Validation-Accuracy = 0.8921568627450981
# Epoch [ 272 / 5000 ] Training-Loss = 0.5024 Training-Accuracy = 0.4975929856300354 Validation-Accuracy = 0.8921568627450981
# Epoch [ 273 / 5000 ] Training-Loss = 0.5015 Training-Accuracy = 0.4985010027885437 Validation-Accuracy = 0.8921568627450981
# Epoch [ 274 / 5000 ] Training-Loss = 0.5006 Training-Accuracy = 0.4994022250175476 Validation-Accuracy = 0.8921568627450981
# Epoch [ 275 / 5000 ] Training-Loss = 0.4997 Training-Accuracy = 0.5002963840961456 Validation-Accuracy = 0.8921568627450981
# Epoch [ 276 / 5000 ] Training-Loss = 0.4988 Training-Accuracy = 0.5011838674545288 Validation-Accuracy = 0.8921568627450981
# Epoch [ 277 / 5000 ] Training-Loss = 0.4979 Training-Accuracy = 0.50206458568573 Validation-Accuracy = 0.8921568627450981
# Epoch [ 278 / 5000 ] Training-Loss = 0.4971 Training-Accuracy = 0.5029386281967163 Validation-Accuracy = 0.8921568627450981
# Epoch [ 279 / 5000 ] Training-Loss = 0.4962 Training-Accuracy = 0.5038059651851654 Validation-Accuracy = 0.8921568627450981
# Epoch [ 280 / 5000 ] Training-Loss = 0.4953 Training-Accuracy = 0.5046668648719788 Validation-Accuracy = 0.8921568627450981
# Epoch [ 281 / 5000 ] Training-Loss = 0.4945 Training-Accuracy = 0.5055211186408997 Validation-Accuracy = 0.8921568627450981
# Epoch [ 282 / 5000 ] Training-Loss = 0.4936 Training-Accuracy = 0.5063689649105072 Validation-Accuracy = 0.8921568627450981
# Epoch [ 283 / 5000 ] Training-Loss = 0.4928 Training-Accuracy = 0.5072103440761566 Validation-Accuracy = 0.8921568627450981
# Epoch [ 284 / 5000 ] Training-Loss = 0.4920 Training-Accuracy = 0.5080452561378479 Validation-Accuracy = 0.8921568627450981
# Epoch [ 285 / 5000 ] Training-Loss = 0.4911 Training-Accuracy = 0.5088738799095154 Validation-Accuracy = 0.8921568627450981
# Epoch [ 286 / 5000 ] Training-Loss = 0.4903 Training-Accuracy = 0.5096961557865143 Validation-Accuracy = 0.8921568627450981
# Epoch [ 287 / 5000 ] Training-Loss = 0.4895 Training-Accuracy = 0.5105122029781342 Validation-Accuracy = 0.8921568627450981
# Epoch [ 288 / 5000 ] Training-Loss = 0.4887 Training-Accuracy = 0.5113219916820526 Validation-Accuracy = 0.8921568627450981
# Epoch [ 289 / 5000 ] Training-Loss = 0.4879 Training-Accuracy = 0.512125700712204 Validation-Accuracy = 0.8921568627450981
# Epoch [ 290 / 5000 ] Training-Loss = 0.4871 Training-Accuracy = 0.5129233598709106 Validation-Accuracy = 0.8921568627450981
# Epoch [ 291 / 5000 ] Training-Loss = 0.4863 Training-Accuracy = 0.5137148201465607 Validation-Accuracy = 0.8921568627450981
# Epoch [ 292 / 5000 ] Training-Loss = 0.4855 Training-Accuracy = 0.5145003795623779 Validation-Accuracy = 0.8921568627450981
# Epoch [ 293 / 5000 ] Training-Loss = 0.4847 Training-Accuracy = 0.5152799487113953 Validation-Accuracy = 0.8921568627450981
# Epoch [ 294 / 5000 ] Training-Loss = 0.4839 Training-Accuracy = 0.5160535573959351 Validation-Accuracy = 0.8921568627450981
# Epoch [ 295 / 5000 ] Training-Loss = 0.4832 Training-Accuracy = 0.5168211460113525 Validation-Accuracy = 0.8921568627450981
# Epoch [ 296 / 5000 ] Training-Loss = 0.4824 Training-Accuracy = 0.5175830125808716 Validation-Accuracy = 0.8921568627450981
# Epoch [ 297 / 5000 ] Training-Loss = 0.4817 Training-Accuracy = 0.5183391273021698 Validation-Accuracy = 0.8921568627450981
# Epoch [ 298 / 5000 ] Training-Loss = 0.4809 Training-Accuracy = 0.5190894603729248 Validation-Accuracy = 0.8921568627450981
# Epoch [ 299 / 5000 ] Training-Loss = 0.4802 Training-Accuracy = 0.5198340117931366 Validation-Accuracy = 0.8921568627450981
# Epoch [ 300 / 5000 ] Training-Loss = 0.4794 Training-Accuracy = 0.5205729007720947 Validation-Accuracy = 0.8921568627450981
# Epoch [ 301 / 5000 ] Training-Loss = 0.4787 Training-Accuracy = 0.5213062167167664 Validation-Accuracy = 0.8921568627450981
# Epoch [ 302 / 5000 ] Training-Loss = 0.4780 Training-Accuracy = 0.5220339000225067 Validation-Accuracy = 0.8921568627450981
# Epoch [ 303 / 5000 ] Training-Loss = 0.4772 Training-Accuracy = 0.5227560698986053 Validation-Accuracy = 0.8921568627450981
# Epoch [ 304 / 5000 ] Training-Loss = 0.4765 Training-Accuracy = 0.5234726965427399 Validation-Accuracy = 0.8921568627450981
# Epoch [ 305 / 5000 ] Training-Loss = 0.4758 Training-Accuracy = 0.5241838693618774 Validation-Accuracy = 0.8921568627450981
# Epoch [ 306 / 5000 ] Training-Loss = 0.4751 Training-Accuracy = 0.5248896479606628 Validation-Accuracy = 0.8921568627450981
# Epoch [ 307 / 5000 ] Training-Loss = 0.4744 Training-Accuracy = 0.5255901217460632 Validation-Accuracy = 0.8921568627450981
# Epoch [ 308 / 5000 ] Training-Loss = 0.4737 Training-Accuracy = 0.5262851715087891 Validation-Accuracy = 0.8921568627450981
# Epoch [ 309 / 5000 ] Training-Loss = 0.4730 Training-Accuracy = 0.5269748270511627 Validation-Accuracy = 0.8921568627450981
# Epoch [ 310 / 5000 ] Training-Loss = 0.4723 Training-Accuracy = 0.5276594161987305 Validation-Accuracy = 0.8921568627450981
# Epoch [ 311 / 5000 ] Training-Loss = 0.4717 Training-Accuracy = 0.528338611125946 Validation-Accuracy = 0.8921568627450981
# Epoch [ 312 / 5000 ] Training-Loss = 0.4710 Training-Accuracy = 0.5290127396583557 Validation-Accuracy = 0.8921568627450981
# Epoch [ 313 / 5000 ] Training-Loss = 0.4703 Training-Accuracy = 0.5296818315982819 Validation-Accuracy = 0.8921568627450981
# Epoch [ 314 / 5000 ] Training-Loss = 0.4697 Training-Accuracy = 0.5303456783294678 Validation-Accuracy = 0.8921568627450981
# Epoch [ 315 / 5000 ] Training-Loss = 0.4690 Training-Accuracy = 0.5310044586658478 Validation-Accuracy = 0.8921568627450981
# Epoch [ 316 / 5000 ] Training-Loss = 0.4683 Training-Accuracy = 0.5316582918167114 Validation-Accuracy = 0.8921568627450981
# Epoch [ 317 / 5000 ] Training-Loss = 0.4677 Training-Accuracy = 0.5323071479797363 Validation-Accuracy = 0.8921568627450981
# Epoch [ 318 / 5000 ] Training-Loss = 0.4670 Training-Accuracy = 0.5329509377479553 Validation-Accuracy = 0.8921568627450981
# Epoch [ 319 / 5000 ] Training-Loss = 0.4664 Training-Accuracy = 0.5335900187492371 Validation-Accuracy = 0.8921568627450981
# Epoch [ 320 / 5000 ] Training-Loss = 0.4658 Training-Accuracy = 0.5342240333557129 Validation-Accuracy = 0.8921568627450981
# Epoch [ 321 / 5000 ] Training-Loss = 0.4651 Training-Accuracy = 0.5348533093929291 Validation-Accuracy = 0.8921568627450981
# Epoch [ 322 / 5000 ] Training-Loss = 0.4645 Training-Accuracy = 0.5354777574539185 Validation-Accuracy = 0.8921568627450981
# Epoch [ 323 / 5000 ] Training-Loss = 0.4639 Training-Accuracy = 0.536097526550293 Validation-Accuracy = 0.8921568627450981
# Epoch [ 324 / 5000 ] Training-Loss = 0.4633 Training-Accuracy = 0.5367125272750854 Validation-Accuracy = 0.8921568627450981
# Epoch [ 325 / 5000 ] Training-Loss = 0.4627 Training-Accuracy = 0.5373228192329407 Validation-Accuracy = 0.8921568627450981
# Epoch [ 326 / 5000 ] Training-Loss = 0.4621 Training-Accuracy = 0.537928581237793 Validation-Accuracy = 0.8921568627450981
# Epoch [ 327 / 5000 ] Training-Loss = 0.4615 Training-Accuracy = 0.5385295748710632 Validation-Accuracy = 0.8921568627450981
# Epoch [ 328 / 5000 ] Training-Loss = 0.4609 Training-Accuracy = 0.5391261279582977 Validation-Accuracy = 0.8921568627450981
# Epoch [ 329 / 5000 ] Training-Loss = 0.4603 Training-Accuracy = 0.5397180318832397 Validation-Accuracy = 0.8921568627450981
# Epoch [ 330 / 5000 ] Training-Loss = 0.4597 Training-Accuracy = 0.5403054356575012 Validation-Accuracy = 0.8921568627450981
# Epoch [ 331 / 5000 ] Training-Loss = 0.4591 Training-Accuracy = 0.5408883988857269 Validation-Accuracy = 0.8921568627450981
# Epoch [ 332 / 5000 ] Training-Loss = 0.4585 Training-Accuracy = 0.5414669215679169 Validation-Accuracy = 0.8921568627450981
# Epoch [ 333 / 5000 ] Training-Loss = 0.4580 Training-Accuracy = 0.5420410335063934 Validation-Accuracy = 0.8921568627450981
# Epoch [ 334 / 5000 ] Training-Loss = 0.4574 Training-Accuracy = 0.5426108241081238 Validation-Accuracy = 0.8921568627450981
# Epoch [ 335 / 5000 ] Training-Loss = 0.4568 Training-Accuracy = 0.5431762635707855 Validation-Accuracy = 0.8921568627450981
# Epoch [ 336 / 5000 ] Training-Loss = 0.4563 Training-Accuracy = 0.5437372624874115 Validation-Accuracy = 0.8921568627450981
# Epoch [ 337 / 5000 ] Training-Loss = 0.4557 Training-Accuracy = 0.5442941188812256 Validation-Accuracy = 0.8921568627450981
# Epoch [ 338 / 5000 ] Training-Loss = 0.4552 Training-Accuracy = 0.5448466539382935 Validation-Accuracy = 0.8921568627450981
# Epoch [ 339 / 5000 ] Training-Loss = 0.4546 Training-Accuracy = 0.5453950464725494 Validation-Accuracy = 0.8921568627450981
# Epoch [ 340 / 5000 ] Training-Loss = 0.4541 Training-Accuracy = 0.5459392666816711 Validation-Accuracy = 0.8921568627450981
# Epoch [ 341 / 5000 ] Training-Loss = 0.4535 Training-Accuracy = 0.5464792847633362 Validation-Accuracy = 0.8921568627450981
# Epoch [ 342 / 5000 ] Training-Loss = 0.4530 Training-Accuracy = 0.5470151603221893 Validation-Accuracy = 0.8921568627450981
# Epoch [ 343 / 5000 ] Training-Loss = 0.4525 Training-Accuracy = 0.5475470721721649 Validation-Accuracy = 0.8921568627450981
# Epoch [ 344 / 5000 ] Training-Loss = 0.4519 Training-Accuracy = 0.548074871301651 Validation-Accuracy = 0.8921568627450981
# Epoch [ 345 / 5000 ] Training-Loss = 0.4514 Training-Accuracy = 0.5485986769199371 Validation-Accuracy = 0.8921568627450981
# Epoch [ 346 / 5000 ] Training-Loss = 0.4509 Training-Accuracy = 0.5491184592247009 Validation-Accuracy = 0.8921568627450981
# Epoch [ 347 / 5000 ] Training-Loss = 0.4504 Training-Accuracy = 0.5496343374252319 Validation-Accuracy = 0.8921568627450981
# Epoch [ 348 / 5000 ] Training-Loss = 0.4499 Training-Accuracy = 0.5501461923122406 Validation-Accuracy = 0.8921568627450981
# Epoch [ 349 / 5000 ] Training-Loss = 0.4493 Training-Accuracy = 0.5506542325019836 Validation-Accuracy = 0.8921568627450981
# Epoch [ 350 / 5000 ] Training-Loss = 0.4488 Training-Accuracy = 0.5511582493782043 Validation-Accuracy = 0.8921568627450981
# Epoch [ 351 / 5000 ] Training-Loss = 0.4483 Training-Accuracy = 0.5516586005687714 Validation-Accuracy = 0.8921568627450981
# Epoch [ 352 / 5000 ] Training-Loss = 0.4478 Training-Accuracy = 0.552155077457428 Validation-Accuracy = 0.8921568627450981
# Epoch [ 353 / 5000 ] Training-Loss = 0.4474 Training-Accuracy = 0.5526477098464966 Validation-Accuracy = 0.8921568627450981
# Epoch [ 354 / 5000 ] Training-Loss = 0.4469 Training-Accuracy = 0.5531365871429443 Validation-Accuracy = 0.8921568627450981
# Epoch [ 355 / 5000 ] Training-Loss = 0.4464 Training-Accuracy = 0.5536216199398041 Validation-Accuracy = 0.8921568627450981
# Epoch [ 356 / 5000 ] Training-Loss = 0.4459 Training-Accuracy = 0.5541031956672668 Validation-Accuracy = 0.8921568627450981
# Epoch [ 357 / 5000 ] Training-Loss = 0.4454 Training-Accuracy = 0.5545808374881744 Validation-Accuracy = 0.8921568627450981
# Epoch [ 358 / 5000 ] Training-Loss = 0.4449 Training-Accuracy = 0.555055171251297 Validation-Accuracy = 0.8921568627450981
# Epoch [ 359 / 5000 ] Training-Loss = 0.4445 Training-Accuracy = 0.5555254817008972 Validation-Accuracy = 0.8921568627450981
# Epoch [ 360 / 5000 ] Training-Loss = 0.4440 Training-Accuracy = 0.5559924840927124 Validation-Accuracy = 0.8921568627450981
# Epoch [ 361 / 5000 ] Training-Loss = 0.4435 Training-Accuracy = 0.5564558804035187 Validation-Accuracy = 0.8921568627450981
# Epoch [ 362 / 5000 ] Training-Loss = 0.4431 Training-Accuracy = 0.5569157600402832 Validation-Accuracy = 0.8921568627450981
# Epoch [ 363 / 5000 ] Training-Loss = 0.4426 Training-Accuracy = 0.5573720932006836 Validation-Accuracy = 0.8921568627450981
# Epoch [ 364 / 5000 ] Training-Loss = 0.4422 Training-Accuracy = 0.5578249990940094 Validation-Accuracy = 0.8921568627450981
# Epoch [ 365 / 5000 ] Training-Loss = 0.4417 Training-Accuracy = 0.5582743883132935 Validation-Accuracy = 0.8921568627450981
# Epoch [ 366 / 5000 ] Training-Loss = 0.4413 Training-Accuracy = 0.5587204098701477 Validation-Accuracy = 0.8921568627450981
# Epoch [ 367 / 5000 ] Training-Loss = 0.4408 Training-Accuracy = 0.5591630041599274 Validation-Accuracy = 0.8921568627450981
# Epoch [ 368 / 5000 ] Training-Loss = 0.4404 Training-Accuracy = 0.5596022605895996 Validation-Accuracy = 0.8921568627450981
# Epoch [ 369 / 5000 ] Training-Loss = 0.4400 Training-Accuracy = 0.560038149356842 Validation-Accuracy = 0.8921568627450981
# Epoch [ 370 / 5000 ] Training-Loss = 0.4395 Training-Accuracy = 0.5604707896709442 Validation-Accuracy = 0.8921568627450981
# Epoch [ 371 / 5000 ] Training-Loss = 0.4391 Training-Accuracy = 0.5609001517295837 Validation-Accuracy = 0.8921568627450981
# Epoch [ 372 / 5000 ] Training-Loss = 0.4387 Training-Accuracy = 0.5613261461257935 Validation-Accuracy = 0.8921568627450981
# Epoch [ 373 / 5000 ] Training-Loss = 0.4383 Training-Accuracy = 0.5617489218711853 Validation-Accuracy = 0.8921568627450981
# Epoch [ 374 / 5000 ] Training-Loss = 0.4378 Training-Accuracy = 0.5621686279773712 Validation-Accuracy = 0.8921568627450981
# Epoch [ 375 / 5000 ] Training-Loss = 0.4374 Training-Accuracy = 0.5625849366188049 Validation-Accuracy = 0.8921568627450981
# Epoch [ 376 / 5000 ] Training-Loss = 0.4370 Training-Accuracy = 0.5629981756210327 Validation-Accuracy = 0.8921568627450981
# Epoch [ 377 / 5000 ] Training-Loss = 0.4366 Training-Accuracy = 0.5634082853794098 Validation-Accuracy = 0.8921568627450981
# Epoch [ 378 / 5000 ] Training-Loss = 0.4362 Training-Accuracy = 0.5638152658939362 Validation-Accuracy = 0.8921568627450981
# Epoch [ 379 / 5000 ] Training-Loss = 0.4358 Training-Accuracy = 0.5642191171646118 Validation-Accuracy = 0.8921568627450981
# Epoch [ 380 / 5000 ] Training-Loss = 0.4354 Training-Accuracy = 0.5646199285984039 Validation-Accuracy = 0.8921568627450981
# Epoch [ 381 / 5000 ] Training-Loss = 0.4350 Training-Accuracy = 0.5650177001953125 Validation-Accuracy = 0.8921568627450981
# Epoch [ 382 / 5000 ] Training-Loss = 0.4346 Training-Accuracy = 0.5654124021530151 Validation-Accuracy = 0.8921568627450981
# Epoch [ 383 / 5000 ] Training-Loss = 0.4342 Training-Accuracy = 0.5658040940761566 Validation-Accuracy = 0.8921568627450981
# Epoch [ 384 / 5000 ] Training-Loss = 0.4338 Training-Accuracy = 0.5661928057670593 Validation-Accuracy = 0.8921568627450981
# Epoch [ 385 / 5000 ] Training-Loss = 0.4334 Training-Accuracy = 0.566578596830368 Validation-Accuracy = 0.8921568627450981
# ...
# Epoch [ 4873 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6191995739936829 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4874 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192000210285187 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4875 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192003488540649 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4876 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192007958889008 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4877 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192011535167694 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4878 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192015409469604 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4879 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192019581794739 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4880 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.619202196598053 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4881 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192026436328888 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4882 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192030608654022 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4883 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192033886909485 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4884 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192037761211395 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4885 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192041635513306 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4886 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192044913768768 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4887 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192048490047455 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4888 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192052662372589 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4889 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192056238651276 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4890 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192059516906738 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4891 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192062795162201 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4892 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192066967487335 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4893 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192070543766022 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4894 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192073822021484 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4895 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192077696323395 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4896 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192082166671753 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4897 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192085444927216 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4898 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192089319229126 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4899 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192094087600708 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4900 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192097067832947 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4901 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192100942134857 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4902 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192105114459991 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4903 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192108392715454 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4904 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192112863063812 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4905 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192116439342499 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4906 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192119717597961 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4907 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.619212418794632 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4908 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192127466201782 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4909 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192131340503693 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4910 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192135214805603 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4911 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192137897014618 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4912 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.61921426653862 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4913 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.619214653968811 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4914 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192149817943573 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4915 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192153692245483 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4916 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192156970500946 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4917 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.619216114282608 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4918 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192164421081543 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4919 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192168593406677 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4920 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192172169685364 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4921 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.619217574596405 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4922 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192179918289185 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4923 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192184686660767 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4924 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192187964916229 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4925 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192190945148468 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4926 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192193925380707 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4927 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192198395729065 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4928 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192201673984528 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4929 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192205846309662 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4930 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192209720611572 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4931 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192213594913483 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4932 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192218363285065 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4933 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192221939563751 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4934 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192225217819214 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4935 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.61922287940979 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4936 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192232966423035 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4937 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192236542701721 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4938 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192240417003632 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4939 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192243695259094 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4940 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192246973514557 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4941 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192251145839691 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4942 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192254722118378 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4943 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192259192466736 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4944 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192263662815094 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4945 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192266345024109 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4946 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192271411418915 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4947 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192273199558258 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4948 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192277371883392 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4949 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192281246185303 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4950 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192284822463989 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4951 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192288398742676 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4952 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.619229257106781 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4953 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192296147346497 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4954 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192300319671631 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4955 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192303895950317 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4956 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192307770252228 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4957 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192311346530914 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4958 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192314922809601 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4959 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192319691181183 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4960 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192322671413422 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4961 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192326545715332 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4962 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192330121994019 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4963 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192333698272705 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4964 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192337870597839 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4965 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192341148853302 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4966 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192345917224884 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4967 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192349791526794 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4968 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192352771759033 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4969 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192356646060944 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4970 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192360818386078 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4971 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192364394664764 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4972 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192367672920227 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4973 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192371249198914 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4974 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192375123500824 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4975 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192378401756287 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4976 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192383170127869 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4977 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192387640476227 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4978 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192391216754913 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4979 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192395091056824 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4980 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192397773265839 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4981 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192402243614197 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4982 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192406713962555 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4983 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192409992218018 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4984 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.619241327047348 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4985 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192417740821838 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4986 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192420721054077 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4987 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192424297332764 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4988 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192428469657898 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4989 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192432940006256 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4990 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192436814308167 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4991 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192440092563629 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4992 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192444562911987 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4993 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192448437213898 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4994 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192452013492584 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4995 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192455589771271 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4996 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192458868026733 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4997 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192462742328644 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4998 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.619246631860733 Validation-Accuracy = 0.8921568627450981
# Epoch [ 4999 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192470192909241 Validation-Accuracy = 0.8921568627450981
# Epoch [ 5000 / 5000 ] Training-Loss = 0.3808 Training-Accuracy = 0.6192474067211151 Validation-Accuracy = 0.8921568627450981

# %%
print("Maximum Training Accuracy = ", max(training_acc_list))
print("Maximum Validation Accuracy = ",max(val_acc_list) )
model = model_list[training_acc_list.index(max(training_acc_list))]
# Out:
# Maximum Training Accuracy =  0.6192474067211151
# Maximum Validation Accuracy =  0.8954248366013072

# %%
predicted = model(x_train).to(device)
predicted = torch.max(predicted.data,1)[1]
confusionMatrixPrint(predicted.to('cpu').numpy(),y_train.to('cpu').numpy(),0)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Train Data :
#          True Positive =  0            True Negetive =  161
#         False Positive =  0           False Negetive =  1060
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 1221
#
# Accuracy  :  0.8681408681408681
#
# ------------------------------------------------------------------------------------

# %%
predicted = model(x_test).to(device)
predicted = torch.max(predicted.data,1)[1]
confusionMatrixPrint(predicted.to('cpu').numpy(),y_test.to('cpu').numpy(),1)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Validation Data
#
#          True Positive =  0            True Negetive =  33
#         False Positive =  0           False Negetive =  273
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 306
#
# Accuracy  :  0.8921568627450981
#
# ------------------------------------------------------------------------------------

# %%
torch.save(model,"saved_model/temporal_nn.pt")
