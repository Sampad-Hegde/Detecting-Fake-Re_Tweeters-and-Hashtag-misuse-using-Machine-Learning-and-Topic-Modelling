# %% [markdown]
# # Models on Combined Features
# ## Data Preparation

# %%
from Classifier import get_KNN_Model, get_accuracy_matric, get_lin_SVM_Model, get_NaiveBayes_Model
from Hawkes_Process import get_topic_vector
from Topic_Modelling import LDA_main_driver
from filters import train_test_splitter
import numpy as np
import warnings

warnings.simplefilter(action='ignore')

# %%
df, dict_genuine, dict_fake, lda_genuine, lda_fake = LDA_main_driver()
num_topics = 10
# Out:
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-* LDA Training Started -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
#
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-* LDA Training Ended -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*

# %%
user_topic_vectors, labels = get_topic_vector(df, dict_genuine, dict_fake, lda_genuine, lda_fake, 0)
# Out:
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-* Hawkes Process Started -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
#
#
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-* Hawkes Process Ended -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*

# %%
total_len = len(user_topic_vectors)
X = np.array(user_topic_vectors)
Y = np.array(labels)

# %%
x_train, x_test, y_train, y_test = train_test_splitter(X, Y)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((1221, 22), (1221,), (306, 22), (306,))

# %%
def confusionMatrixPrint(P,Y,dataType):
    TF = 0
    TT = 0
    FF = 0
    FT = 0
    for p,y in zip(P,Y):
        if (p,y) == (0,0):
            FF += 1
        elif (p,y) == (1,1):
            TT += 1
        elif (p,y) == (0,1):
            TF += 1
        else:
            FT += 1

    print('------------------------------------------------------------------------------------\n')
    if dataType == 0:
        print("  Confusion Matrix for Train Data : ")
    else:
        print("  Confusion Matrix for Validation Data \n")
    print("         True Positive = ",TT,"           True Negetive = ",TF)
    print("        False Positive = ",FT,"          False Negetive = ",FF)
    print('\n------------------------------------------------------------------------------------\n')
    total = TT+FF+TF+FT
    print(f"  Total Cases : {total}\n")
    print("Accuracy  : ",(TT+FF)/total)
    try:
        prec = (TT)/(TT+FT)
        recall = (TT)/(TT+TF)
        f = (2*recall*prec)/(recall+prec)
        print("Precision : ",prec)
        print("Recall    : ",recall)
        print("F1 Score  : ",f)
    except:
        pass
    
    
    print('\n------------------------------------------------------------------------------------')

# %% [markdown]
# ##  1. KNN Classifier on Combined Topic Vectors Generated by LDA and Hawkes process

# %%
knn = get_KNN_Model(x_train, y_train)

# %%
pred = knn.predict(x_train)
confusionMatrixPrint(pred,y_train,0)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Train Data :
#          True Positive =  148            True Negetive =  173
#         False Positive =  46           False Negetive =  854
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 1221
#
# Accuracy  :  0.8206388206388207
# Precision :  0.7628865979381443
# Recall    :  0.46105919003115264
# F1 Score  :  0.574757281553398
#
# ------------------------------------------------------------------------------------

# %%
pred = knn.predict(x_test)
confusionMatrixPrint(pred,y_test,1)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Validation Data
#
#          True Positive =  20            True Negetive =  45
#         False Positive =  27           False Negetive =  214
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 306
#
# Accuracy  :  0.7647058823529411
# Precision :  0.425531914893617
# Recall    :  0.3076923076923077
# F1 Score  :  0.3571428571428572
#
# ------------------------------------------------------------------------------------

# %% [markdown]
# ## 2. SVM Classifier on Combined Topic Vectors Generated by LDA and Hawkes process

# %%
svm = get_lin_SVM_Model(x_train, y_train)

# %%
pred = svm.predict(x_train)
confusionMatrixPrint(pred,y_train,0)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Train Data :
#          True Positive =  51            True Negetive =  270
#         False Positive =  27           False Negetive =  873
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 1221
#
# Accuracy  :  0.7567567567567568
# Precision :  0.6538461538461539
# Recall    :  0.1588785046728972
# F1 Score  :  0.2556390977443609
#
# ------------------------------------------------------------------------------------

# %%
pred = svm.predict(x_test)
confusionMatrixPrint(pred,y_test,1)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Validation Data
#
#          True Positive =  9            True Negetive =  56
#         False Positive =  7           False Negetive =  234
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 306
#
# Accuracy  :  0.7941176470588235
# Precision :  0.5625
# Recall    :  0.13846153846153847
# F1 Score  :  0.22222222222222224
#
# ------------------------------------------------------------------------------------

# %% [markdown]
# ## 3. Naive Bayes Classifier on Combined Topic Vectors Generated by LDA and Hawkes process

# %%
nb = get_NaiveBayes_Model(x_train, y_train)

# %%
pred = nb.predict(x_train)
confusionMatrixPrint(pred,y_train,0)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Train Data :
#          True Positive =  137            True Negetive =  184
#         False Positive =  171           False Negetive =  729
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 1221
#
# Accuracy  :  0.7092547092547092
# Precision :  0.4448051948051948
# Recall    :  0.42679127725856697
# F1 Score  :  0.4356120826709062
#
# ------------------------------------------------------------------------------------

# %%
pred = nb.predict(x_test)
confusionMatrixPrint(pred,y_test,1)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Validation Data
#
#          True Positive =  27            True Negetive =  38
#         False Positive =  55           False Negetive =  186
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 306
#
# Accuracy  :  0.696078431372549
# Precision :  0.32926829268292684
# Recall    :  0.4153846153846154
# F1 Score  :  0.3673469387755102
#
# ------------------------------------------------------------------------------------

# %% [markdown]
# ## 4. Nueral Network Classifier on Combined Topic Vectors Generated by LDA and Hawkes process
# ### Fully Connected Network of :
#      - Input Layer : 22, 64
#      - Hidden Layer 1 : 64 , 128
#      - Hidden Layer 2 : 128 , 256
#      - Hidden Layer 3 : 256 , 512
#      - Hidden Layer 4 : 512 , 256
#      - Hidden Layer 5 : 256 , 128
#      - Hidden Layer 6 : 128 , 64
#      - Hidden Layer 7 : 64 , 32
#      - Hidden Layer 8 : 32 , 16
#      - Output Layer : 16 , 2

# %%
import torch.nn as nn
import warnings
import torch

# %%
def get_Device():
    return torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device = get_Device()
print(device)
# Out:
# cuda

# %%
x_train = torch.Tensor(x_train).to(device)
y_train = torch.Tensor(y_train).to(device)
x_test = torch.Tensor(x_test).to(device)
y_test = torch.Tensor(y_test).to(device)
y_train = y_train.to(torch.long)

# %%
y_train = y_train.to(torch.long)

# %%
class CombinedClassifierModel(nn.Module):
    def __init__(self, input_size, output_size):
        super(CombinedClassifierModel, self).__init__()
        self.layer1 = nn.Linear(input_size, 64)
        self.layer2 = nn.Linear(64, 128)
        self.layer3 = nn.Linear(128, 256)
        self.layer4 = nn.Linear(256, 512)
        self.layer5 = nn.Linear(512, 256)
        
        self.layer6 = nn.Linear(256, 128)
        self.layer7 = nn.Linear(128, 64)
        self.layer8 = nn.Linear(64, 32)
        self.layer9 = nn.Linear(32, 16)
        self.layer10 = nn.Linear(16, output_size)
        self.relu = nn.ReLU()
        

    def forward(self, inputs):
        out = self.layer1(inputs)
        out = self.relu(out)
        
        out = self.layer2(out)
        out = self.relu(out)
        
        out = self.layer3(out)
        out = self.relu(out)
        
        out = self.layer4(out)
        out = self.relu(out)
        
        out = self.layer5(out)
        out = self.relu(out)
        
        out = self.layer6(out)
        out = self.relu(out)
        
        out = self.layer7(out)
        out = self.relu(out)
        
        out = self.layer8(out)
        out = self.relu(out)
        
        out = self.layer9(out)
        out = self.relu(out)
        
        out = self.layer10(out)
        
        return out

# %%
input_size = 22
output_size = 2
hidden_size = 80
learning_rate = 0.0001
n_epochs = 500

# %%
model = CombinedClassifierModel(input_size=input_size,
                                     output_size=output_size)
model.to(device)
# Out:
# CombinedClassifierModel(
#   (layer1): Linear(in_features=22, out_features=64, bias=True)
#   (layer2): Linear(in_features=64, out_features=128, bias=True)
#   (layer3): Linear(in_features=128, out_features=256, bias=True)
#   (layer4): Linear(in_features=256, out_features=512, bias=True)
#   (layer5): Linear(in_features=512, out_features=256, bias=True)
#   (layer6): Linear(in_features=256, out_features=128, bias=True)
#   (layer7): Linear(in_features=128, out_features=64, bias=True)
#   (layer8): Linear(in_features=64, out_features=32, bias=True)
#   (layer9): Linear(in_features=32, out_features=16, bias=True)
#   (layer10): Linear(in_features=16, out_features=2, bias=True)
#   (relu): ReLU()
# )

# %%
lossfn = torch.nn.CrossEntropyLoss()
lossfn.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def Validator(x_test, y_test):
    predicted = model(x_test).to(device)
    pred = torch.max(predicted.data,1)[1]
    total_test = len(y_test)
    correct_pred = 0

    for i in range(total_test):
        if y_test[i] == pred[i]:
            correct_pred += 1

    return correct_pred/total_test

# %%
val_acc_list = []
training_acc_list = []
model_list = []

for epoch in range(n_epochs):

    predicted = model(x_train).to(device)    

    loss = lossfn(predicted,y_train)
        
    optimizer.zero_grad()
    loss.backward()
    
    optimizer.step()
    
    val_acc = Validator(x_test, y_test.to(torch.int))
    
    print(f'Epoch [ {epoch+1} / {n_epochs} ] Training-Loss = {loss.item():.4f} Training-Accuracy = {1- loss.item()} Validation-Accuracy = {val_acc}')
    
    training_acc_list.append(1-loss.item())
    val_acc_list.append(val_acc)
    model_list.append(model)
# Out:
# Epoch [ 1 / 500 ] Training-Loss = 0.6485 Training-Accuracy = 0.3515099883079529 Validation-Accuracy = 0.7875816993464052
# Epoch [ 2 / 500 ] Training-Loss = 0.6483 Training-Accuracy = 0.3516991138458252 Validation-Accuracy = 0.7875816993464052
# Epoch [ 3 / 500 ] Training-Loss = 0.6481 Training-Accuracy = 0.35188794136047363 Validation-Accuracy = 0.7875816993464052
# Epoch [ 4 / 500 ] Training-Loss = 0.6479 Training-Accuracy = 0.35207635164260864 Validation-Accuracy = 0.7875816993464052
# Epoch [ 5 / 500 ] Training-Loss = 0.6477 Training-Accuracy = 0.3522634506225586 Validation-Accuracy = 0.7875816993464052
# Epoch [ 6 / 500 ] Training-Loss = 0.6475 Training-Accuracy = 0.3524501919746399 Validation-Accuracy = 0.7875816993464052
# Epoch [ 7 / 500 ] Training-Loss = 0.6474 Training-Accuracy = 0.3526347279548645 Validation-Accuracy = 0.7875816993464052
# Epoch [ 8 / 500 ] Training-Loss = 0.6472 Training-Accuracy = 0.3528137803077698 Validation-Accuracy = 0.7875816993464052
# Epoch [ 9 / 500 ] Training-Loss = 0.6470 Training-Accuracy = 0.35299521684646606 Validation-Accuracy = 0.7875816993464052
# Epoch [ 10 / 500 ] Training-Loss = 0.6468 Training-Accuracy = 0.35317832231521606 Validation-Accuracy = 0.7875816993464052
# Epoch [ 11 / 500 ] Training-Loss = 0.6466 Training-Accuracy = 0.35335981845855713 Validation-Accuracy = 0.7875816993464052
# Epoch [ 12 / 500 ] Training-Loss = 0.6465 Training-Accuracy = 0.3535417914390564 Validation-Accuracy = 0.7875816993464052
# Epoch [ 13 / 500 ] Training-Loss = 0.6463 Training-Accuracy = 0.35372668504714966 Validation-Accuracy = 0.7875816993464052
# Epoch [ 14 / 500 ] Training-Loss = 0.6461 Training-Accuracy = 0.353912353515625 Validation-Accuracy = 0.7875816993464052
# Epoch [ 15 / 500 ] Training-Loss = 0.6459 Training-Accuracy = 0.3540956377983093 Validation-Accuracy = 0.7875816993464052
# Epoch [ 16 / 500 ] Training-Loss = 0.6457 Training-Accuracy = 0.3542777895927429 Validation-Accuracy = 0.7875816993464052
# Epoch [ 17 / 500 ] Training-Loss = 0.6455 Training-Accuracy = 0.3544620871543884 Validation-Accuracy = 0.7875816993464052
# Epoch [ 18 / 500 ] Training-Loss = 0.6454 Training-Accuracy = 0.3546481728553772 Validation-Accuracy = 0.7875816993464052
# Epoch [ 19 / 500 ] Training-Loss = 0.6452 Training-Accuracy = 0.3548368215560913 Validation-Accuracy = 0.7875816993464052
# Epoch [ 20 / 500 ] Training-Loss = 0.6450 Training-Accuracy = 0.3550272583961487 Validation-Accuracy = 0.7875816993464052
# Epoch [ 21 / 500 ] Training-Loss = 0.6448 Training-Accuracy = 0.35521912574768066 Validation-Accuracy = 0.7875816993464052
# Epoch [ 22 / 500 ] Training-Loss = 0.6446 Training-Accuracy = 0.35540771484375 Validation-Accuracy = 0.7875816993464052
# Epoch [ 23 / 500 ] Training-Loss = 0.6444 Training-Accuracy = 0.3555893898010254 Validation-Accuracy = 0.7875816993464052
# Epoch [ 24 / 500 ] Training-Loss = 0.6442 Training-Accuracy = 0.3557710647583008 Validation-Accuracy = 0.7875816993464052
# Epoch [ 25 / 500 ] Training-Loss = 0.6440 Training-Accuracy = 0.35595619678497314 Validation-Accuracy = 0.7875816993464052
# Epoch [ 26 / 500 ] Training-Loss = 0.6439 Training-Accuracy = 0.3561447858810425 Validation-Accuracy = 0.7875816993464052
# Epoch [ 27 / 500 ] Training-Loss = 0.6437 Training-Accuracy = 0.3563358187675476 Validation-Accuracy = 0.7875816993464052
# Epoch [ 28 / 500 ] Training-Loss = 0.6435 Training-Accuracy = 0.356525719165802 Validation-Accuracy = 0.7875816993464052
# Epoch [ 29 / 500 ] Training-Loss = 0.6433 Training-Accuracy = 0.3567134737968445 Validation-Accuracy = 0.7875816993464052
# Epoch [ 30 / 500 ] Training-Loss = 0.6431 Training-Accuracy = 0.35690242052078247 Validation-Accuracy = 0.7875816993464052
# Epoch [ 31 / 500 ] Training-Loss = 0.6429 Training-Accuracy = 0.357097327709198 Validation-Accuracy = 0.7875816993464052
# Epoch [ 32 / 500 ] Training-Loss = 0.6427 Training-Accuracy = 0.3572988510131836 Validation-Accuracy = 0.7875816993464052
# Epoch [ 33 / 500 ] Training-Loss = 0.6425 Training-Accuracy = 0.3575076460838318 Validation-Accuracy = 0.7875816993464052
# Epoch [ 34 / 500 ] Training-Loss = 0.6423 Training-Accuracy = 0.357724130153656 Validation-Accuracy = 0.7875816993464052
# Epoch [ 35 / 500 ] Training-Loss = 0.6421 Training-Accuracy = 0.3579484224319458 Validation-Accuracy = 0.7875816993464052
# Epoch [ 36 / 500 ] Training-Loss = 0.6418 Training-Accuracy = 0.3581817150115967 Validation-Accuracy = 0.7875816993464052
# Epoch [ 37 / 500 ] Training-Loss = 0.6416 Training-Accuracy = 0.3584265112876892 Validation-Accuracy = 0.7875816993464052
# Epoch [ 38 / 500 ] Training-Loss = 0.6413 Training-Accuracy = 0.35868746042251587 Validation-Accuracy = 0.7875816993464052
# Epoch [ 39 / 500 ] Training-Loss = 0.6410 Training-Accuracy = 0.3589690923690796 Validation-Accuracy = 0.7875816993464052
# Epoch [ 40 / 500 ] Training-Loss = 0.6407 Training-Accuracy = 0.3592727780342102 Validation-Accuracy = 0.7875816993464052
# Epoch [ 41 / 500 ] Training-Loss = 0.6404 Training-Accuracy = 0.3595997095108032 Validation-Accuracy = 0.7875816993464052
# Epoch [ 42 / 500 ] Training-Loss = 0.6400 Training-Accuracy = 0.35995012521743774 Validation-Accuracy = 0.7875816993464052
# Epoch [ 43 / 500 ] Training-Loss = 0.6397 Training-Accuracy = 0.3603203296661377 Validation-Accuracy = 0.7875816993464052
# Epoch [ 44 / 500 ] Training-Loss = 0.6393 Training-Accuracy = 0.3607112169265747 Validation-Accuracy = 0.7875816993464052
# Epoch [ 45 / 500 ] Training-Loss = 0.6389 Training-Accuracy = 0.36112940311431885 Validation-Accuracy = 0.7875816993464052
# Epoch [ 46 / 500 ] Training-Loss = 0.6384 Training-Accuracy = 0.36158430576324463 Validation-Accuracy = 0.7875816993464052
# Epoch [ 47 / 500 ] Training-Loss = 0.6379 Training-Accuracy = 0.362091064453125 Validation-Accuracy = 0.7875816993464052
# Epoch [ 48 / 500 ] Training-Loss = 0.6373 Training-Accuracy = 0.36265939474105835 Validation-Accuracy = 0.7875816993464052
# Epoch [ 49 / 500 ] Training-Loss = 0.6367 Training-Accuracy = 0.36328744888305664 Validation-Accuracy = 0.7875816993464052
# Epoch [ 50 / 500 ] Training-Loss = 0.6360 Training-Accuracy = 0.363966703414917 Validation-Accuracy = 0.7875816993464052
# Epoch [ 51 / 500 ] Training-Loss = 0.6353 Training-Accuracy = 0.36469918489456177 Validation-Accuracy = 0.7875816993464052
# Epoch [ 52 / 500 ] Training-Loss = 0.6345 Training-Accuracy = 0.3654972314834595 Validation-Accuracy = 0.7875816993464052
# Epoch [ 53 / 500 ] Training-Loss = 0.6336 Training-Accuracy = 0.3663714528083801 Validation-Accuracy = 0.7875816993464052
# Epoch [ 54 / 500 ] Training-Loss = 0.6327 Training-Accuracy = 0.3673269748687744 Validation-Accuracy = 0.7875816993464052
# Epoch [ 55 / 500 ] Training-Loss = 0.6316 Training-Accuracy = 0.3683701753616333 Validation-Accuracy = 0.7875816993464052
# Epoch [ 56 / 500 ] Training-Loss = 0.6305 Training-Accuracy = 0.3695180416107178 Validation-Accuracy = 0.7875816993464052
# Epoch [ 57 / 500 ] Training-Loss = 0.6292 Training-Accuracy = 0.3708103895187378 Validation-Accuracy = 0.7875816993464052
# Epoch [ 58 / 500 ] Training-Loss = 0.6277 Training-Accuracy = 0.3723022937774658 Validation-Accuracy = 0.7875816993464052
# Epoch [ 59 / 500 ] Training-Loss = 0.6260 Training-Accuracy = 0.37399619817733765 Validation-Accuracy = 0.7875816993464052
# Epoch [ 60 / 500 ] Training-Loss = 0.6242 Training-Accuracy = 0.37583136558532715 Validation-Accuracy = 0.7875816993464052
# Epoch [ 61 / 500 ] Training-Loss = 0.6222 Training-Accuracy = 0.37778937816619873 Validation-Accuracy = 0.7875816993464052
# Epoch [ 62 / 500 ] Training-Loss = 0.6201 Training-Accuracy = 0.37989383935928345 Validation-Accuracy = 0.7875816993464052
# Epoch [ 63 / 500 ] Training-Loss = 0.6178 Training-Accuracy = 0.38215768337249756 Validation-Accuracy = 0.7875816993464052
# Epoch [ 64 / 500 ] Training-Loss = 0.6154 Training-Accuracy = 0.3845773935317993 Validation-Accuracy = 0.7875816993464052
# Epoch [ 65 / 500 ] Training-Loss = 0.6128 Training-Accuracy = 0.38715577125549316 Validation-Accuracy = 0.7875816993464052
# Epoch [ 66 / 500 ] Training-Loss = 0.6101 Training-Accuracy = 0.3899075388908386 Validation-Accuracy = 0.7875816993464052
# Epoch [ 67 / 500 ] Training-Loss = 0.6072 Training-Accuracy = 0.3928180932998657 Validation-Accuracy = 0.7875816993464052
# Epoch [ 68 / 500 ] Training-Loss = 0.6041 Training-Accuracy = 0.39587604999542236 Validation-Accuracy = 0.7875816993464052
# Epoch [ 69 / 500 ] Training-Loss = 0.6009 Training-Accuracy = 0.39907461404800415 Validation-Accuracy = 0.7875816993464052
# Epoch [ 70 / 500 ] Training-Loss = 0.5976 Training-Accuracy = 0.4023905396461487 Validation-Accuracy = 0.7875816993464052
# Epoch [ 71 / 500 ] Training-Loss = 0.5942 Training-Accuracy = 0.4057573676109314 Validation-Accuracy = 0.7875816993464052
# Epoch [ 72 / 500 ] Training-Loss = 0.5909 Training-Accuracy = 0.4091079831123352 Validation-Accuracy = 0.7875816993464052
# Epoch [ 73 / 500 ] Training-Loss = 0.5876 Training-Accuracy = 0.41241705417633057 Validation-Accuracy = 0.7875816993464052
# Epoch [ 74 / 500 ] Training-Loss = 0.5844 Training-Accuracy = 0.41563379764556885 Validation-Accuracy = 0.7875816993464052
# Epoch [ 75 / 500 ] Training-Loss = 0.5813 Training-Accuracy = 0.418698251247406 Validation-Accuracy = 0.7875816993464052
# Epoch [ 76 / 500 ] Training-Loss = 0.5785 Training-Accuracy = 0.42152875661849976 Validation-Accuracy = 0.7875816993464052
# Epoch [ 77 / 500 ] Training-Loss = 0.5760 Training-Accuracy = 0.42399871349334717 Validation-Accuracy = 0.7875816993464052
# Epoch [ 78 / 500 ] Training-Loss = 0.5740 Training-Accuracy = 0.4259839653968811 Validation-Accuracy = 0.7875816993464052
# Epoch [ 79 / 500 ] Training-Loss = 0.5726 Training-Accuracy = 0.42736148834228516 Validation-Accuracy = 0.7875816993464052
# Epoch [ 80 / 500 ] Training-Loss = 0.5720 Training-Accuracy = 0.42804044485092163 Validation-Accuracy = 0.7875816993464052
# Epoch [ 81 / 500 ] Training-Loss = 0.5720 Training-Accuracy = 0.4280255436897278 Validation-Accuracy = 0.7875816993464052
# Epoch [ 82 / 500 ] Training-Loss = 0.5726 Training-Accuracy = 0.4274352788925171 Validation-Accuracy = 0.7875816993464052
# Epoch [ 83 / 500 ] Training-Loss = 0.5735 Training-Accuracy = 0.4265178442001343 Validation-Accuracy = 0.7875816993464052
# Epoch [ 84 / 500 ] Training-Loss = 0.5744 Training-Accuracy = 0.42560726404190063 Validation-Accuracy = 0.7875816993464052
# Epoch [ 85 / 500 ] Training-Loss = 0.5750 Training-Accuracy = 0.4249841570854187 Validation-Accuracy = 0.7875816993464052
# Epoch [ 86 / 500 ] Training-Loss = 0.5752 Training-Accuracy = 0.42479467391967773 Validation-Accuracy = 0.7875816993464052
# Epoch [ 87 / 500 ] Training-Loss = 0.5750 Training-Accuracy = 0.4250372648239136 Validation-Accuracy = 0.7875816993464052
# Epoch [ 88 / 500 ] Training-Loss = 0.5744 Training-Accuracy = 0.42559605836868286 Validation-Accuracy = 0.7875816993464052
# Epoch [ 89 / 500 ] Training-Loss = 0.5737 Training-Accuracy = 0.4263290762901306 Validation-Accuracy = 0.7875816993464052
# Epoch [ 90 / 500 ] Training-Loss = 0.5729 Training-Accuracy = 0.4270850419998169 Validation-Accuracy = 0.7875816993464052
# Epoch [ 91 / 500 ] Training-Loss = 0.5722 Training-Accuracy = 0.42775923013687134 Validation-Accuracy = 0.7875816993464052
# Epoch [ 92 / 500 ] Training-Loss = 0.5717 Training-Accuracy = 0.42827844619750977 Validation-Accuracy = 0.7875816993464052
# Epoch [ 93 / 500 ] Training-Loss = 0.5714 Training-Accuracy = 0.4286203384399414 Validation-Accuracy = 0.7875816993464052
# Epoch [ 94 / 500 ] Training-Loss = 0.5712 Training-Accuracy = 0.4287962317466736 Validation-Accuracy = 0.7875816993464052
# Epoch [ 95 / 500 ] Training-Loss = 0.5712 Training-Accuracy = 0.42883872985839844 Validation-Accuracy = 0.7875816993464052
# Epoch [ 96 / 500 ] Training-Loss = 0.5712 Training-Accuracy = 0.42879194021224976 Validation-Accuracy = 0.7875816993464052
# Epoch [ 97 / 500 ] Training-Loss = 0.5713 Training-Accuracy = 0.4287019371986389 Validation-Accuracy = 0.7875816993464052
# Epoch [ 98 / 500 ] Training-Loss = 0.5714 Training-Accuracy = 0.4286075234413147 Validation-Accuracy = 0.7875816993464052
# Epoch [ 99 / 500 ] Training-Loss = 0.5715 Training-Accuracy = 0.4285391569137573 Validation-Accuracy = 0.7875816993464052
# Epoch [ 100 / 500 ] Training-Loss = 0.5715 Training-Accuracy = 0.4285151958465576 Validation-Accuracy = 0.7875816993464052
# Epoch [ 101 / 500 ] Training-Loss = 0.5715 Training-Accuracy = 0.42854398488998413 Validation-Accuracy = 0.7875816993464052
# Epoch [ 102 / 500 ] Training-Loss = 0.5714 Training-Accuracy = 0.42862480878829956 Validation-Accuracy = 0.7875816993464052
# Epoch [ 103 / 500 ] Training-Loss = 0.5712 Training-Accuracy = 0.4287509322166443 Validation-Accuracy = 0.7875816993464052
# Epoch [ 104 / 500 ] Training-Loss = 0.5711 Training-Accuracy = 0.42891013622283936 Validation-Accuracy = 0.7875816993464052
# Epoch [ 105 / 500 ] Training-Loss = 0.5709 Training-Accuracy = 0.42909061908721924 Validation-Accuracy = 0.7875816993464052
# Epoch [ 106 / 500 ] Training-Loss = 0.5707 Training-Accuracy = 0.4292682409286499 Validation-Accuracy = 0.7875816993464052
# Epoch [ 107 / 500 ] Training-Loss = 0.5706 Training-Accuracy = 0.42943668365478516 Validation-Accuracy = 0.7875816993464052
# Epoch [ 108 / 500 ] Training-Loss = 0.5704 Training-Accuracy = 0.42958712577819824 Validation-Accuracy = 0.7875816993464052
# Epoch [ 109 / 500 ] Training-Loss = 0.5703 Training-Accuracy = 0.42971283197402954 Validation-Accuracy = 0.7875816993464052
# Epoch [ 110 / 500 ] Training-Loss = 0.5702 Training-Accuracy = 0.4298103451728821 Validation-Accuracy = 0.7875816993464052
# Epoch [ 111 / 500 ] Training-Loss = 0.5701 Training-Accuracy = 0.42988163232803345 Validation-Accuracy = 0.7875816993464052
# Epoch [ 112 / 500 ] Training-Loss = 0.5701 Training-Accuracy = 0.429934561252594 Validation-Accuracy = 0.7875816993464052
# Epoch [ 113 / 500 ] Training-Loss = 0.5700 Training-Accuracy = 0.42997580766677856 Validation-Accuracy = 0.7875816993464052
# Epoch [ 114 / 500 ] Training-Loss = 0.5700 Training-Accuracy = 0.430014967918396 Validation-Accuracy = 0.7875816993464052
# Epoch [ 115 / 500 ] Training-Loss = 0.5699 Training-Accuracy = 0.43005919456481934 Validation-Accuracy = 0.7875816993464052
# Epoch [ 116 / 500 ] Training-Loss = 0.5699 Training-Accuracy = 0.43011265993118286 Validation-Accuracy = 0.7875816993464052
# Epoch [ 117 / 500 ] Training-Loss = 0.5698 Training-Accuracy = 0.43017929792404175 Validation-Accuracy = 0.7875816993464052
# Epoch [ 118 / 500 ] Training-Loss = 0.5697 Training-Accuracy = 0.43025898933410645 Validation-Accuracy = 0.7875816993464052
# Epoch [ 119 / 500 ] Training-Loss = 0.5697 Training-Accuracy = 0.43034934997558594 Validation-Accuracy = 0.7875816993464052
# Epoch [ 120 / 500 ] Training-Loss = 0.5696 Training-Accuracy = 0.4304463863372803 Validation-Accuracy = 0.7875816993464052
# Epoch [ 121 / 500 ] Training-Loss = 0.5695 Training-Accuracy = 0.43054449558258057 Validation-Accuracy = 0.7875816993464052
# Epoch [ 122 / 500 ] Training-Loss = 0.5694 Training-Accuracy = 0.4306405782699585 Validation-Accuracy = 0.7875816993464052
# Epoch [ 123 / 500 ] Training-Loss = 0.5693 Training-Accuracy = 0.4307307004928589 Validation-Accuracy = 0.7875816993464052
# Epoch [ 124 / 500 ] Training-Loss = 0.5692 Training-Accuracy = 0.4308127164840698 Validation-Accuracy = 0.7875816993464052
# Epoch [ 125 / 500 ] Training-Loss = 0.5691 Training-Accuracy = 0.4308881163597107 Validation-Accuracy = 0.7875816993464052
# Epoch [ 126 / 500 ] Training-Loss = 0.5690 Training-Accuracy = 0.4309583306312561 Validation-Accuracy = 0.7875816993464052
# Epoch [ 127 / 500 ] Training-Loss = 0.5690 Training-Accuracy = 0.4310256242752075 Validation-Accuracy = 0.7875816993464052
# Epoch [ 128 / 500 ] Training-Loss = 0.5689 Training-Accuracy = 0.4310930371284485 Validation-Accuracy = 0.7875816993464052
# Epoch [ 129 / 500 ] Training-Loss = 0.5688 Training-Accuracy = 0.4311618208885193 Validation-Accuracy = 0.7875816993464052
# Epoch [ 130 / 500 ] Training-Loss = 0.5688 Training-Accuracy = 0.4312325119972229 Validation-Accuracy = 0.7875816993464052
# Epoch [ 131 / 500 ] Training-Loss = 0.5687 Training-Accuracy = 0.43130701780319214 Validation-Accuracy = 0.7875816993464052
# Epoch [ 132 / 500 ] Training-Loss = 0.5686 Training-Accuracy = 0.431385338306427 Validation-Accuracy = 0.7875816993464052
# Epoch [ 133 / 500 ] Training-Loss = 0.5685 Training-Accuracy = 0.43146687746047974 Validation-Accuracy = 0.7875816993464052
# Epoch [ 134 / 500 ] Training-Loss = 0.5685 Training-Accuracy = 0.43154942989349365 Validation-Accuracy = 0.7875816993464052
# Epoch [ 135 / 500 ] Training-Loss = 0.5684 Training-Accuracy = 0.4316326379776001 Validation-Accuracy = 0.7875816993464052
# Epoch [ 136 / 500 ] Training-Loss = 0.5683 Training-Accuracy = 0.4317132830619812 Validation-Accuracy = 0.7875816993464052
# Epoch [ 137 / 500 ] Training-Loss = 0.5682 Training-Accuracy = 0.43179041147232056 Validation-Accuracy = 0.7875816993464052
# Epoch [ 138 / 500 ] Training-Loss = 0.5681 Training-Accuracy = 0.4318660497665405 Validation-Accuracy = 0.7875816993464052
# Epoch [ 139 / 500 ] Training-Loss = 0.5681 Training-Accuracy = 0.4319421648979187 Validation-Accuracy = 0.7875816993464052
# Epoch [ 140 / 500 ] Training-Loss = 0.5680 Training-Accuracy = 0.4320187568664551 Validation-Accuracy = 0.7875816993464052
# Epoch [ 141 / 500 ] Training-Loss = 0.5679 Training-Accuracy = 0.43209749460220337 Validation-Accuracy = 0.7875816993464052
# Epoch [ 142 / 500 ] Training-Loss = 0.5678 Training-Accuracy = 0.43217766284942627 Validation-Accuracy = 0.7875816993464052
# Epoch [ 143 / 500 ] Training-Loss = 0.5677 Training-Accuracy = 0.4322584867477417 Validation-Accuracy = 0.7875816993464052
# Epoch [ 144 / 500 ] Training-Loss = 0.5677 Training-Accuracy = 0.43234026432037354 Validation-Accuracy = 0.7875816993464052
# Epoch [ 145 / 500 ] Training-Loss = 0.5676 Training-Accuracy = 0.4324237108230591 Validation-Accuracy = 0.7875816993464052
# Epoch [ 146 / 500 ] Training-Loss = 0.5675 Training-Accuracy = 0.432506799697876 Validation-Accuracy = 0.7875816993464052
# Epoch [ 147 / 500 ] Training-Loss = 0.5674 Training-Accuracy = 0.4325903058052063 Validation-Accuracy = 0.7875816993464052
# Epoch [ 148 / 500 ] Training-Loss = 0.5673 Training-Accuracy = 0.4326735734939575 Validation-Accuracy = 0.7875816993464052
# Epoch [ 149 / 500 ] Training-Loss = 0.5672 Training-Accuracy = 0.43276041746139526 Validation-Accuracy = 0.7875816993464052
# Epoch [ 150 / 500 ] Training-Loss = 0.5671 Training-Accuracy = 0.43285900354385376 Validation-Accuracy = 0.7875816993464052
# Epoch [ 151 / 500 ] Training-Loss = 0.5670 Training-Accuracy = 0.43296903371810913 Validation-Accuracy = 0.7875816993464052
# Epoch [ 152 / 500 ] Training-Loss = 0.5669 Training-Accuracy = 0.4330829381942749 Validation-Accuracy = 0.7875816993464052
# Epoch [ 153 / 500 ] Training-Loss = 0.5668 Training-Accuracy = 0.4331982731819153 Validation-Accuracy = 0.7875816993464052
# Epoch [ 154 / 500 ] Training-Loss = 0.5667 Training-Accuracy = 0.4333100914955139 Validation-Accuracy = 0.7875816993464052
# Epoch [ 155 / 500 ] Training-Loss = 0.5666 Training-Accuracy = 0.4334148168563843 Validation-Accuracy = 0.7875816993464052
# Epoch [ 156 / 500 ] Training-Loss = 0.5665 Training-Accuracy = 0.4335140585899353 Validation-Accuracy = 0.7875816993464052
# Epoch [ 157 / 500 ] Training-Loss = 0.5664 Training-Accuracy = 0.4336066246032715 Validation-Accuracy = 0.7875816993464052
# Epoch [ 158 / 500 ] Training-Loss = 0.5663 Training-Accuracy = 0.43369418382644653 Validation-Accuracy = 0.7875816993464052
# Epoch [ 159 / 500 ] Training-Loss = 0.5662 Training-Accuracy = 0.4337816834449768 Validation-Accuracy = 0.7875816993464052
# Epoch [ 160 / 500 ] Training-Loss = 0.5661 Training-Accuracy = 0.4338700771331787 Validation-Accuracy = 0.7875816993464052
# Epoch [ 161 / 500 ] Training-Loss = 0.5660 Training-Accuracy = 0.4339596629142761 Validation-Accuracy = 0.7875816993464052
# Epoch [ 162 / 500 ] Training-Loss = 0.5659 Training-Accuracy = 0.4340503215789795 Validation-Accuracy = 0.7875816993464052
# Epoch [ 163 / 500 ] Training-Loss = 0.5659 Training-Accuracy = 0.4341421127319336 Validation-Accuracy = 0.7875816993464052
# Epoch [ 164 / 500 ] Training-Loss = 0.5658 Training-Accuracy = 0.4342345595359802 Validation-Accuracy = 0.7875816993464052
# Epoch [ 165 / 500 ] Training-Loss = 0.5657 Training-Accuracy = 0.43432730436325073 Validation-Accuracy = 0.7875816993464052
# Epoch [ 166 / 500 ] Training-Loss = 0.5656 Training-Accuracy = 0.43441981077194214 Validation-Accuracy = 0.7875816993464052
# Epoch [ 167 / 500 ] Training-Loss = 0.5655 Training-Accuracy = 0.43451225757598877 Validation-Accuracy = 0.7875816993464052
# Epoch [ 168 / 500 ] Training-Loss = 0.5654 Training-Accuracy = 0.43460530042648315 Validation-Accuracy = 0.7875816993464052
# Epoch [ 169 / 500 ] Training-Loss = 0.5653 Training-Accuracy = 0.4346988797187805 Validation-Accuracy = 0.7875816993464052
# Epoch [ 170 / 500 ] Training-Loss = 0.5652 Training-Accuracy = 0.43479305505752563 Validation-Accuracy = 0.7875816993464052
# Epoch [ 171 / 500 ] Training-Loss = 0.5651 Training-Accuracy = 0.43488746881484985 Validation-Accuracy = 0.7875816993464052
# Epoch [ 172 / 500 ] Training-Loss = 0.5650 Training-Accuracy = 0.43498319387435913 Validation-Accuracy = 0.7875816993464052
# Epoch [ 173 / 500 ] Training-Loss = 0.5649 Training-Accuracy = 0.43507981300354004 Validation-Accuracy = 0.7875816993464052
# Epoch [ 174 / 500 ] Training-Loss = 0.5648 Training-Accuracy = 0.435177743434906 Validation-Accuracy = 0.7875816993464052
# Epoch [ 175 / 500 ] Training-Loss = 0.5647 Training-Accuracy = 0.4352765679359436 Validation-Accuracy = 0.7875816993464052
# Epoch [ 176 / 500 ] Training-Loss = 0.5646 Training-Accuracy = 0.4353766441345215 Validation-Accuracy = 0.7875816993464052
# Epoch [ 177 / 500 ] Training-Loss = 0.5645 Training-Accuracy = 0.4354778528213501 Validation-Accuracy = 0.7875816993464052
# Epoch [ 178 / 500 ] Training-Loss = 0.5644 Training-Accuracy = 0.43558019399642944 Validation-Accuracy = 0.7875816993464052
# Epoch [ 179 / 500 ] Training-Loss = 0.5643 Training-Accuracy = 0.43568289279937744 Validation-Accuracy = 0.7875816993464052
# Epoch [ 180 / 500 ] Training-Loss = 0.5642 Training-Accuracy = 0.4357873797416687 Validation-Accuracy = 0.7875816993464052
# Epoch [ 181 / 500 ] Training-Loss = 0.5641 Training-Accuracy = 0.43589407205581665 Validation-Accuracy = 0.7875816993464052
# Epoch [ 182 / 500 ] Training-Loss = 0.5640 Training-Accuracy = 0.4360019564628601 Validation-Accuracy = 0.7875816993464052
# Epoch [ 183 / 500 ] Training-Loss = 0.5639 Training-Accuracy = 0.43611007928848267 Validation-Accuracy = 0.7875816993464052
# Epoch [ 184 / 500 ] Training-Loss = 0.5638 Training-Accuracy = 0.4362180829048157 Validation-Accuracy = 0.7875816993464052
# Epoch [ 185 / 500 ] Training-Loss = 0.5637 Training-Accuracy = 0.43632614612579346 Validation-Accuracy = 0.7875816993464052
# Epoch [ 186 / 500 ] Training-Loss = 0.5636 Training-Accuracy = 0.4364365339279175 Validation-Accuracy = 0.7875816993464052
# Epoch [ 187 / 500 ] Training-Loss = 0.5635 Training-Accuracy = 0.4365496039390564 Validation-Accuracy = 0.7875816993464052
# Epoch [ 188 / 500 ] Training-Loss = 0.5633 Training-Accuracy = 0.43666428327560425 Validation-Accuracy = 0.7875816993464052
# Epoch [ 189 / 500 ] Training-Loss = 0.5632 Training-Accuracy = 0.4367811679840088 Validation-Accuracy = 0.7875816993464052
# Epoch [ 190 / 500 ] Training-Loss = 0.5631 Training-Accuracy = 0.4369003176689148 Validation-Accuracy = 0.7875816993464052
# Epoch [ 191 / 500 ] Training-Loss = 0.5630 Training-Accuracy = 0.4370223879814148 Validation-Accuracy = 0.7875816993464052
# Epoch [ 192 / 500 ] Training-Loss = 0.5629 Training-Accuracy = 0.43714743852615356 Validation-Accuracy = 0.7875816993464052
# Epoch [ 193 / 500 ] Training-Loss = 0.5627 Training-Accuracy = 0.43727368116378784 Validation-Accuracy = 0.7875816993464052
# Epoch [ 194 / 500 ] Training-Loss = 0.5626 Training-Accuracy = 0.43740314245224 Validation-Accuracy = 0.7875816993464052
# Epoch [ 195 / 500 ] Training-Loss = 0.5625 Training-Accuracy = 0.4375356435775757 Validation-Accuracy = 0.7875816993464052
# Epoch [ 196 / 500 ] Training-Loss = 0.5623 Training-Accuracy = 0.4376707673072815 Validation-Accuracy = 0.7875816993464052
# Epoch [ 197 / 500 ] Training-Loss = 0.5622 Training-Accuracy = 0.43780750036239624 Validation-Accuracy = 0.7875816993464052
# Epoch [ 198 / 500 ] Training-Loss = 0.5621 Training-Accuracy = 0.4379459619522095 Validation-Accuracy = 0.7875816993464052
# Epoch [ 199 / 500 ] Training-Loss = 0.5619 Training-Accuracy = 0.4380875825881958 Validation-Accuracy = 0.7875816993464052
# Epoch [ 200 / 500 ] Training-Loss = 0.5618 Training-Accuracy = 0.43823254108428955 Validation-Accuracy = 0.7875816993464052
# Epoch [ 201 / 500 ] Training-Loss = 0.5616 Training-Accuracy = 0.43838071823120117 Validation-Accuracy = 0.7875816993464052
# Epoch [ 202 / 500 ] Training-Loss = 0.5615 Training-Accuracy = 0.43853217363357544 Validation-Accuracy = 0.7875816993464052
# Epoch [ 203 / 500 ] Training-Loss = 0.5613 Training-Accuracy = 0.43868720531463623 Validation-Accuracy = 0.7875816993464052
# Epoch [ 204 / 500 ] Training-Loss = 0.5612 Training-Accuracy = 0.43884629011154175 Validation-Accuracy = 0.7875816993464052
# Epoch [ 205 / 500 ] Training-Loss = 0.5610 Training-Accuracy = 0.43900883197784424 Validation-Accuracy = 0.7875816993464052
# Epoch [ 206 / 500 ] Training-Loss = 0.5608 Training-Accuracy = 0.4391738176345825 Validation-Accuracy = 0.7875816993464052
# Epoch [ 207 / 500 ] Training-Loss = 0.5607 Training-Accuracy = 0.43933969736099243 Validation-Accuracy = 0.7875816993464052
# Epoch [ 208 / 500 ] Training-Loss = 0.5605 Training-Accuracy = 0.4395086169242859 Validation-Accuracy = 0.7875816993464052
# Epoch [ 209 / 500 ] Training-Loss = 0.5603 Training-Accuracy = 0.4396820664405823 Validation-Accuracy = 0.7875816993464052
# Epoch [ 210 / 500 ] Training-Loss = 0.5601 Training-Accuracy = 0.4398593306541443 Validation-Accuracy = 0.7875816993464052
# Epoch [ 211 / 500 ] Training-Loss = 0.5600 Training-Accuracy = 0.4400401711463928 Validation-Accuracy = 0.7875816993464052
# Epoch [ 212 / 500 ] Training-Loss = 0.5598 Training-Accuracy = 0.4402252435684204 Validation-Accuracy = 0.7875816993464052
# Epoch [ 213 / 500 ] Training-Loss = 0.5596 Training-Accuracy = 0.44041359424591064 Validation-Accuracy = 0.7875816993464052
# Epoch [ 214 / 500 ] Training-Loss = 0.5594 Training-Accuracy = 0.4406052231788635 Validation-Accuracy = 0.7875816993464052
# Epoch [ 215 / 500 ] Training-Loss = 0.5592 Training-Accuracy = 0.4408012628555298 Validation-Accuracy = 0.7875816993464052
# Epoch [ 216 / 500 ] Training-Loss = 0.5590 Training-Accuracy = 0.4410020709037781 Validation-Accuracy = 0.7875816993464052
# Epoch [ 217 / 500 ] Training-Loss = 0.5588 Training-Accuracy = 0.44120848178863525 Validation-Accuracy = 0.7875816993464052
# Epoch [ 218 / 500 ] Training-Loss = 0.5586 Training-Accuracy = 0.4414209723472595 Validation-Accuracy = 0.7875816993464052
# Epoch [ 219 / 500 ] Training-Loss = 0.5584 Training-Accuracy = 0.4416397213935852 Validation-Accuracy = 0.7875816993464052
# Epoch [ 220 / 500 ] Training-Loss = 0.5581 Training-Accuracy = 0.4418622851371765 Validation-Accuracy = 0.7875816993464052
# Epoch [ 221 / 500 ] Training-Loss = 0.5579 Training-Accuracy = 0.4420914649963379 Validation-Accuracy = 0.7875816993464052
# Epoch [ 222 / 500 ] Training-Loss = 0.5577 Training-Accuracy = 0.44232749938964844 Validation-Accuracy = 0.7875816993464052
# Epoch [ 223 / 500 ] Training-Loss = 0.5574 Training-Accuracy = 0.442568838596344 Validation-Accuracy = 0.7875816993464052
# Epoch [ 224 / 500 ] Training-Loss = 0.5572 Training-Accuracy = 0.44281625747680664 Validation-Accuracy = 0.7875816993464052
# Epoch [ 225 / 500 ] Training-Loss = 0.5569 Training-Accuracy = 0.4430696964263916 Validation-Accuracy = 0.7875816993464052
# Epoch [ 226 / 500 ] Training-Loss = 0.5567 Training-Accuracy = 0.44333022832870483 Validation-Accuracy = 0.7875816993464052
# Epoch [ 227 / 500 ] Training-Loss = 0.5564 Training-Accuracy = 0.44359880685806274 Validation-Accuracy = 0.7875816993464052
# Epoch [ 228 / 500 ] Training-Loss = 0.5561 Training-Accuracy = 0.44387388229370117 Validation-Accuracy = 0.7875816993464052
# Epoch [ 229 / 500 ] Training-Loss = 0.5558 Training-Accuracy = 0.44415515661239624 Validation-Accuracy = 0.7875816993464052
# Epoch [ 230 / 500 ] Training-Loss = 0.5556 Training-Accuracy = 0.4444463849067688 Validation-Accuracy = 0.7875816993464052
# Epoch [ 231 / 500 ] Training-Loss = 0.5553 Training-Accuracy = 0.444746196269989 Validation-Accuracy = 0.7875816993464052
# Epoch [ 232 / 500 ] Training-Loss = 0.5549 Training-Accuracy = 0.44505375623703003 Validation-Accuracy = 0.7875816993464052
# Epoch [ 233 / 500 ] Training-Loss = 0.5546 Training-Accuracy = 0.44536709785461426 Validation-Accuracy = 0.7875816993464052
# Epoch [ 234 / 500 ] Training-Loss = 0.5543 Training-Accuracy = 0.4456913471221924 Validation-Accuracy = 0.7875816993464052
# Epoch [ 235 / 500 ] Training-Loss = 0.5540 Training-Accuracy = 0.4460250735282898 Validation-Accuracy = 0.7875816993464052
# Epoch [ 236 / 500 ] Training-Loss = 0.5536 Training-Accuracy = 0.44636738300323486 Validation-Accuracy = 0.7875816993464052
# Epoch [ 237 / 500 ] Training-Loss = 0.5533 Training-Accuracy = 0.44672077894210815 Validation-Accuracy = 0.7875816993464052
# Epoch [ 238 / 500 ] Training-Loss = 0.5529 Training-Accuracy = 0.44708991050720215 Validation-Accuracy = 0.7875816993464052
# Epoch [ 239 / 500 ] Training-Loss = 0.5525 Training-Accuracy = 0.44747430086135864 Validation-Accuracy = 0.7875816993464052
# Epoch [ 240 / 500 ] Training-Loss = 0.5521 Training-Accuracy = 0.4478682279586792 Validation-Accuracy = 0.7875816993464052
# Epoch [ 241 / 500 ] Training-Loss = 0.5517 Training-Accuracy = 0.44827306270599365 Validation-Accuracy = 0.7875816993464052
# Epoch [ 242 / 500 ] Training-Loss = 0.5513 Training-Accuracy = 0.4486876130104065 Validation-Accuracy = 0.7875816993464052
# Epoch [ 243 / 500 ] Training-Loss = 0.5509 Training-Accuracy = 0.44911354780197144 Validation-Accuracy = 0.7875816993464052
# Epoch [ 244 / 500 ] Training-Loss = 0.5504 Training-Accuracy = 0.4495556354522705 Validation-Accuracy = 0.7875816993464052
# Epoch [ 245 / 500 ] Training-Loss = 0.5500 Training-Accuracy = 0.4500018358230591 Validation-Accuracy = 0.7875816993464052
# Epoch [ 246 / 500 ] Training-Loss = 0.5495 Training-Accuracy = 0.4504736661911011 Validation-Accuracy = 0.7875816993464052
# Epoch [ 247 / 500 ] Training-Loss = 0.5490 Training-Accuracy = 0.45095473527908325 Validation-Accuracy = 0.7875816993464052
# Epoch [ 248 / 500 ] Training-Loss = 0.5485 Training-Accuracy = 0.4514511823654175 Validation-Accuracy = 0.7875816993464052
# Epoch [ 249 / 500 ] Training-Loss = 0.5480 Training-Accuracy = 0.45196104049682617 Validation-Accuracy = 0.7875816993464052
# Epoch [ 250 / 500 ] Training-Loss = 0.5475 Training-Accuracy = 0.45248275995254517 Validation-Accuracy = 0.7875816993464052
# Epoch [ 251 / 500 ] Training-Loss = 0.5470 Training-Accuracy = 0.4530192017555237 Validation-Accuracy = 0.7875816993464052
# Epoch [ 252 / 500 ] Training-Loss = 0.5464 Training-Accuracy = 0.45356881618499756 Validation-Accuracy = 0.7875816993464052
# Epoch [ 253 / 500 ] Training-Loss = 0.5459 Training-Accuracy = 0.4541351795196533 Validation-Accuracy = 0.7875816993464052
# Epoch [ 254 / 500 ] Training-Loss = 0.5453 Training-Accuracy = 0.4547203779220581 Validation-Accuracy = 0.7875816993464052
# Epoch [ 255 / 500 ] Training-Loss = 0.5447 Training-Accuracy = 0.4553220868110657 Validation-Accuracy = 0.7875816993464052
# Epoch [ 256 / 500 ] Training-Loss = 0.5441 Training-Accuracy = 0.4559361934661865 Validation-Accuracy = 0.7875816993464052
# Epoch [ 257 / 500 ] Training-Loss = 0.5434 Training-Accuracy = 0.45656687021255493 Validation-Accuracy = 0.7875816993464052
# Epoch [ 258 / 500 ] Training-Loss = 0.5428 Training-Accuracy = 0.4572189450263977 Validation-Accuracy = 0.7875816993464052
# Epoch [ 259 / 500 ] Training-Loss = 0.5421 Training-Accuracy = 0.4578894376754761 Validation-Accuracy = 0.7875816993464052
# Epoch [ 260 / 500 ] Training-Loss = 0.5414 Training-Accuracy = 0.4585716724395752 Validation-Accuracy = 0.7875816993464052
# Epoch [ 261 / 500 ] Training-Loss = 0.5407 Training-Accuracy = 0.45927339792251587 Validation-Accuracy = 0.7875816993464052
# Epoch [ 262 / 500 ] Training-Loss = 0.5400 Training-Accuracy = 0.4599856734275818 Validation-Accuracy = 0.7875816993464052
# Epoch [ 263 / 500 ] Training-Loss = 0.5393 Training-Accuracy = 0.460715651512146 Validation-Accuracy = 0.7875816993464052
# Epoch [ 264 / 500 ] Training-Loss = 0.5385 Training-Accuracy = 0.46146613359451294 Validation-Accuracy = 0.7875816993464052
# Epoch [ 265 / 500 ] Training-Loss = 0.5378 Training-Accuracy = 0.46222859621047974 Validation-Accuracy = 0.7875816993464052
# Epoch [ 266 / 500 ] Training-Loss = 0.5370 Training-Accuracy = 0.4630025625228882 Validation-Accuracy = 0.7875816993464052
# Epoch [ 267 / 500 ] Training-Loss = 0.5362 Training-Accuracy = 0.4637855291366577 Validation-Accuracy = 0.7875816993464052
# Epoch [ 268 / 500 ] Training-Loss = 0.5354 Training-Accuracy = 0.4645710587501526 Validation-Accuracy = 0.7875816993464052
# Epoch [ 269 / 500 ] Training-Loss = 0.5346 Training-Accuracy = 0.465363085269928 Validation-Accuracy = 0.7875816993464052
# Epoch [ 270 / 500 ] Training-Loss = 0.5339 Training-Accuracy = 0.46614640951156616 Validation-Accuracy = 0.7875816993464052
# Epoch [ 271 / 500 ] Training-Loss = 0.5331 Training-Accuracy = 0.4669104814529419 Validation-Accuracy = 0.7875816993464052
# Epoch [ 272 / 500 ] Training-Loss = 0.5323 Training-Accuracy = 0.4676656723022461 Validation-Accuracy = 0.7875816993464052
# Epoch [ 273 / 500 ] Training-Loss = 0.5316 Training-Accuracy = 0.46840494871139526 Validation-Accuracy = 0.7875816993464052
# Epoch [ 274 / 500 ] Training-Loss = 0.5309 Training-Accuracy = 0.46912485361099243 Validation-Accuracy = 0.7875816993464052
# Epoch [ 275 / 500 ] Training-Loss = 0.5302 Training-Accuracy = 0.46981996297836304 Validation-Accuracy = 0.7875816993464052
# Epoch [ 276 / 500 ] Training-Loss = 0.5295 Training-Accuracy = 0.4704861044883728 Validation-Accuracy = 0.7875816993464052
# Epoch [ 277 / 500 ] Training-Loss = 0.5289 Training-Accuracy = 0.4711225628852844 Validation-Accuracy = 0.7875816993464052
# Epoch [ 278 / 500 ] Training-Loss = 0.5283 Training-Accuracy = 0.47173088788986206 Validation-Accuracy = 0.7875816993464052
# Epoch [ 279 / 500 ] Training-Loss = 0.5277 Training-Accuracy = 0.47231942415237427 Validation-Accuracy = 0.7875816993464052
# Epoch [ 280 / 500 ] Training-Loss = 0.5271 Training-Accuracy = 0.4728785753250122 Validation-Accuracy = 0.7875816993464052
# Epoch [ 281 / 500 ] Training-Loss = 0.5266 Training-Accuracy = 0.47340822219848633 Validation-Accuracy = 0.7875816993464052
# Epoch [ 282 / 500 ] Training-Loss = 0.5261 Training-Accuracy = 0.4739009737968445 Validation-Accuracy = 0.7875816993464052
# Epoch [ 283 / 500 ] Training-Loss = 0.5256 Training-Accuracy = 0.4743678569793701 Validation-Accuracy = 0.7875816993464052
# Epoch [ 284 / 500 ] Training-Loss = 0.5252 Training-Accuracy = 0.4748183488845825 Validation-Accuracy = 0.7875816993464052
# Epoch [ 285 / 500 ] Training-Loss = 0.5248 Training-Accuracy = 0.47524893283843994 Validation-Accuracy = 0.7875816993464052
# Epoch [ 286 / 500 ] Training-Loss = 0.5244 Training-Accuracy = 0.4756477475166321 Validation-Accuracy = 0.7875816993464052
# Epoch [ 287 / 500 ] Training-Loss = 0.5240 Training-Accuracy = 0.4760293960571289 Validation-Accuracy = 0.7875816993464052
# Epoch [ 288 / 500 ] Training-Loss = 0.5236 Training-Accuracy = 0.47639626264572144 Validation-Accuracy = 0.7875816993464052
# Epoch [ 289 / 500 ] Training-Loss = 0.5233 Training-Accuracy = 0.47673678398132324 Validation-Accuracy = 0.7875816993464052
# Epoch [ 290 / 500 ] Training-Loss = 0.5229 Training-Accuracy = 0.4770532250404358 Validation-Accuracy = 0.7875816993464052
# Epoch [ 291 / 500 ] Training-Loss = 0.5226 Training-Accuracy = 0.4773629903793335 Validation-Accuracy = 0.7875816993464052
# Epoch [ 292 / 500 ] Training-Loss = 0.5223 Training-Accuracy = 0.47766703367233276 Validation-Accuracy = 0.7875816993464052
# Epoch [ 293 / 500 ] Training-Loss = 0.5220 Training-Accuracy = 0.4779614806175232 Validation-Accuracy = 0.7875816993464052
# Epoch [ 294 / 500 ] Training-Loss = 0.5218 Training-Accuracy = 0.47824615240097046 Validation-Accuracy = 0.7875816993464052
# Epoch [ 295 / 500 ] Training-Loss = 0.5215 Training-Accuracy = 0.47852957248687744 Validation-Accuracy = 0.7875816993464052
# Epoch [ 296 / 500 ] Training-Loss = 0.5212 Training-Accuracy = 0.47881537675857544 Validation-Accuracy = 0.7875816993464052
# Epoch [ 297 / 500 ] Training-Loss = 0.5209 Training-Accuracy = 0.4791169762611389 Validation-Accuracy = 0.7875816993464052
# Epoch [ 298 / 500 ] Training-Loss = 0.5206 Training-Accuracy = 0.47942978143692017 Validation-Accuracy = 0.7875816993464052
# Epoch [ 299 / 500 ] Training-Loss = 0.5203 Training-Accuracy = 0.47974443435668945 Validation-Accuracy = 0.7875816993464052
# Epoch [ 300 / 500 ] Training-Loss = 0.5199 Training-Accuracy = 0.48007023334503174 Validation-Accuracy = 0.7875816993464052
# Epoch [ 301 / 500 ] Training-Loss = 0.5196 Training-Accuracy = 0.4803858995437622 Validation-Accuracy = 0.7875816993464052
# Epoch [ 302 / 500 ] Training-Loss = 0.5193 Training-Accuracy = 0.4806963801383972 Validation-Accuracy = 0.7875816993464052
# Epoch [ 303 / 500 ] Training-Loss = 0.5190 Training-Accuracy = 0.4809790849685669 Validation-Accuracy = 0.7875816993464052
# Epoch [ 304 / 500 ] Training-Loss = 0.5188 Training-Accuracy = 0.4812386631965637 Validation-Accuracy = 0.7875816993464052
# Epoch [ 305 / 500 ] Training-Loss = 0.5185 Training-Accuracy = 0.48151475191116333 Validation-Accuracy = 0.7875816993464052
# Epoch [ 306 / 500 ] Training-Loss = 0.5182 Training-Accuracy = 0.48180335760116577 Validation-Accuracy = 0.7875816993464052
# Epoch [ 307 / 500 ] Training-Loss = 0.5179 Training-Accuracy = 0.4820951819419861 Validation-Accuracy = 0.7875816993464052
# Epoch [ 308 / 500 ] Training-Loss = 0.5176 Training-Accuracy = 0.48239725828170776 Validation-Accuracy = 0.7875816993464052
# Epoch [ 309 / 500 ] Training-Loss = 0.5173 Training-Accuracy = 0.48269736766815186 Validation-Accuracy = 0.7875816993464052
# Epoch [ 310 / 500 ] Training-Loss = 0.5170 Training-Accuracy = 0.48298805952072144 Validation-Accuracy = 0.7875816993464052
# Epoch [ 311 / 500 ] Training-Loss = 0.5167 Training-Accuracy = 0.48328059911727905 Validation-Accuracy = 0.7875816993464052
# Epoch [ 312 / 500 ] Training-Loss = 0.5164 Training-Accuracy = 0.4835737943649292 Validation-Accuracy = 0.7875816993464052
# Epoch [ 313 / 500 ] Training-Loss = 0.5161 Training-Accuracy = 0.48386698961257935 Validation-Accuracy = 0.7875816993464052
# Epoch [ 314 / 500 ] Training-Loss = 0.5158 Training-Accuracy = 0.48416489362716675 Validation-Accuracy = 0.7875816993464052
# Epoch [ 315 / 500 ] Training-Loss = 0.5155 Training-Accuracy = 0.4844664931297302 Validation-Accuracy = 0.7875816993464052
# Epoch [ 316 / 500 ] Training-Loss = 0.5152 Training-Accuracy = 0.4847671389579773 Validation-Accuracy = 0.7875816993464052
# Epoch [ 317 / 500 ] Training-Loss = 0.5149 Training-Accuracy = 0.4850653409957886 Validation-Accuracy = 0.7875816993464052
# Epoch [ 318 / 500 ] Training-Loss = 0.5146 Training-Accuracy = 0.48536014556884766 Validation-Accuracy = 0.7875816993464052
# Epoch [ 319 / 500 ] Training-Loss = 0.5143 Training-Accuracy = 0.48566436767578125 Validation-Accuracy = 0.7875816993464052
# Epoch [ 320 / 500 ] Training-Loss = 0.5140 Training-Accuracy = 0.4859756827354431 Validation-Accuracy = 0.7875816993464052
# Epoch [ 321 / 500 ] Training-Loss = 0.5137 Training-Accuracy = 0.4863016605377197 Validation-Accuracy = 0.7875816993464052
# Epoch [ 322 / 500 ] Training-Loss = 0.5134 Training-Accuracy = 0.48662877082824707 Validation-Accuracy = 0.7875816993464052
# Epoch [ 323 / 500 ] Training-Loss = 0.5130 Training-Accuracy = 0.4869678020477295 Validation-Accuracy = 0.7875816993464052
# Epoch [ 324 / 500 ] Training-Loss = 0.5127 Training-Accuracy = 0.48730677366256714 Validation-Accuracy = 0.7875816993464052
# Epoch [ 325 / 500 ] Training-Loss = 0.5124 Training-Accuracy = 0.48763442039489746 Validation-Accuracy = 0.7875816993464052
# Epoch [ 326 / 500 ] Training-Loss = 0.5121 Training-Accuracy = 0.48793143033981323 Validation-Accuracy = 0.7875816993464052
# Epoch [ 327 / 500 ] Training-Loss = 0.5117 Training-Accuracy = 0.488254189491272 Validation-Accuracy = 0.7875816993464052
# Epoch [ 328 / 500 ] Training-Loss = 0.5113 Training-Accuracy = 0.4886990189552307 Validation-Accuracy = 0.7875816993464052
# Epoch [ 329 / 500 ] Training-Loss = 0.5110 Training-Accuracy = 0.48904168605804443 Validation-Accuracy = 0.7875816993464052
# Epoch [ 330 / 500 ] Training-Loss = 0.5107 Training-Accuracy = 0.48931992053985596 Validation-Accuracy = 0.7875816993464052
# Epoch [ 331 / 500 ] Training-Loss = 0.5102 Training-Accuracy = 0.4897691607475281 Validation-Accuracy = 0.7875816993464052
# Epoch [ 332 / 500 ] Training-Loss = 0.5098 Training-Accuracy = 0.49018383026123047 Validation-Accuracy = 0.7875816993464052
# Epoch [ 333 / 500 ] Training-Loss = 0.5095 Training-Accuracy = 0.4905400276184082 Validation-Accuracy = 0.7875816993464052
# Epoch [ 334 / 500 ] Training-Loss = 0.5090 Training-Accuracy = 0.49097293615341187 Validation-Accuracy = 0.7875816993464052
# Epoch [ 335 / 500 ] Training-Loss = 0.5086 Training-Accuracy = 0.4913756847381592 Validation-Accuracy = 0.7875816993464052
# Epoch [ 336 / 500 ] Training-Loss = 0.5082 Training-Accuracy = 0.49176132678985596 Validation-Accuracy = 0.7875816993464052
# Epoch [ 337 / 500 ] Training-Loss = 0.5078 Training-Accuracy = 0.4922366142272949 Validation-Accuracy = 0.7875816993464052
# Epoch [ 338 / 500 ] Training-Loss = 0.5073 Training-Accuracy = 0.49269574880599976 Validation-Accuracy = 0.7875816993464052
# Epoch [ 339 / 500 ] Training-Loss = 0.5069 Training-Accuracy = 0.4930981397628784 Validation-Accuracy = 0.7875816993464052
# Epoch [ 340 / 500 ] Training-Loss = 0.5065 Training-Accuracy = 0.49349451065063477 Validation-Accuracy = 0.7875816993464052
# Epoch [ 341 / 500 ] Training-Loss = 0.5060 Training-Accuracy = 0.4940236806869507 Validation-Accuracy = 0.7875816993464052
# Epoch [ 342 / 500 ] Training-Loss = 0.5055 Training-Accuracy = 0.4945083260536194 Validation-Accuracy = 0.7875816993464052
# Epoch [ 343 / 500 ] Training-Loss = 0.5051 Training-Accuracy = 0.4949473738670349 Validation-Accuracy = 0.7875816993464052
# Epoch [ 344 / 500 ] Training-Loss = 0.5046 Training-Accuracy = 0.4953871965408325 Validation-Accuracy = 0.7875816993464052
# Epoch [ 345 / 500 ] Training-Loss = 0.5042 Training-Accuracy = 0.49584293365478516 Validation-Accuracy = 0.7875816993464052
# Epoch [ 346 / 500 ] Training-Loss = 0.5037 Training-Accuracy = 0.49632728099823 Validation-Accuracy = 0.7875816993464052
# Epoch [ 347 / 500 ] Training-Loss = 0.5032 Training-Accuracy = 0.49681270122528076 Validation-Accuracy = 0.7875816993464052
# Epoch [ 348 / 500 ] Training-Loss = 0.5027 Training-Accuracy = 0.4973018765449524 Validation-Accuracy = 0.7875816993464052
# Epoch [ 349 / 500 ] Training-Loss = 0.5022 Training-Accuracy = 0.49779587984085083 Validation-Accuracy = 0.7875816993464052
# Epoch [ 350 / 500 ] Training-Loss = 0.5017 Training-Accuracy = 0.4982806444168091 Validation-Accuracy = 0.7875816993464052
# Epoch [ 351 / 500 ] Training-Loss = 0.5012 Training-Accuracy = 0.49879205226898193 Validation-Accuracy = 0.7875816993464052
# Epoch [ 352 / 500 ] Training-Loss = 0.5007 Training-Accuracy = 0.49928539991378784 Validation-Accuracy = 0.7875816993464052
# Epoch [ 353 / 500 ] Training-Loss = 0.5002 Training-Accuracy = 0.4997817277908325 Validation-Accuracy = 0.7875816993464052
# Epoch [ 354 / 500 ] Training-Loss = 0.4997 Training-Accuracy = 0.5002806186676025 Validation-Accuracy = 0.7875816993464052
# Epoch [ 355 / 500 ] Training-Loss = 0.4991 Training-Accuracy = 0.5008572041988373 Validation-Accuracy = 0.7875816993464052
# Epoch [ 356 / 500 ] Training-Loss = 0.4986 Training-Accuracy = 0.5014204680919647 Validation-Accuracy = 0.7875816993464052
# Epoch [ 357 / 500 ] Training-Loss = 0.4980 Training-Accuracy = 0.50201615691185 Validation-Accuracy = 0.7875816993464052
# Epoch [ 358 / 500 ] Training-Loss = 0.4974 Training-Accuracy = 0.5025604367256165 Validation-Accuracy = 0.7875816993464052
# Epoch [ 359 / 500 ] Training-Loss = 0.4969 Training-Accuracy = 0.503092348575592 Validation-Accuracy = 0.7875816993464052
# Epoch [ 360 / 500 ] Training-Loss = 0.4964 Training-Accuracy = 0.5036021769046783 Validation-Accuracy = 0.7875816993464052
# Epoch [ 361 / 500 ] Training-Loss = 0.4959 Training-Accuracy = 0.5040761232376099 Validation-Accuracy = 0.7875816993464052
# Epoch [ 362 / 500 ] Training-Loss = 0.4956 Training-Accuracy = 0.504368782043457 Validation-Accuracy = 0.7875816993464052
# Epoch [ 363 / 500 ] Training-Loss = 0.4951 Training-Accuracy = 0.5049247145652771 Validation-Accuracy = 0.7875816993464052
# Epoch [ 364 / 500 ] Training-Loss = 0.4945 Training-Accuracy = 0.5055057108402252 Validation-Accuracy = 0.7875816993464052
# Epoch [ 365 / 500 ] Training-Loss = 0.4937 Training-Accuracy = 0.5062989294528961 Validation-Accuracy = 0.7875816993464052
# Epoch [ 366 / 500 ] Training-Loss = 0.4933 Training-Accuracy = 0.5067410469055176 Validation-Accuracy = 0.7875816993464052
# Epoch [ 367 / 500 ] Training-Loss = 0.4930 Training-Accuracy = 0.5070011913776398 Validation-Accuracy = 0.7875816993464052
# Epoch [ 368 / 500 ] Training-Loss = 0.4924 Training-Accuracy = 0.5076304972171783 Validation-Accuracy = 0.7875816993464052
# Epoch [ 369 / 500 ] Training-Loss = 0.4917 Training-Accuracy = 0.5083047747612 Validation-Accuracy = 0.7875816993464052
# Epoch [ 370 / 500 ] Training-Loss = 0.4911 Training-Accuracy = 0.5089027881622314 Validation-Accuracy = 0.7875816993464052
# Epoch [ 371 / 500 ] Training-Loss = 0.4906 Training-Accuracy = 0.5093840062618256 Validation-Accuracy = 0.7875816993464052
# Epoch [ 372 / 500 ] Training-Loss = 0.4902 Training-Accuracy = 0.5098248720169067 Validation-Accuracy = 0.7875816993464052
# Epoch [ 373 / 500 ] Training-Loss = 0.4897 Training-Accuracy = 0.5102699398994446 Validation-Accuracy = 0.7875816993464052
# Epoch [ 374 / 500 ] Training-Loss = 0.4892 Training-Accuracy = 0.51075878739357 Validation-Accuracy = 0.7875816993464052
# Epoch [ 375 / 500 ] Training-Loss = 0.4886 Training-Accuracy = 0.5114159286022186 Validation-Accuracy = 0.7875816993464052
# Epoch [ 376 / 500 ] Training-Loss = 0.4880 Training-Accuracy = 0.5120034217834473 Validation-Accuracy = 0.7875816993464052
# Epoch [ 377 / 500 ] Training-Loss = 0.4875 Training-Accuracy = 0.5125012993812561 Validation-Accuracy = 0.7875816993464052
# Epoch [ 378 / 500 ] Training-Loss = 0.4870 Training-Accuracy = 0.512976199388504 Validation-Accuracy = 0.7875816993464052
# Epoch [ 379 / 500 ] Training-Loss = 0.4867 Training-Accuracy = 0.5132606327533722 Validation-Accuracy = 0.7875816993464052
# Epoch [ 380 / 500 ] Training-Loss = 0.4862 Training-Accuracy = 0.5137632489204407 Validation-Accuracy = 0.7875816993464052
# Epoch [ 381 / 500 ] Training-Loss = 0.4857 Training-Accuracy = 0.5143439173698425 Validation-Accuracy = 0.7875816993464052
# Epoch [ 382 / 500 ] Training-Loss = 0.4848 Training-Accuracy = 0.5152144134044647 Validation-Accuracy = 0.7875816993464052
# Epoch [ 383 / 500 ] Training-Loss = 0.4841 Training-Accuracy = 0.5158698260784149 Validation-Accuracy = 0.7875816993464052
# Epoch [ 384 / 500 ] Training-Loss = 0.4838 Training-Accuracy = 0.5162485539913177 Validation-Accuracy = 0.7875816993464052
# Epoch [ 385 / 500 ] Training-Loss = 0.4834 Training-Accuracy = 0.516564130783081 Validation-Accuracy = 0.7875816993464052
# Epoch [ 386 / 500 ] Training-Loss = 0.4830 Training-Accuracy = 0.517041802406311 Validation-Accuracy = 0.7875816993464052
# Epoch [ 387 / 500 ] Training-Loss = 0.4822 Training-Accuracy = 0.5177931785583496 Validation-Accuracy = 0.7875816993464052
# Epoch [ 388 / 500 ] Training-Loss = 0.4813 Training-Accuracy = 0.5186764597892761 Validation-Accuracy = 0.7875816993464052
# Epoch [ 389 / 500 ] Training-Loss = 0.4807 Training-Accuracy = 0.5193237066268921 Validation-Accuracy = 0.7875816993464052
# Epoch [ 390 / 500 ] Training-Loss = 0.4802 Training-Accuracy = 0.5197855234146118 Validation-Accuracy = 0.7875816993464052
# Epoch [ 391 / 500 ] Training-Loss = 0.4797 Training-Accuracy = 0.5203302502632141 Validation-Accuracy = 0.7875816993464052
# Epoch [ 392 / 500 ] Training-Loss = 0.4792 Training-Accuracy = 0.5207886397838593 Validation-Accuracy = 0.7875816993464052
# Epoch [ 393 / 500 ] Training-Loss = 0.4785 Training-Accuracy = 0.5215182304382324 Validation-Accuracy = 0.7875816993464052
# Epoch [ 394 / 500 ] Training-Loss = 0.4778 Training-Accuracy = 0.5222297012805939 Validation-Accuracy = 0.7875816993464052
# Epoch [ 395 / 500 ] Training-Loss = 0.4771 Training-Accuracy = 0.5229279696941376 Validation-Accuracy = 0.7875816993464052
# Epoch [ 396 / 500 ] Training-Loss = 0.4766 Training-Accuracy = 0.5233751535415649 Validation-Accuracy = 0.7908496732026143
# Epoch [ 397 / 500 ] Training-Loss = 0.4763 Training-Accuracy = 0.5236831903457642 Validation-Accuracy = 0.7941176470588235
# Epoch [ 398 / 500 ] Training-Loss = 0.4757 Training-Accuracy = 0.5242553055286407 Validation-Accuracy = 0.8006535947712419
# Epoch [ 399 / 500 ] Training-Loss = 0.4749 Training-Accuracy = 0.5251099467277527 Validation-Accuracy = 0.7941176470588235
# Epoch [ 400 / 500 ] Training-Loss = 0.4741 Training-Accuracy = 0.5259474515914917 Validation-Accuracy = 0.7843137254901961
# Epoch [ 401 / 500 ] Training-Loss = 0.4733 Training-Accuracy = 0.5266617238521576 Validation-Accuracy = 0.7810457516339869
# Epoch [ 402 / 500 ] Training-Loss = 0.4729 Training-Accuracy = 0.5270875990390778 Validation-Accuracy = 0.7875816993464052
# Epoch [ 403 / 500 ] Training-Loss = 0.4731 Training-Accuracy = 0.5269005596637726 Validation-Accuracy = 0.7843137254901961
# Epoch [ 404 / 500 ] Training-Loss = 0.4738 Training-Accuracy = 0.5262316763401031 Validation-Accuracy = 0.7908496732026143
# Epoch [ 405 / 500 ] Training-Loss = 0.4722 Training-Accuracy = 0.5277657508850098 Validation-Accuracy = 0.7777777777777778
# Epoch [ 406 / 500 ] Training-Loss = 0.4703 Training-Accuracy = 0.5296521782875061 Validation-Accuracy = 0.7712418300653595
# Epoch [ 407 / 500 ] Training-Loss = 0.4698 Training-Accuracy = 0.5302082598209381 Validation-Accuracy = 0.7745098039215687
# Epoch [ 408 / 500 ] Training-Loss = 0.4702 Training-Accuracy = 0.5298091471195221 Validation-Accuracy = 0.7647058823529411
# Epoch [ 409 / 500 ] Training-Loss = 0.4703 Training-Accuracy = 0.5296701490879059 Validation-Accuracy = 0.7712418300653595
# Epoch [ 410 / 500 ] Training-Loss = 0.4680 Training-Accuracy = 0.5319890081882477 Validation-Accuracy = 0.7712418300653595
# Epoch [ 411 / 500 ] Training-Loss = 0.4681 Training-Accuracy = 0.531912624835968 Validation-Accuracy = 0.7549019607843137
# Epoch [ 412 / 500 ] Training-Loss = 0.4689 Training-Accuracy = 0.531075656414032 Validation-Accuracy = 0.7679738562091504
# Epoch [ 413 / 500 ] Training-Loss = 0.4664 Training-Accuracy = 0.5335899889469147 Validation-Accuracy = 0.7745098039215687
# Epoch [ 414 / 500 ] Training-Loss = 0.4668 Training-Accuracy = 0.5331855416297913 Validation-Accuracy = 0.738562091503268
# Epoch [ 415 / 500 ] Training-Loss = 0.4674 Training-Accuracy = 0.5326302647590637 Validation-Accuracy = 0.7581699346405228
# Epoch [ 416 / 500 ] Training-Loss = 0.4647 Training-Accuracy = 0.5352595150470734 Validation-Accuracy = 0.7777777777777778
# Epoch [ 417 / 500 ] Training-Loss = 0.4664 Training-Accuracy = 0.5336346328258514 Validation-Accuracy = 0.738562091503268
# Epoch [ 418 / 500 ] Training-Loss = 0.4656 Training-Accuracy = 0.534433513879776 Validation-Accuracy = 0.7450980392156863
# Epoch [ 419 / 500 ] Training-Loss = 0.4636 Training-Accuracy = 0.5363806486129761 Validation-Accuracy = 0.7647058823529411
# Epoch [ 420 / 500 ] Training-Loss = 0.4653 Training-Accuracy = 0.5346516668796539 Validation-Accuracy = 0.738562091503268
# Epoch [ 421 / 500 ] Training-Loss = 0.4624 Training-Accuracy = 0.5376003682613373 Validation-Accuracy = 0.7320261437908496
# Epoch [ 422 / 500 ] Training-Loss = 0.4635 Training-Accuracy = 0.536523163318634 Validation-Accuracy = 0.7581699346405228
# Epoch [ 423 / 500 ] Training-Loss = 0.4623 Training-Accuracy = 0.5377301871776581 Validation-Accuracy = 0.7516339869281046
# Epoch [ 424 / 500 ] Training-Loss = 0.4612 Training-Accuracy = 0.5388395488262177 Validation-Accuracy = 0.7287581699346405
# Epoch [ 425 / 500 ] Training-Loss = 0.4620 Training-Accuracy = 0.5380227565765381 Validation-Accuracy = 0.738562091503268
# Epoch [ 426 / 500 ] Training-Loss = 0.4598 Training-Accuracy = 0.5402254164218903 Validation-Accuracy = 0.7549019607843137
# Epoch [ 427 / 500 ] Training-Loss = 0.4606 Training-Accuracy = 0.5393880605697632 Validation-Accuracy = 0.738562091503268
# Epoch [ 428 / 500 ] Training-Loss = 0.4595 Training-Accuracy = 0.540547102689743 Validation-Accuracy = 0.7418300653594772
# Epoch [ 429 / 500 ] Training-Loss = 0.4585 Training-Accuracy = 0.5415033102035522 Validation-Accuracy = 0.7549019607843137
# Epoch [ 430 / 500 ] Training-Loss = 0.4591 Training-Accuracy = 0.5408523082733154 Validation-Accuracy = 0.7418300653594772
# Epoch [ 431 / 500 ] Training-Loss = 0.4574 Training-Accuracy = 0.5426483750343323 Validation-Accuracy = 0.7418300653594772
# Epoch [ 432 / 500 ] Training-Loss = 0.4575 Training-Accuracy = 0.5424743294715881 Validation-Accuracy = 0.7516339869281046
# Epoch [ 433 / 500 ] Training-Loss = 0.4570 Training-Accuracy = 0.5430118441581726 Validation-Accuracy = 0.738562091503268
# Epoch [ 434 / 500 ] Training-Loss = 0.4558 Training-Accuracy = 0.5442429482936859 Validation-Accuracy = 0.738562091503268
# Epoch [ 435 / 500 ] Training-Loss = 0.4560 Training-Accuracy = 0.5439502596855164 Validation-Accuracy = 0.7450980392156863
# Epoch [ 436 / 500 ] Training-Loss = 0.4550 Training-Accuracy = 0.5450035929679871 Validation-Accuracy = 0.7450980392156863
# Epoch [ 437 / 500 ] Training-Loss = 0.4543 Training-Accuracy = 0.545700192451477 Validation-Accuracy = 0.738562091503268
# Epoch [ 438 / 500 ] Training-Loss = 0.4545 Training-Accuracy = 0.5455422103404999 Validation-Accuracy = 0.7483660130718954
# Epoch [ 439 / 500 ] Training-Loss = 0.4535 Training-Accuracy = 0.5465214252471924 Validation-Accuracy = 0.7418300653594772
# Epoch [ 440 / 500 ] Training-Loss = 0.4527 Training-Accuracy = 0.5473437905311584 Validation-Accuracy = 0.7352941176470589
# Epoch [ 441 / 500 ] Training-Loss = 0.4525 Training-Accuracy = 0.547513335943222 Validation-Accuracy = 0.7483660130718954
# Epoch [ 442 / 500 ] Training-Loss = 0.4519 Training-Accuracy = 0.5481355786323547 Validation-Accuracy = 0.7352941176470589
# Epoch [ 443 / 500 ] Training-Loss = 0.4511 Training-Accuracy = 0.5489205121994019 Validation-Accuracy = 0.7352941176470589
# Epoch [ 444 / 500 ] Training-Loss = 0.4506 Training-Accuracy = 0.549412339925766 Validation-Accuracy = 0.7483660130718954
# Epoch [ 445 / 500 ] Training-Loss = 0.4503 Training-Accuracy = 0.5497314929962158 Validation-Accuracy = 0.7320261437908496
# Epoch [ 446 / 500 ] Training-Loss = 0.4498 Training-Accuracy = 0.5502486228942871 Validation-Accuracy = 0.7418300653594772
# Epoch [ 447 / 500 ] Training-Loss = 0.4489 Training-Accuracy = 0.5510647892951965 Validation-Accuracy = 0.738562091503268
# Epoch [ 448 / 500 ] Training-Loss = 0.4482 Training-Accuracy = 0.5517702698707581 Validation-Accuracy = 0.7287581699346405
# Epoch [ 449 / 500 ] Training-Loss = 0.4477 Training-Accuracy = 0.5522994697093964 Validation-Accuracy = 0.7418300653594772
# Epoch [ 450 / 500 ] Training-Loss = 0.4472 Training-Accuracy = 0.5528070032596588 Validation-Accuracy = 0.7254901960784313
# Epoch [ 451 / 500 ] Training-Loss = 0.4467 Training-Accuracy = 0.5533307790756226 Validation-Accuracy = 0.7418300653594772
# Epoch [ 452 / 500 ] Training-Loss = 0.4459 Training-Accuracy = 0.5540666580200195 Validation-Accuracy = 0.7287581699346405
# Epoch [ 453 / 500 ] Training-Loss = 0.4452 Training-Accuracy = 0.5548177063465118 Validation-Accuracy = 0.7418300653594772
# Epoch [ 454 / 500 ] Training-Loss = 0.4447 Training-Accuracy = 0.5553208887577057 Validation-Accuracy = 0.7124183006535948
# Epoch [ 455 / 500 ] Training-Loss = 0.4445 Training-Accuracy = 0.5555036067962646 Validation-Accuracy = 0.7352941176470589
# Epoch [ 456 / 500 ] Training-Loss = 0.4443 Training-Accuracy = 0.5556904673576355 Validation-Accuracy = 0.7124183006535948
# Epoch [ 457 / 500 ] Training-Loss = 0.4441 Training-Accuracy = 0.5559321045875549 Validation-Accuracy = 0.7352941176470589
# Epoch [ 458 / 500 ] Training-Loss = 0.4431 Training-Accuracy = 0.5569413900375366 Validation-Accuracy = 0.7222222222222222
# Epoch [ 459 / 500 ] Training-Loss = 0.4416 Training-Accuracy = 0.5583970844745636 Validation-Accuracy = 0.738562091503268
# Epoch [ 460 / 500 ] Training-Loss = 0.4407 Training-Accuracy = 0.5593479573726654 Validation-Accuracy = 0.7352941176470589
# Epoch [ 461 / 500 ] Training-Loss = 0.4400 Training-Accuracy = 0.5599700510501862 Validation-Accuracy = 0.7287581699346405
# Epoch [ 462 / 500 ] Training-Loss = 0.4398 Training-Accuracy = 0.5602478086948395 Validation-Accuracy = 0.7483660130718954
# Epoch [ 463 / 500 ] Training-Loss = 0.4402 Training-Accuracy = 0.5598280131816864 Validation-Accuracy = 0.7156862745098039
# Epoch [ 464 / 500 ] Training-Loss = 0.4407 Training-Accuracy = 0.5592612326145172 Validation-Accuracy = 0.7483660130718954
# Epoch [ 465 / 500 ] Training-Loss = 0.4403 Training-Accuracy = 0.5596681535243988 Validation-Accuracy = 0.7222222222222222
# Epoch [ 466 / 500 ] Training-Loss = 0.4385 Training-Accuracy = 0.5615071058273315 Validation-Accuracy = 0.7418300653594772
# Epoch [ 467 / 500 ] Training-Loss = 0.4372 Training-Accuracy = 0.5627787411212921 Validation-Accuracy = 0.7418300653594772
# Epoch [ 468 / 500 ] Training-Loss = 0.4369 Training-Accuracy = 0.563145786523819 Validation-Accuracy = 0.7189542483660131
# Epoch [ 469 / 500 ] Training-Loss = 0.4370 Training-Accuracy = 0.5629792213439941 Validation-Accuracy = 0.7483660130718954
# Epoch [ 470 / 500 ] Training-Loss = 0.4371 Training-Accuracy = 0.5629138350486755 Validation-Accuracy = 0.7222222222222222
# Epoch [ 471 / 500 ] Training-Loss = 0.4358 Training-Accuracy = 0.5641515851020813 Validation-Accuracy = 0.7450980392156863
# Epoch [ 472 / 500 ] Training-Loss = 0.4349 Training-Accuracy = 0.5650756657123566 Validation-Accuracy = 0.7483660130718954
# Epoch [ 473 / 500 ] Training-Loss = 0.4348 Training-Accuracy = 0.5652443766593933 Validation-Accuracy = 0.7287581699346405
# Epoch [ 474 / 500 ] Training-Loss = 0.4345 Training-Accuracy = 0.5654863119125366 Validation-Accuracy = 0.7516339869281046
# Epoch [ 475 / 500 ] Training-Loss = 0.4339 Training-Accuracy = 0.5660728812217712 Validation-Accuracy = 0.7450980392156863
# Epoch [ 476 / 500 ] Training-Loss = 0.4332 Training-Accuracy = 0.5667968094348907 Validation-Accuracy = 0.7450980392156863
# Epoch [ 477 / 500 ] Training-Loss = 0.4329 Training-Accuracy = 0.5671365261077881 Validation-Accuracy = 0.7549019607843137
# Epoch [ 478 / 500 ] Training-Loss = 0.4326 Training-Accuracy = 0.5673653185367584 Validation-Accuracy = 0.7450980392156863
# Epoch [ 479 / 500 ] Training-Loss = 0.4322 Training-Accuracy = 0.5678079128265381 Validation-Accuracy = 0.7516339869281046
# Epoch [ 480 / 500 ] Training-Loss = 0.4316 Training-Accuracy = 0.5684272050857544 Validation-Accuracy = 0.7483660130718954
# Epoch [ 481 / 500 ] Training-Loss = 0.4311 Training-Accuracy = 0.5689340233802795 Validation-Accuracy = 0.7450980392156863
# Epoch [ 482 / 500 ] Training-Loss = 0.4308 Training-Accuracy = 0.5692094266414642 Validation-Accuracy = 0.7549019607843137
# Epoch [ 483 / 500 ] Training-Loss = 0.4305 Training-Accuracy = 0.5695181787014008 Validation-Accuracy = 0.7450980392156863
# Epoch [ 484 / 500 ] Training-Loss = 0.4302 Training-Accuracy = 0.5697978138923645 Validation-Accuracy = 0.7549019607843137
# Epoch [ 485 / 500 ] Training-Loss = 0.4299 Training-Accuracy = 0.5701189041137695 Validation-Accuracy = 0.7483660130718954
# Epoch [ 486 / 500 ] Training-Loss = 0.4295 Training-Accuracy = 0.5705134570598602 Validation-Accuracy = 0.7581699346405228
# Epoch [ 487 / 500 ] Training-Loss = 0.4291 Training-Accuracy = 0.5709050595760345 Validation-Accuracy = 0.7483660130718954
# Epoch [ 488 / 500 ] Training-Loss = 0.4285 Training-Accuracy = 0.5714537799358368 Validation-Accuracy = 0.7549019607843137
# Epoch [ 489 / 500 ] Training-Loss = 0.4280 Training-Accuracy = 0.5720459222793579 Validation-Accuracy = 0.7483660130718954
# Epoch [ 490 / 500 ] Training-Loss = 0.4274 Training-Accuracy = 0.5726175308227539 Validation-Accuracy = 0.7483660130718954
# Epoch [ 491 / 500 ] Training-Loss = 0.4269 Training-Accuracy = 0.5730624198913574 Validation-Accuracy = 0.7516339869281046
# Epoch [ 492 / 500 ] Training-Loss = 0.4266 Training-Accuracy = 0.5733793675899506 Validation-Accuracy = 0.738562091503268
# Epoch [ 493 / 500 ] Training-Loss = 0.4267 Training-Accuracy = 0.5733303129673004 Validation-Accuracy = 0.7581699346405228
# Epoch [ 494 / 500 ] Training-Loss = 0.4279 Training-Accuracy = 0.5721447467803955 Validation-Accuracy = 0.7189542483660131
# Epoch [ 495 / 500 ] Training-Loss = 0.4310 Training-Accuracy = 0.5689976811408997 Validation-Accuracy = 0.7647058823529411
# Epoch [ 496 / 500 ] Training-Loss = 0.4315 Training-Accuracy = 0.5685005486011505 Validation-Accuracy = 0.7287581699346405
# Epoch [ 497 / 500 ] Training-Loss = 0.4268 Training-Accuracy = 0.5731652677059174 Validation-Accuracy = 0.7418300653594772
# Epoch [ 498 / 500 ] Training-Loss = 0.4243 Training-Accuracy = 0.575679749250412 Validation-Accuracy = 0.7647058823529411
# Epoch [ 499 / 500 ] Training-Loss = 0.4273 Training-Accuracy = 0.5727050304412842 Validation-Accuracy = 0.7287581699346405
# Epoch [ 500 / 500 ] Training-Loss = 0.4283 Training-Accuracy = 0.5717458426952362 Validation-Accuracy = 0.7516339869281046

# %%
print("Maximum Training Accuracy = ", max(training_acc_list))
print("Maximum Validation Accuracy = ", max(val_acc_list))
model = model_list[training_acc_list.index(max(training_acc_list))]
# Out:
# Maximum Training Accuracy =  0.575679749250412
# Maximum Validation Accuracy =  0.8006535947712419

# %%
predicted = model(x_train).to(device)
predicted = torch.max(predicted.data,1)[1]
confusionMatrixPrint(predicted.to('cpu').numpy(),y_train.to('cpu').numpy(),0)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Train Data :
#          True Positive =  192            True Negetive =  129
#         False Positive =  84           False Negetive =  816
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 1221
#
# Accuracy  :  0.8255528255528255
# Precision :  0.6956521739130435
# Recall    :  0.5981308411214953
# F1 Score  :  0.64321608040201
#
# ------------------------------------------------------------------------------------

# %%
predicted = model(x_test).to(device)
predicted = torch.max(predicted.data,1)[1]
confusionMatrixPrint(predicted.to('cpu').numpy(),y_test.to('cpu').numpy(),1)
# Out:
# ------------------------------------------------------------------------------------
#
#   Confusion Matrix for Validation Data
#
#          True Positive =  23            True Negetive =  42
#         False Positive =  34           False Negetive =  207
#
# ------------------------------------------------------------------------------------
#
#   Total Cases : 306
#
# Accuracy  :  0.7516339869281046
# Precision :  0.40350877192982454
# Recall    :  0.35384615384615387
# F1 Score  :  0.3770491803278689
#
# ------------------------------------------------------------------------------------

# %%
torch.save(model,"saved_model/combined_nn.pt")

# %%
def get_trainable_data_2():
    global x_train, x_test, y_train, y_test, is_updated
    dataset_path = "C:/Users/Sampad/Desktop/Projects/Capstone/Implimentation/Code/0_DataSet/"

    df = pd.read_csv(dataset_path + "CompleteAnnotated.csv")

    df.tweet_text = df.tweet_text.apply(text_clean)
    complete_docs = []

    for i in range(df.shape[0]):
        complete_docs.append(df.iloc[i]['tweet_text'].split())

    complete_dict = Dictionary(complete_docs)
    complete_corpus = [complete_dict.doc2bow(text) for text in complete_docs]
    lda = LdaModel(complete_corpus, num_topics=10)

    num_topics = 10
    labels = []

    # LDA outputs
    user_topic_vectors = []
    print(
        '-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-* Hawkes Process Started -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*\n\n')
    for i in range(get_number_of_users()):
        # from 0_Datset folder get each user tweets timeline and filter retweets from them
        i_user_df = get_retweet_df(i)
        if i_user_df.shape[0] < 2:
            continue

        # String Date Time to python Datetime library
        i_user_df.created_at = i_user_df.created_at.apply(dateTimeCreator)

        # time at which first retweet was made
        min_date = min(i_user_df['created_at'])

        # time to minutes passed from the first retweet
        timestamps = i_user_df.created_at.apply(get_timestamp, origin_date=min_date).to_numpy()

        min_time = np.min(timestamps)
        max_time = np.max(timestamps)

        # Min-Max Scaler (0, 1)
        sorted_time = (np.sort(np.unique((timestamps - min_time) / max_time)))

        # fit the model and get the Hawkes Expression kernal model output
        BaseLine, adj_mat = get_hawkes_model(timestamps=[sorted_time])

        # append the results

        # baselines.append(BaseLine)
        if df[df.user_id == i_user_df['user_id'][0]]['Annotation'].item() == 1 or \
                df[df.user_id == i_user_df['user_id'][0]]['Tag'].item() == 1:
            labels.append(1)
        else:
            labels.append(0)
        # hawkes_user_ids.append(i_user_df['user_id'][0])
        # adjs.append(adj_mat)

        # get topic vector for tweet in users.csv file
        tweet_text_list = df[df.user_id == i_user_df['user_id'][0]]['tweet_text'].item().split()
        topic_vector = get_topic_vector(tweet_text_list, num_topics, complete_dict, lda)
        topic_vector[-1] = BaseLine
        topic_vector[-2] = adj_mat

        user_topic_vectors.append(topic_vector)

    print(
        '-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-* Hawkes Process Ended -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*\n')

    labels = np.array(labels)
    user_topic_vectors = np.array(user_topic_vectors)

    x_train, x_test, y_train, y_test = train_test_splitter(user_topic_vectors, labels)
    is_updated = True
    return user_topic_vectors, labels
